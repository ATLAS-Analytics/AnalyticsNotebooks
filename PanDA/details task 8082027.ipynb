# %% [raw]
# For a given jeditaskid return the Panda Job ID and the number of events

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from elasticsearch import Elasticsearch, exceptions as es_exceptions
from elasticsearch.helpers import scan
es = Elasticsearch(hosts=[{'host':'atlas-kibana.mwt2.org', 'port':9200}],timeout=180)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from elasticsearch import Elasticsearch, exceptions as es_exceptions
from elasticsearch.helpers import scan

es = Elasticsearch(hosts=[{'host':'atlas-kibana.mwt2.org', 'port':9200}],timeout=180)

ind="jobs2016"

ss = {
  "query": {
    "filtered": {
      "filter" : {
        "range" : {
          "nevents" : { "gt" : 0 } 
          }
      },
      "query" : {
        "match" : {
          "jeditaskid" : "8764489" 
        }
      }
    }
  }
}

res= es.search( index=ind, body=ss, analyze_wildcard=True)
print (res)
#scroll = scan(es, query=ss, index=ind)
scroll = scan(es, query=ss, index=ind, scroll='10s')

fi=[]
fa=[]
for res in scroll:
    print (res)
    #r=res['fields']
    #if r['jobstatus'][0]=='finished':
    #    fi.append(r['wall_time'][0]/3600)
    #elif r['jobstatus'][0]=='failed':
    #    fa.append(r['wall_time'][0]/3600)
# Out:
# {'hits': {'max_score': None, 'total': 0, 'hits': []}, 'timed_out': False, '_shards': {'successful': 650, 'total': 650, 'failed': 0}, 'took': 64}

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from elasticsearch import Elasticsearch, exceptions as es_exceptions
from elasticsearch.helpers import scan

es = Elasticsearch(hosts=[{'host':'atlas-kibana.mwt2.org', 'port':9200}],timeout=180)

indices=es.indices.get_aliases().keys()
jobs_indices=[]
sorted_indices = sorted(indices)
for index in sorted_indices:
    if "jobs_archive_2016" in index:
        jobs_indices.append(index)
        #print(index)
ss = {
  "fields": ["nevents","wall_time","jobstatus","cpuconsumptiontime","pandaid","transformation","jobmetrics"],
  "query": {
    "filtered": {
      "filter" : {
        "range" : {
          "nevents" : { "gt" : 0 } 
          }
      },
      "query" : {
        "match" : {
          "jeditaskid" : "8082027" 
        }
      }
    }
  }
}

fi=[]
fa=[]

for ind in jobs_indices:
    scroll = scan(es, query=ss, index=ind, scroll='10s')
    for res in scroll:
        r = res['fields']
        if r['transformation'][0] == 'Sim_tf.py' and int(r['cpuconsumptiontime'][0]) > 0 :            
            print(r)
            print (r['nevents'][0])
            print (r['cpuconsumptiontime'][0])
            fi.append(float(r['cpuconsumptiontime'][0])/float(r['nevents'][0]))

#for ind in jobs_indices:
#    res= es.search( index=ind, body=ss, analyze_wildcard=True)
#    print (res)

print (len(fi))

plt.hist([fi],bins=30, log=True, alpha=0.5, stacked=False, label=['cputime per event'])
plt.legend(loc='upper right')
plt.show()
# Out:
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [13815], 'pandaid': [2816602187], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31637504']}
# 1000
# 135
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [13990], 'pandaid': [2816593853], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31666176']}
# 1000
# 132
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [14052], 'pandaid': [2816595575], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31686656']}
# 1000
# 135
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [13439], 'pandaid': [2816580793], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31428608']}
# 1000
# 132
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14359], 'pandaid': [2816572321], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31940608']}
# 1000
# 136
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [13697], 'pandaid': [2816850157], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31707136']}
# 1000
# 132
# {'cpuconsumptiontime': [141], 'transformation': ['Sim_tf.py'], 'wall_time': [14421], 'pandaid': [2816828722], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31981568']}
# 1000
# 141
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [13936], 'pandaid': [2816850154], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31719424']}
# 1000
# 137
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [14361], 'pandaid': [2816838721], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31985664']}
# 1000
# 133
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [13625], 'pandaid': [2816838775], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31682560']}
# 1000
# 137
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [13937], 'pandaid': [2816854769], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31698944']}
# 1000
# 139
# {'cpuconsumptiontime': [138], 'transformation': ['Sim_tf.py'], 'wall_time': [14798], 'pandaid': [2816826279], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32342016']}
# 1000
# 138
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [14179], 'pandaid': [2816845851], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32075776']}
# 1000
# 137
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [13811], 'pandaid': [2816854697], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31698944']}
# 1000
# 137
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14242], 'pandaid': [2816838781], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31977472']}
# 1000
# 136
# {'cpuconsumptiontime': [129], 'transformation': ['Sim_tf.py'], 'wall_time': [13748], 'pandaid': [2816584125], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31678464']}
# 1000
# 129
# {'cpuconsumptiontime': [134], 'transformation': ['Sim_tf.py'], 'wall_time': [13442], 'pandaid': [2816600925], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31408128']}
# 1000
# 134
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [14310], 'pandaid': [2816583870], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31920128']}
# 1000
# 133
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [14051], 'pandaid': [2816606895], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31707136']}
# 1000
# 133
# {'cpuconsumptiontime': [126], 'transformation': ['Sim_tf.py'], 'wall_time': [13863], 'pandaid': [2816605635], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31838208']}
# 1000
# 126
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [13686], 'pandaid': [2816607150], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31739904']}
# 1000
# 132
# {'cpuconsumptiontime': [134], 'transformation': ['Sim_tf.py'], 'wall_time': [14174], 'pandaid': [2816648292], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31674368']}
# 1000
# 134
# {'cpuconsumptiontime': [131], 'transformation': ['Sim_tf.py'], 'wall_time': [14111], 'pandaid': [2816644527], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31985664']}
# 1000
# 131
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [13576], 'pandaid': [2816671804], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31739904']}
# 1000
# 133
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [13500], 'pandaid': [2816661053], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31678464']}
# 1000
# 139
# {'cpuconsumptiontime': [124], 'transformation': ['Sim_tf.py'], 'wall_time': [13195], 'pandaid': [2816636399], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31490048']}
# 1000
# 124
# {'cpuconsumptiontime': [131], 'transformation': ['Sim_tf.py'], 'wall_time': [14362], 'pandaid': [2816595662], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32006144']}
# 1000
# 131
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [14423], 'pandaid': [2816594076], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31977472']}
# 1000
# 130
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [14669], 'pandaid': [2816593878], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31989760']}
# 1000
# 140
# {'cpuconsumptiontime': [148], 'transformation': ['Sim_tf.py'], 'wall_time': [14431], 'pandaid': [2816608070], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31973376']}
# 1000
# 148
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [14237], 'pandaid': [2816656420], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32116736']}
# 1000
# 140
# {'cpuconsumptiontime': [128], 'transformation': ['Sim_tf.py'], 'wall_time': [13809], 'pandaid': [2816661411], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31735808']}
# 1000
# 128
# {'cpuconsumptiontime': [124], 'transformation': ['Sim_tf.py'], 'wall_time': [14174], 'pandaid': [2816600600], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31981568']}
# 1000
# 124
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [14055], 'pandaid': [2816600918], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31748096']}
# 1000
# 130
# {'cpuconsumptiontime': [134], 'transformation': ['Sim_tf.py'], 'wall_time': [14543], 'pandaid': [2816769172], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32169984']}
# 1000
# 134
# {'cpuconsumptiontime': [125], 'transformation': ['Sim_tf.py'], 'wall_time': [14419], 'pandaid': [2816661566], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32051200']}
# 1000
# 125
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [13810], 'pandaid': [2816659136], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31698944']}
# 1000
# 137
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [13929], 'pandaid': [2816660076], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31698944']}
# 1000
# 136
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [13623], 'pandaid': [2816637557], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31678464']}
# 1000
# 137
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14417], 'pandaid': [2816644189], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31952896']}
# 1000
# 136
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [13745], 'pandaid': [2816656389], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31698944']}
# 1000
# 130
# {'cpuconsumptiontime': [134], 'transformation': ['Sim_tf.py'], 'wall_time': [13814], 'pandaid': [2816656834], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31698944']}
# 1000
# 134
# {'cpuconsumptiontime': [145], 'transformation': ['Sim_tf.py'], 'wall_time': [14363], 'pandaid': [2816773617], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32022528']}
# 1000
# 145
# {'cpuconsumptiontime': [150], 'transformation': ['Sim_tf.py'], 'wall_time': [14544], 'pandaid': [2816741020], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31977472']}
# 1000
# 150
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [14183], 'pandaid': [2816768562], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31961088']}
# 1000
# 140
# {'cpuconsumptiontime': [134], 'transformation': ['Sim_tf.py'], 'wall_time': [13630], 'pandaid': [2816781665], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31666176']}
# 1000
# 134
# {'cpuconsumptiontime': [138], 'transformation': ['Sim_tf.py'], 'wall_time': [14483], 'pandaid': [2816656607], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31977472']}
# 1000
# 138
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [14051], 'pandaid': [2816653727], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31707136']}
# 1000
# 130
# {'cpuconsumptiontime': [124], 'transformation': ['Sim_tf.py'], 'wall_time': [13992], 'pandaid': [2816656360], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31744000']}
# 1000
# 124
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [14069], 'pandaid': [2816764733], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31653888']}
# 1000
# 135
# {'cpuconsumptiontime': [134], 'transformation': ['Sim_tf.py'], 'wall_time': [13810], 'pandaid': [2816768707], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31744000']}
# 1000
# 134
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [14053], 'pandaid': [2816750504], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31707136']}
# 1000
# 139
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [13563], 'pandaid': [2816660241], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=701075545 scout=outDiskCount']}
# 1000
# 136
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [13950], 'pandaid': [2816789350], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31698944']}
# 1000
# 140
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [14237], 'pandaid': [2816789244], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31916032']}
# 1000
# 139
# {'cpuconsumptiontime': [144], 'transformation': ['Sim_tf.py'], 'wall_time': [14115], 'pandaid': [2816791534], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31965184']}
# 1000
# 144
# {'cpuconsumptiontime': [134], 'transformation': ['Sim_tf.py'], 'wall_time': [14239], 'pandaid': [2816778479], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31895552']}
# 1000
# 134
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14419], 'pandaid': [2816740923], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31969280']}
# 1000
# 136
# {'cpuconsumptiontime': [138], 'transformation': ['Sim_tf.py'], 'wall_time': [13750], 'pandaid': [2816807090], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31670272']}
# 1000
# 138
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [13809], 'pandaid': [2816814353], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31801344']}
# 1000
# 130
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [14177], 'pandaid': [2816811763], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31969280']}
# 1000
# 132
# {'cpuconsumptiontime': [131], 'transformation': ['Sim_tf.py'], 'wall_time': [13625], 'pandaid': [2816797000], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31694848']}
# 1000
# 131
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [14362], 'pandaid': [2816791407], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31977472']}
# 1000
# 133
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [14200], 'pandaid': [2816819811], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31969280']}
# 1000
# 137
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [13623], 'pandaid': [2816819549], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31645696']}
# 1000
# 133
# {'cpuconsumptiontime': [138], 'transformation': ['Sim_tf.py'], 'wall_time': [14237], 'pandaid': [2816766864], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32006144']}
# 1000
# 138
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [14361], 'pandaid': [2816809055], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32022528']}
# 1000
# 135
# {'cpuconsumptiontime': [147], 'transformation': ['Sim_tf.py'], 'wall_time': [13871], 'pandaid': [2816826041], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31760384']}
# 1000
# 147
# {'cpuconsumptiontime': [127], 'transformation': ['Sim_tf.py'], 'wall_time': [13695], 'pandaid': [2816825958], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31703040']}
# 1000
# 127
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [13868], 'pandaid': [2816796926], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31703040']}
# 1000
# 137
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [13852], 'pandaid': [2816791578], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31744000']}
# 1000
# 139
# {'cpuconsumptiontime': [141], 'transformation': ['Sim_tf.py'], 'wall_time': [13827], 'pandaid': [2816781753], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31707136']}
# 1000
# 141
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [14479], 'pandaid': [2816803012], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31948800']}
# 1000
# 132
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14197], 'pandaid': [2816783658], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31948800']}
# 1000
# 136
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [14300], 'pandaid': [2816814597], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31989760']}
# 1000
# 139
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [13688], 'pandaid': [2816781010], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31678464']}
# 1000
# 136
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [13938], 'pandaid': [2816762081], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31731712']}
# 1000
# 132
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [14495], 'pandaid': [2816761861], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32096256']}
# 1000
# 137
# {'cpuconsumptiontime': [138], 'transformation': ['Sim_tf.py'], 'wall_time': [13893], 'pandaid': [2816797689], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31678464']}
# 1000
# 138
# {'cpuconsumptiontime': [126], 'transformation': ['Sim_tf.py'], 'wall_time': [13439], 'pandaid': [2816600873], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31383552']}
# 1000
# 126
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [13623], 'pandaid': [2816595616], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31686656']}
# 1000
# 135
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [14789], 'pandaid': [2816760097], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32227328']}
# 1000
# 140
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [14119], 'pandaid': [2816764885], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31944704']}
# 1000
# 140
# {'cpuconsumptiontime': [145], 'transformation': ['Sim_tf.py'], 'wall_time': [14118], 'pandaid': [2816775454], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31965184']}
# 1000
# 145
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [14424], 'pandaid': [2816772310], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31961088']}
# 1000
# 140
# {'cpuconsumptiontime': [138], 'transformation': ['Sim_tf.py'], 'wall_time': [13932], 'pandaid': [2816797145], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31756288']}
# 1000
# 138
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [13930], 'pandaid': [2816811865], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31641600']}
# 1000
# 133
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [13870], 'pandaid': [2816831904], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31657984']}
# 1000
# 136
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [14664], 'pandaid': [2816850259], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32006144']}
# 1000
# 137
# {'cpuconsumptiontime': [138], 'transformation': ['Sim_tf.py'], 'wall_time': [13504], 'pandaid': [2816831984], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31723520']}
# 1000
# 138
# {'cpuconsumptiontime': [143], 'transformation': ['Sim_tf.py'], 'wall_time': [13747], 'pandaid': [2816852261], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31703040']}
# 1000
# 143
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [13805], 'pandaid': [2816854429], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31694848']}
# 1000
# 140
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [14304], 'pandaid': [2816854910], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31985664']}
# 1000
# 132
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [13991], 'pandaid': [2816825687], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31690752']}
# 1000
# 133
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [13809], 'pandaid': [2816840935], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31789056']}
# 1000
# 132
# {'cpuconsumptiontime': [124], 'transformation': ['Sim_tf.py'], 'wall_time': [14357], 'pandaid': [2816836999], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31961088']}
# 1000
# 124
# {'cpuconsumptiontime': [125], 'transformation': ['Sim_tf.py'], 'wall_time': [14607], 'pandaid': [2816788871], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32063488']}
# 1000
# 125
# {'cpuconsumptiontime': [129], 'transformation': ['Sim_tf.py'], 'wall_time': [13560], 'pandaid': [2816821359], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31707136']}
# 1000
# 129
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [13807], 'pandaid': [2816855448], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31698944']}
# 1000
# 135
# {'cpuconsumptiontime': [142], 'transformation': ['Sim_tf.py'], 'wall_time': [13875], 'pandaid': [2816814496], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31719424']}
# 1000
# 142
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [13747], 'pandaid': [2816825382], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31707136']}
# 1000
# 135
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [14488], 'pandaid': [2816809233], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31977472']}
# 1000
# 133
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [14423], 'pandaid': [2816811529], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31920128']}
# 1000
# 137
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [14421], 'pandaid': [2816806782], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32051200']}
# 1000
# 139
# {'cpuconsumptiontime': [145], 'transformation': ['Sim_tf.py'], 'wall_time': [13628], 'pandaid': [2816785415], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31694848']}
# 1000
# 145
# {'cpuconsumptiontime': [147], 'transformation': ['Sim_tf.py'], 'wall_time': [14482], 'pandaid': [2816981778], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31993856']}
# 1000
# 147
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [13807], 'pandaid': [2816602087], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31674368']}
# 1000
# 139
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [13685], 'pandaid': [2816614054], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31633408']}
# 1000
# 136
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [14239], 'pandaid': [2816613389], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31916032']}
# 1000
# 135
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [14420], 'pandaid': [2816697230], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31989760']}
# 1000
# 135
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [13627], 'pandaid': [2816593863], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31674368']}
# 1000
# 132
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [14601], 'pandaid': [2816626281], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32030720']}
# 1000
# 133
# {'cpuconsumptiontime': [129], 'transformation': ['Sim_tf.py'], 'wall_time': [13439], 'pandaid': [2816631653], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31444992']}
# 1000
# 129
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [13687], 'pandaid': [2816734778], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31617024']}
# 1000
# 135
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14247], 'pandaid': [2816599323], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31973376']}
# 1000
# 136
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [13626], 'pandaid': [2816595683], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31707136']}
# 1000
# 130
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [13438], 'pandaid': [2816606415], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31404032']}
# 1000
# 130
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [13989], 'pandaid': [2816719060], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31707136']}
# 1000
# 137
# {'cpuconsumptiontime': [143], 'transformation': ['Sim_tf.py'], 'wall_time': [14662], 'pandaid': [2816709310], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31993856']}
# 1000
# 143
# {'cpuconsumptiontime': [138], 'transformation': ['Sim_tf.py'], 'wall_time': [14439], 'pandaid': [2816725120], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31956992']}
# 1000
# 138
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [13938], 'pandaid': [2816719379], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31711232']}
# 1000
# 139
# {'cpuconsumptiontime': [146], 'transformation': ['Sim_tf.py'], 'wall_time': [14185], 'pandaid': [2816730147], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31944704']}
# 1000
# 146
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [13686], 'pandaid': [2816733630], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31666176']}
# 1000
# 135
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [14124], 'pandaid': [2816719165], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31944704']}
# 1000
# 130
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [14542], 'pandaid': [2816706756], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32014336']}
# 1000
# 135
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [13992], 'pandaid': [2816715599], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31637504']}
# 1000
# 137
# {'cpuconsumptiontime': [143], 'transformation': ['Sim_tf.py'], 'wall_time': [14735], 'pandaid': [2816730143], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32223232']}
# 1000
# 143
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [14604], 'pandaid': [2816702066], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32063488']}
# 1000
# 133
# {'cpuconsumptiontime': [131], 'transformation': ['Sim_tf.py'], 'wall_time': [13749], 'pandaid': [2816599202], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31698944']}
# 1000
# 131
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [13568], 'pandaid': [2816705286], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31662080']}
# 1000
# 135
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [14487], 'pandaid': [2816669244], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32018432']}
# 1000
# 137
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [14178], 'pandaid': [2816606929], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31969280']}
# 1000
# 133
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [13623], 'pandaid': [2816668511], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31707136']}
# 1000
# 133
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [13994], 'pandaid': [2816645568], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31686656']}
# 1000
# 130
# {'cpuconsumptiontime': [129], 'transformation': ['Sim_tf.py'], 'wall_time': [13444], 'pandaid': [2816657064], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31428608']}
# 1000
# 129
# {'cpuconsumptiontime': [126], 'transformation': ['Sim_tf.py'], 'wall_time': [14595], 'pandaid': [2816641499], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31911936']}
# 1000
# 126
# {'cpuconsumptiontime': [144], 'transformation': ['Sim_tf.py'], 'wall_time': [13932], 'pandaid': [2816656522], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31649792']}
# 1000
# 144
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [14793], 'pandaid': [2816648404], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32235520']}
# 1000
# 139
# {'cpuconsumptiontime': [131], 'transformation': ['Sim_tf.py'], 'wall_time': [13990], 'pandaid': [2816644302], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31694848']}
# 1000
# 131
# {'cpuconsumptiontime': [134], 'transformation': ['Sim_tf.py'], 'wall_time': [13573], 'pandaid': [2816667238], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31682560']}
# 1000
# 134
# {'cpuconsumptiontime': [127], 'transformation': ['Sim_tf.py'], 'wall_time': [14426], 'pandaid': [2816688056], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31895552']}
# 1000
# 127
# {'cpuconsumptiontime': [147], 'transformation': ['Sim_tf.py'], 'wall_time': [13995], 'pandaid': [2816685665], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31703040']}
# 1000
# 147
# {'cpuconsumptiontime': [131], 'transformation': ['Sim_tf.py'], 'wall_time': [14053], 'pandaid': [2816674335], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31703040']}
# 1000
# 131
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [13870], 'pandaid': [2816606979], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31649792']}
# 1000
# 136
# {'cpuconsumptiontime': [128], 'transformation': ['Sim_tf.py'], 'wall_time': [14545], 'pandaid': [2816580873], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31985664']}
# 1000
# 128
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14241], 'pandaid': [2816608047], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31916032 scout=outDiskCount']}
# 1000
# 136
# {'cpuconsumptiontime': [141], 'transformation': ['Sim_tf.py'], 'wall_time': [13717], 'pandaid': [2816775516], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31768576']}
# 1000
# 141
# {'cpuconsumptiontime': [131], 'transformation': ['Sim_tf.py'], 'wall_time': [14548], 'pandaid': [2816752091], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31965184']}
# 1000
# 131
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [14051], 'pandaid': [2816684551], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31682560']}
# 1000
# 140
# {'cpuconsumptiontime': [129], 'transformation': ['Sim_tf.py'], 'wall_time': [14852], 'pandaid': [2816674281], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32464896']}
# 1000
# 129
# {'cpuconsumptiontime': [134], 'transformation': ['Sim_tf.py'], 'wall_time': [13993], 'pandaid': [2816701011], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31711232']}
# 1000
# 134
# {'cpuconsumptiontime': [141], 'transformation': ['Sim_tf.py'], 'wall_time': [13750], 'pandaid': [2816764731], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31649792']}
# 1000
# 141
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [14550], 'pandaid': [2816765037], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32038912']}
# 1000
# 135
# {'cpuconsumptiontime': [138], 'transformation': ['Sim_tf.py'], 'wall_time': [14420], 'pandaid': [2816741024], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31961088']}
# 1000
# 138
# {'cpuconsumptiontime': [141], 'transformation': ['Sim_tf.py'], 'wall_time': [14244], 'pandaid': [2816749332], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31952896']}
# 1000
# 141
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14058], 'pandaid': [2816764838], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31711232']}
# 1000
# 136
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14420], 'pandaid': [2816773602], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31916032']}
# 1000
# 136
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [13991], 'pandaid': [2816773314], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31682560']}
# 1000
# 133
# {'cpuconsumptiontime': [138], 'transformation': ['Sim_tf.py'], 'wall_time': [13623], 'pandaid': [2816682166], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31686656']}
# 1000
# 138
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [13563], 'pandaid': [2816783766], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31633408']}
# 1000
# 133
# {'cpuconsumptiontime': [143], 'transformation': ['Sim_tf.py'], 'wall_time': [14799], 'pandaid': [2816768524], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32260096']}
# 1000
# 143
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [14181], 'pandaid': [2816764870], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31961088']}
# 1000
# 137
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [14666], 'pandaid': [2816753030], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32014336']}
# 1000
# 133
# {'cpuconsumptiontime': [141], 'transformation': ['Sim_tf.py'], 'wall_time': [13629], 'pandaid': [2816752310], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31686656']}
# 1000
# 141
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14481], 'pandaid': [2816750642], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31993856']}
# 1000
# 136
# {'cpuconsumptiontime': [134], 'transformation': ['Sim_tf.py'], 'wall_time': [14116], 'pandaid': [2816753456], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32014336']}
# 1000
# 134
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [14545], 'pandaid': [2816766415], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32002048']}
# 1000
# 130
# {'cpuconsumptiontime': [143], 'transformation': ['Sim_tf.py'], 'wall_time': [13629], 'pandaid': [2816775466], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31657984']}
# 1000
# 143
# {'cpuconsumptiontime': [141], 'transformation': ['Sim_tf.py'], 'wall_time': [14174], 'pandaid': [2816766800], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31932416']}
# 1000
# 141
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [14297], 'pandaid': [2816779891], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31920128']}
# 1000
# 140
# {'cpuconsumptiontime': [144], 'transformation': ['Sim_tf.py'], 'wall_time': [14418], 'pandaid': [2816763035], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32034816']}
# 1000
# 144
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [14481], 'pandaid': [2816752946], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31977472']}
# 1000
# 132
# {'cpuconsumptiontime': [146], 'transformation': ['Sim_tf.py'], 'wall_time': [14178], 'pandaid': [2816775422], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31936512']}
# 1000
# 146
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [14115], 'pandaid': [2816738546], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32043008']}
# 1000
# 140
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [13759], 'pandaid': [2816732638], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31690752']}
# 1000
# 136
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [13573], 'pandaid': [2816727224], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31686656']}
# 1000
# 132
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [13504], 'pandaid': [2816784005], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31735808']}
# 1000
# 136
# {'cpuconsumptiontime': [141], 'transformation': ['Sim_tf.py'], 'wall_time': [14541], 'pandaid': [2816761611], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32018432']}
# 1000
# 141
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [13628], 'pandaid': [2816778979], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31711232']}
# 1000
# 136
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [13932], 'pandaid': [2816745299], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31653888']}
# 1000
# 139
# {'cpuconsumptiontime': [142], 'transformation': ['Sim_tf.py'], 'wall_time': [14245], 'pandaid': [2816749252], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31956992']}
# 1000
# 142
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [13749], 'pandaid': [2816778408], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31735808']}
# 1000
# 137
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [14054], 'pandaid': [2816729838], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31723520']}
# 1000
# 135
# {'cpuconsumptiontime': [141], 'transformation': ['Sim_tf.py'], 'wall_time': [13874], 'pandaid': [2816743056], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31686656']}
# 1000
# 141
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [13575], 'pandaid': [2816713154], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31612928']}
# 1000
# 130
# {'cpuconsumptiontime': [149], 'transformation': ['Sim_tf.py'], 'wall_time': [13935], 'pandaid': [2816725267], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31645696']}
# 1000
# 149
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [14179], 'pandaid': [2816701323], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31924224']}
# 1000
# 132
# {'cpuconsumptiontime': [129], 'transformation': ['Sim_tf.py'], 'wall_time': [13816], 'pandaid': [2816714377], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31678464']}
# 1000
# 129
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [13936], 'pandaid': [2816729895], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31895552']}
# 1000
# 133
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [13937], 'pandaid': [2816688665], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31678464']}
# 1000
# 140
# {'cpuconsumptiontime': [129], 'transformation': ['Sim_tf.py'], 'wall_time': [14170], 'pandaid': [2816674328], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32022528']}
# 1000
# 129
# {'cpuconsumptiontime': [134], 'transformation': ['Sim_tf.py'], 'wall_time': [13499], 'pandaid': [2816690030], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31719424']}
# 1000
# 134
# {'cpuconsumptiontime': [131], 'transformation': ['Sim_tf.py'], 'wall_time': [14197], 'pandaid': [2816685435], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31965184']}
# 1000
# 131
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [14240], 'pandaid': [2816688648], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31891456']}
# 1000
# 132
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [13868], 'pandaid': [2816701297], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31723520']}
# 1000
# 137
# {'cpuconsumptiontime': [143], 'transformation': ['Sim_tf.py'], 'wall_time': [13747], 'pandaid': [2816697820], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31686656']}
# 1000
# 143
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [13996], 'pandaid': [2816697294], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31703040']}
# 1000
# 135
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [13691], 'pandaid': [2816729850], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31674368']}
# 1000
# 132
# {'cpuconsumptiontime': [142], 'transformation': ['Sim_tf.py'], 'wall_time': [13813], 'pandaid': [2816737807], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31711232']}
# 1000
# 142
# {'cpuconsumptiontime': [143], 'transformation': ['Sim_tf.py'], 'wall_time': [14239], 'pandaid': [2816729907], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32014336']}
# 1000
# 143
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14058], 'pandaid': [2816685551], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31666176']}
# 1000
# 136
# {'cpuconsumptiontime': [138], 'transformation': ['Sim_tf.py'], 'wall_time': [14180], 'pandaid': [2816704218], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32108544']}
# 1000
# 138
# {'cpuconsumptiontime': [143], 'transformation': ['Sim_tf.py'], 'wall_time': [14481], 'pandaid': [2816734921], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32010240']}
# 1000
# 143
# {'cpuconsumptiontime': [144], 'transformation': ['Sim_tf.py'], 'wall_time': [14359], 'pandaid': [2816737791], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31961088']}
# 1000
# 144
# {'cpuconsumptiontime': [141], 'transformation': ['Sim_tf.py'], 'wall_time': [14429], 'pandaid': [2816727610], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31969280']}
# 1000
# 141
# {'cpuconsumptiontime': [142], 'transformation': ['Sim_tf.py'], 'wall_time': [14361], 'pandaid': [2816771923], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31981568']}
# 1000
# 142
# {'cpuconsumptiontime': [143], 'transformation': ['Sim_tf.py'], 'wall_time': [13931], 'pandaid': [2816773169], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31670272']}
# 1000
# 143
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [13628], 'pandaid': [2816729784], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31703040']}
# 1000
# 135
# {'cpuconsumptiontime': [141], 'transformation': ['Sim_tf.py'], 'wall_time': [13933], 'pandaid': [2816732676], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31711232']}
# 1000
# 141
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14795], 'pandaid': [2816700406], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32292864']}
# 1000
# 136
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14605], 'pandaid': [2816719174], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32002048']}
# 1000
# 136
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [13823], 'pandaid': [2816808940], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31666176']}
# 1000
# 139
# {'cpuconsumptiontime': [135], 'transformation': ['Sim_tf.py'], 'wall_time': [13731], 'pandaid': [2816811602], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31756288']}
# 1000
# 135
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14063], 'pandaid': [2816932211], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31584256']}
# 1000
# 136
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [13871], 'pandaid': [2816791569], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31850496']}
# 1000
# 137
# {'cpuconsumptiontime': [143], 'transformation': ['Sim_tf.py'], 'wall_time': [13931], 'pandaid': [2816797618], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31727616']}
# 1000
# 143
# {'cpuconsumptiontime': [136], 'transformation': ['Sim_tf.py'], 'wall_time': [14298], 'pandaid': [2816791284], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31969280']}
# 1000
# 136
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [13930], 'pandaid': [2816785032], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31711232']}
# 1000
# 137
# {'cpuconsumptiontime': [139], 'transformation': ['Sim_tf.py'], 'wall_time': [14361], 'pandaid': [2816791519], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31969280']}
# 1000
# 139
# {'cpuconsumptiontime': [132], 'transformation': ['Sim_tf.py'], 'wall_time': [14426], 'pandaid': [2816785870], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31965184']}
# 1000
# 132
# ...
# 1000
# 178
# {'cpuconsumptiontime': [155], 'transformation': ['Sim_tf.py'], 'wall_time': [20908], 'pandaid': [2826277939], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=34406400']}
# 1000
# 155
# {'cpuconsumptiontime': [128], 'transformation': ['Sim_tf.py'], 'wall_time': [14368], 'pandaid': [2826323812], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31387648']}
# 1000
# 128
# {'cpuconsumptiontime': [152], 'transformation': ['Sim_tf.py'], 'wall_time': [21135], 'pandaid': [2826301410], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=34279424']}
# 1000
# 152
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [14363], 'pandaid': [2826367951], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31408128']}
# 1000
# 130
# {'cpuconsumptiontime': [144], 'transformation': ['Sim_tf.py'], 'wall_time': [13928], 'pandaid': [2826355633], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31150080']}
# 1000
# 144
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [14731], 'pandaid': [2826285213], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31711232']}
# 1000
# 137
# {'cpuconsumptiontime': [219], 'transformation': ['Sim_tf.py'], 'wall_time': [30499], 'pandaid': [2826300339], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=38457344']}
# 1000
# 219
# {'cpuconsumptiontime': [208], 'transformation': ['Sim_tf.py'], 'wall_time': [31630], 'pandaid': [2826339530], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=38944768']}
# 1000
# 208
# {'cpuconsumptiontime': [228], 'transformation': ['Sim_tf.py'], 'wall_time': [32707], 'pandaid': [2826275263], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=39514112']}
# 1000
# 228
# {'cpuconsumptiontime': [232], 'transformation': ['Sim_tf.py'], 'wall_time': [31508], 'pandaid': [2826308905], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=38977536']}
# 1000
# 232
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [13622], 'pandaid': [2826611175], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31129600']}
# 1000
# 130
# {'cpuconsumptiontime': [211], 'transformation': ['Sim_tf.py'], 'wall_time': [30694], 'pandaid': [2826304997], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=38453248']}
# 1000
# 211
# {'cpuconsumptiontime': [201], 'transformation': ['Sim_tf.py'], 'wall_time': [27811], 'pandaid': [2826394016], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=37314560']}
# 1000
# 201
# {'cpuconsumptiontime': [233], 'transformation': ['Sim_tf.py'], 'wall_time': [30458], 'pandaid': [2826353643], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=38395904']}
# 1000
# 233
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [14556], 'pandaid': [2826281213], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31412224']}
# 1000
# 130
# {'cpuconsumptiontime': [137], 'transformation': ['Sim_tf.py'], 'wall_time': [14436], 'pandaid': [2826297796], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31416320']}
# 1000
# 137
# {'cpuconsumptiontime': [211], 'transformation': ['Sim_tf.py'], 'wall_time': [24871], 'pandaid': [2826468956], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=32985088']}
# 1000
# 211
# {'cpuconsumptiontime': [144], 'transformation': ['Sim_tf.py'], 'wall_time': [13865], 'pandaid': [2826431947], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31125504']}
# 1000
# 144
# {'cpuconsumptiontime': [149], 'transformation': ['Sim_tf.py'], 'wall_time': [20771], 'pandaid': [2826312003], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=34140160']}
# 1000
# 149
# {'cpuconsumptiontime': [210], 'transformation': ['Sim_tf.py'], 'wall_time': [23241], 'pandaid': [2826277876], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=35246080']}
# 1000
# 210
# {'cpuconsumptiontime': [215], 'transformation': ['Sim_tf.py'], 'wall_time': [21828], 'pandaid': [2826285260], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=34676736']}
# 1000
# 215
# {'cpuconsumptiontime': [163], 'transformation': ['Sim_tf.py'], 'wall_time': [20505], 'pandaid': [2826311780], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=34107392']}
# 1000
# 163
# {'cpuconsumptiontime': [268], 'transformation': ['Sim_tf.py'], 'wall_time': [41041], 'pandaid': [2825468568], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=38883328']}
# 1000
# 268
# {'cpuconsumptiontime': [253], 'transformation': ['Sim_tf.py'], 'wall_time': [38818], 'pandaid': [2825469028], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=37953536']}
# 1000
# 253
# {'cpuconsumptiontime': [133], 'transformation': ['Sim_tf.py'], 'wall_time': [14542], 'pandaid': [2826297913], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31334400']}
# 1000
# 133
# {'cpuconsumptiontime': [255], 'transformation': ['Sim_tf.py'], 'wall_time': [40969], 'pandaid': [2825814449], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=38748160']}
# 1000
# 255
# {'cpuconsumptiontime': [185], 'transformation': ['Sim_tf.py'], 'wall_time': [26821], 'pandaid': [2826324214], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=36737024']}
# 1000
# 185
# {'cpuconsumptiontime': [224], 'transformation': ['Sim_tf.py'], 'wall_time': [28957], 'pandaid': [2826309101], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=37892096']}
# 1000
# 224
# {'cpuconsumptiontime': [196], 'transformation': ['Sim_tf.py'], 'wall_time': [25406], 'pandaid': [2826345230], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=36220928']}
# 1000
# 196
# {'cpuconsumptiontime': [155], 'transformation': ['Sim_tf.py'], 'wall_time': [20954], 'pandaid': [2826455188], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=34373632']}
# 1000
# 155
# {'cpuconsumptiontime': [146], 'transformation': ['Sim_tf.py'], 'wall_time': [21412], 'pandaid': [2826412231], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=34279424']}
# 1000
# 146
# {'cpuconsumptiontime': [159], 'transformation': ['Sim_tf.py'], 'wall_time': [15492], 'pandaid': [2826388855], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31858688']}
# 1000
# 159
# {'cpuconsumptiontime': [212], 'transformation': ['Sim_tf.py'], 'wall_time': [21026], 'pandaid': [2826348222], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=34312192']}
# 1000
# 212
# {'cpuconsumptiontime': [165], 'transformation': ['Sim_tf.py'], 'wall_time': [20255], 'pandaid': [2826393723], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=34045952']}
# 1000
# 165
# {'cpuconsumptiontime': [155], 'transformation': ['Sim_tf.py'], 'wall_time': [21304], 'pandaid': [2826442722], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=34381824']}
# 1000
# 155
# {'cpuconsumptiontime': [212], 'transformation': ['Sim_tf.py'], 'wall_time': [25162], 'pandaid': [2826675961], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=35880960']}
# 1000
# 212
# {'cpuconsumptiontime': [268], 'transformation': ['Sim_tf.py'], 'wall_time': [54005], 'pandaid': [2826281310], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=48660480']}
# 1000
# 268
# {'cpuconsumptiontime': [148], 'transformation': ['Sim_tf.py'], 'wall_time': [31078], 'pandaid': [2826574590], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=38723584']}
# 1000
# 148
# {'cpuconsumptiontime': [338], 'transformation': ['Sim_tf.py'], 'wall_time': [53504], 'pandaid': [2826278142], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=48439296']}
# 1000
# 338
# {'cpuconsumptiontime': [227], 'transformation': ['Sim_tf.py'], 'wall_time': [36140], 'pandaid': [2826534243], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=40812544']}
# 1000
# 227
# {'cpuconsumptiontime': [244], 'transformation': ['Sim_tf.py'], 'wall_time': [32909], 'pandaid': [2826779594], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=39407616']}
# 1000
# 244
# {'cpuconsumptiontime': [417], 'transformation': ['Sim_tf.py'], 'wall_time': [54494], 'pandaid': [2826435414], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=48922624']}
# 1000
# 417
# {'cpuconsumptiontime': [318], 'transformation': ['Sim_tf.py'], 'wall_time': [54290], 'pandaid': [2826401347], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=48717824']}
# 1000
# 318
# {'cpuconsumptiontime': [266], 'transformation': ['Sim_tf.py'], 'wall_time': [51456], 'pandaid': [2826345407], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=47681536']}
# 1000
# 266
# {'cpuconsumptiontime': [191], 'transformation': ['Sim_tf.py'], 'wall_time': [28120], 'pandaid': [2826741182], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=37449728']}
# 1000
# 191
# {'cpuconsumptiontime': [228], 'transformation': ['Sim_tf.py'], 'wall_time': [25923], 'pandaid': [2826657577], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=36528128']}
# 1000
# 228
# {'cpuconsumptiontime': [336], 'transformation': ['Sim_tf.py'], 'wall_time': [50780], 'pandaid': [2826281257], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=47325184']}
# 1000
# 336
# {'cpuconsumptiontime': [336], 'transformation': ['Sim_tf.py'], 'wall_time': [49315], 'pandaid': [2826277975], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=46538752']}
# 1000
# 336
# {'cpuconsumptiontime': [377], 'transformation': ['Sim_tf.py'], 'wall_time': [57136], 'pandaid': [2826281216], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=50032640']}
# 1000
# 377
# {'cpuconsumptiontime': [292], 'transformation': ['Sim_tf.py'], 'wall_time': [50472], 'pandaid': [2826435653], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=47099904']}
# 1000
# 292
# {'cpuconsumptiontime': [238], 'transformation': ['Sim_tf.py'], 'wall_time': [34485], 'pandaid': [2826657657], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=40099840']}
# 1000
# 238
# {'cpuconsumptiontime': [254], 'transformation': ['Sim_tf.py'], 'wall_time': [38878], 'pandaid': [2827270863], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=37998592']}
# 1000
# 254
# {'cpuconsumptiontime': [294], 'transformation': ['Sim_tf.py'], 'wall_time': [27269], 'pandaid': [2826666719], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=37015552']}
# 1000
# 294
# {'cpuconsumptiontime': [232], 'transformation': ['Sim_tf.py'], 'wall_time': [27517], 'pandaid': [2826609844], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=37007360']}
# 1000
# 232
# {'cpuconsumptiontime': [140], 'transformation': ['Sim_tf.py'], 'wall_time': [30562], 'pandaid': [2826690024], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=38539264']}
# 1000
# 140
# {'cpuconsumptiontime': [151], 'transformation': ['Sim_tf.py'], 'wall_time': [21785], 'pandaid': [2826833112], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=34676736']}
# 1000
# 151
# {'cpuconsumptiontime': [239], 'transformation': ['Sim_tf.py'], 'wall_time': [35814], 'pandaid': [2826602457], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=40886272']}
# 1000
# 239
# {'cpuconsumptiontime': [376], 'transformation': ['Sim_tf.py'], 'wall_time': [56996], 'pandaid': [2826281929], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=49987584']}
# 1000
# 376
# {'cpuconsumptiontime': [372], 'transformation': ['Sim_tf.py'], 'wall_time': [57701], 'pandaid': [2826292765], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=298744398']}
# 1000
# 372
# {'cpuconsumptiontime': [368], 'transformation': ['Sim_tf.py'], 'wall_time': [54364], 'pandaid': [2826301165], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=48971776']}
# 1000
# 368
# {'cpuconsumptiontime': [147], 'transformation': ['Sim_tf.py'], 'wall_time': [26546], 'pandaid': [2826721884], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=36503552']}
# 1000
# 147
# {'cpuconsumptiontime': [365], 'transformation': ['Sim_tf.py'], 'wall_time': [58802], 'pandaid': [2826278123], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=50417664']}
# 1000
# 365
# {'cpuconsumptiontime': [288], 'transformation': ['Sim_tf.py'], 'wall_time': [58995], 'pandaid': [2826281237], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=50823168']}
# 1000
# 288
# {'cpuconsumptiontime': [238], 'transformation': ['Sim_tf.py'], 'wall_time': [54576], 'pandaid': [2826281283], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=48893952']}
# 1000
# 238
# {'cpuconsumptiontime': [366], 'transformation': ['Sim_tf.py'], 'wall_time': [56182], 'pandaid': [2826285551], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=49512448']}
# 1000
# 366
# {'cpuconsumptiontime': [361], 'transformation': ['Sim_tf.py'], 'wall_time': [53773], 'pandaid': [2826281260], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=48549888']}
# 1000
# 361
# {'cpuconsumptiontime': [336], 'transformation': ['Sim_tf.py'], 'wall_time': [53316], 'pandaid': [2826278170], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=48410624']}
# 1000
# 336
# {'cpuconsumptiontime': [324], 'transformation': ['Sim_tf.py'], 'wall_time': [51958], 'pandaid': [2826550536], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=47968256']}
# 1000
# 324
# {'cpuconsumptiontime': [172], 'transformation': ['Sim_tf.py'], 'wall_time': [68358], 'pandaid': [2826277895], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=52801536']}
# 1000
# 172
# {'cpuconsumptiontime': [130], 'transformation': ['Sim_tf.py'], 'wall_time': [13864], 'pandaid': [2826712861], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=31141888']}
# 1000
# 130
# {'cpuconsumptiontime': [210], 'transformation': ['Sim_tf.py'], 'wall_time': [33043], 'pandaid': [2826439667], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=39374848']}
# 1000
# 210
# {'cpuconsumptiontime': [236], 'transformation': ['Sim_tf.py'], 'wall_time': [30693], 'pandaid': [2826442692], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=38359040']}
# 1000
# 236
# {'cpuconsumptiontime': [207], 'transformation': ['Sim_tf.py'], 'wall_time': [39029], 'pandaid': [2826281248], 'jobstatus': ['finished'], 'nevents': [1000], 'jobmetrics': ['nEvents=1000 workDirSize=42151936']}
# 1000
# 207

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from elasticsearch import Elasticsearch, exceptions as es_exceptions
from elasticsearch.helpers import scan

es = Elasticsearch(hosts=[{'host':'atlas-kibana.mwt2.org', 'port':9200}],timeout=180)

indices=es.indices.get_aliases().keys()
jobs_indices=[]
sorted_indices = sorted(indices)
for index in sorted_indices:
    if "jobs_archive_2016" in index:
        jobs_indices.append(index)
        #print(index)
ss = {
  "fields": ["nevents","wall_time","jobstatus","cpuconsumptiontime","pandaid","transformation","jobmetrics"],
  "query": {
    "filtered": {
      "filter" : {
        "range" : {
          "nevents" : { "gt" : 0 } 
          }
      },
      "query" : {
        "match" : {
          "jeditaskid" : "8848710" 
        }
      }
    }
  }
}

fi=[]
fa=[]

for ind in jobs_indices:
    scroll = scan(es, query=ss, index=ind, scroll='10s')
    for res in scroll:
        r = res['fields']
        if r['transformation'][0] == 'Sim_tf.py' and int(r['cpuconsumptiontime'][0]) > 0 :            
            #print(r)
            #print (r['nevents'][0])
            #print (r['cpuconsumptiontime'][0])
            fi.append(float(r['cpuconsumptiontime'][0])/float(r['nevents'][0]))

#for ind in jobs_indices:
#    res= es.search( index=ind, body=ss, analyze_wildcard=True)
#    print (res)

print (len(fi))

plt.hist([fi],bins=30, log=True, alpha=0.5, stacked=False, label=['cputime per event (NERSC)'])
plt.legend(loc='upper right')
plt.show()
# Out:
# 6198
