# %%
#These lines set up inline plotting, and apply a standard size
# %matplotlib inline
import matplotlib
matplotlib.rc('font', **{'size': 15})

# %% [markdown]
# Let's look at a summary of the packet loss over a 6-month period. Using a boxplot (similar to LatencySummary notebook), we can look at the packet loss distribution of each link over time to get a feel for how unstable each link's packet loss is.

# %%
import numpy as np
import matplotlib.pyplot as plt
from elasticsearch import Elasticsearch, exceptions as es_exceptions
from elasticsearch.helpers import scan

#Create instance of ElasticSearch using the Atlas host server
es = Elasticsearch(hosts=[{'host':'atlas-kibana.mwt2.org', 'port':9200}],
                   timeout=60)

# %%
linkName = ['Australia-ATLAS', 'Taiwan-LCG2', 'BEIJING-LCG2', 'SPRACE',
            'T2-TH-CUNSTDA','EELA-UTFSM', 'TOKYO-LCG2', 'CA-VICTORIA-WESTGRID-T2',
            'ITEP', 'SFU-LCG2','TRIUMF-LCG2', 'UFlorida-HPC', 'UTA_SWT2',
            'SARA-MATRIX', 'WT2', 'INDIACMS-TIFR', 'BU_ATLAS_Tier2', 'LUCILLE',
            'OU_OCHEP_SWT2', 'Nebraska', 'MWT2', 'AGLT2', 'GLOW', 'Vanderbilt',
            'CA-SCINET-T2', 'ru-PNPI', 'BNL-ATLAS', 'RRC-KI',
            'CA-MCGILL-CLUMEQ-T2', 'AM-04-YERPHI', 'CYFRONET-LCG2', 'RRC-KI-T1',
            'CSCS-LCG2', 'RU-Protvino-IHEP', 'RAL-LCG2', 'JINR-T1', 'INFN-BARI',
            'FMPhI-UNIBA', 'JINR-LCG2', 'INFN-ROMA1', 'pic', 'RO-16-UAIC', 
            'FI_HIP_T2', 'RO-07-NIPNE', 'RO-02-NIPNE', 'IFCA-LCG2', 'DESY-ZN',
            'INFN-NAPOLI-ATLAS', 'BEgrid-ULB-VUB', 'DESY-HH',
            'UKI-NORTHGRID-LANCS-HEP', 'NDGF-T1', 'INFN-T1', 'IN2P3-LPC',
            'IEPSAS-Kosice', 'IFIC-LCG2', 'UKI-SCOTGRID-GLASGOW',
            'UKI-NORTHGRID-LIV-HEP', 'BUDAPEST', 'UKI-SCOTGRID-ECDF',
            'UKI-SCOTGRID-DURHAM', 'FZK-LCG2', 'UKI-SOUTHGRID-OX-HEP',
            'UAM-LCG2', 'UKI-NORTHGRID-MAN-HEP', 'UKI-SOUTHGRID-CAM-HEP',
            'UKI-SOUTHGRID-SUSX', 'INFN-FRASCATI', 'UKI-SOUTHGRID-BHAM-HEP',
            'IN2P3-CPPM', 'UKI-LT2-QMUL', 'praguelcg2', 'UKI-SOUTHGRID-RALPP',
            'GoeGrid', 'UKI-LT2-UCL-HEP', 'GRIF', 'wuppertalprod', 'IN2P3-LAPP',
            'IN2P3-LPSC', 'INFN-MILANO-ATLASC', 'IN2P3-CC']

# %%
import ast


query = '''{
  "size": 0,
  "query": {
    "filtered": {
      "query": {
        "query_string": {
          "query": "srcSite:CERN* AND destSite:%s* AND packet_loss:>=0",
          "analyze_wildcard": True,
          "lowercase_expanded_terms": False
        }
      },
      "filter": {
        "bool": {
          "must": [
            {
              "range": {
                "timestamp": {
                  "gte": 1452689502533,
                  "lte": 1468410702533,
                  "format": "epoch_millis"
                }
              }
            }
          ],
          "must_not": []
        }
      }
    }
  },
  "aggs": {
    "2": {
      "date_histogram": {
        "field": "timestamp",
        "interval": "1h",
        "time_zone": "Europe/Berlin",
        "min_doc_count": 1,
        "extended_bounds": {
          "min": 1452689502532,
          "max": 1468410702533
        }
      },
      "aggs": {
        "1": {
          "avg": {
            "field": "packet_loss"
          }
        }
      }
    }
  }
}'''

packetLossData = []
totalEpochTime = []

for i in range(len(linkName)):
    query2 = ast.literal_eval(query%(linkName[i]))
    response = es.search(index="network_weather_2-*", body=query2, request_timeout=600)
    packetLoss = []
    epochTime = []

    for r in response['aggregations']['2']['buckets']:
        #Get field value and timestamp
        packetLoss.append(r['1']['value'])
        epochTime.append(r['key'])
    
    packetLoss = np.array(packetLoss,dtype=np.float)
    epochTime = np.array(epochTime,dtype=np.float)

    indices = np.logical_not(np.isnan(packetLoss))

    packetLoss = packetLoss[indices]
    epochTime = epochTime[indices]
    
    packetLossData.append(packetLoss)
    totalEpochTime.append(epochTime)

# %%
np.shape(packetLossData[0])
# Out:
# (3087,)

# %%
plt.figure(figsize=(20,20))

plt.subplot(211)
plt.boxplot(packetLossData[0:40], whis=[5,95], showfliers=False)
ax = plt.gca() 
ax.xaxis.set_ticklabels(linkName[0:40])
plt.xticks(size=15,rotation= 90)
plt.grid()
plt.ylabel('Avg. Packet loss [%]')
plt.title('Packet loss, Links 1-40')

plt.subplot(212)
plt.boxplot(packetLossData[40:], whis=[5,95], showfliers=False)
ax = plt.gca() 
ax.xaxis.set_ticklabels(linkName[40:])
plt.xticks(size=15,rotation= 90)
plt.ylabel('Avg. Packet loss [%]')
plt.title('Packet loss, Links 41-81')
plt.grid()

plt.tight_layout()

# %%
histPacketLoss= dict(zip(linkName, packetLossData))
histTime = dict(zip(linkName, totalEpochTime))

# %%
import matplotlib.dates as dt

centerName = 'UKI-NORTHGRID-MAN-HEP'

timestamp = dt.epoch2num(histTime[centerName]/1000.)
packetLoss = histPacketLoss[centerName]

plt.figure(figsize=(20,10))
plt.plot(timestamp,packetLoss)

ax = plt.gca()
#Tedious date/time formatting
xfmt = dt.DateFormatter('%d-%m-%Y %H:%M:%S')
ax.xaxis.set_major_formatter(xfmt)
ax.xaxis_date()

plt.ylabel('Avg. packet loss [%]')

#Manually add extra ticks to histogram plots
ticks = 7
start, end = ax.get_xlim()
plt.xticks(np.arange(start, end,ticks),rotation= 80 )
plt.grid()
plt.title('%s packet loss'%centerName)
plt.show()

# %%
from scipy.signal import savgol_filter

deriv = np.diff(packetLoss,n=1)/np.diff(timestamp,n=1)

#filteredDeriv = savgol_filter(deriv,11,5)
plt.figure(figsize=(20,10))
plt.plot(deriv)
# Out:
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   app.launch_new_instance()
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()

# %%
import requests

# %%
requests.get('https://github.com', verify='/path/to/certfile')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     291         try:
# --> 292             context.load_verify_locations(ca_certs, ca_cert_dir)
#     293         except IOError as e:  # Platform-specific: Python 2.6, 2.7, 3.2
#
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     375                     retries=self.max_retries,
# --> 376                     timeout=timeout
#     377                 )
#
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     783         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 784             conn.connect()
#     785
#
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     251                                     server_hostname=hostname,
# --> 252                                     ssl_version=resolved_ssl_version)
#     253
#
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     293         except IOError as e:  # Platform-specific: Python 2.6, 2.7, 3.2
# --> 294             raise SSLError(e)
#     295         # Py33 raises FileNotFoundError which subclasses OSError
#
# SSLError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-88-722351eec849> in <module>()
# ----> 1 requests.get('https://github.com', verify='/path/to/certfile')
#
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      65
#      66     kwargs.setdefault('allow_redirects', True)
# ---> 67     return request('get', url, params=params, **kwargs)
#      68
#      69
#
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      51     # cases, and look like a memory leak in others.
#      52     with sessions.Session() as session:
# ---> 53         return session.request(method=method, url=url, **kwargs)
#      54
#      55
#
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# /home/ivukotic/anaconda3/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     445         except (_SSLError, _HTTPError) as e:
#     446             if isinstance(e, _SSLError):
# --> 447                 raise SSLError(e, request=request)
#     448             elif isinstance(e, ReadTimeoutError):
#     449                 raise ReadTimeout(e, request=request)
#
# SSLError: [Errno 2] No such file or directory
