# %% [markdown]
# #### This code generates large dataframe containing multiple timeseries

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.model_selection import cross_val_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, auc

from sklearn import tree

from sklearn.metrics import roc_curve, auc
#from sklearn.preprocessing import LabelBinarizer

from pandas.tseries.offsets import *

#from graphviz import Source

# %% [markdown]
# #### parameters to set

# %%
n_series = 6
start_date = '2017-08-01 00:00:00'
end_date = '2017-08-07 23:59:59'

# regular behaviour
max_noise_amplitude = 0.05 # all the timeseries will have values between 0 and 1

# anomalies
p_anomaly = 10E-6
max_anomaly_duration = 4*3600 # 4 h

# tuning parameters
cut = 0.55
window = 24

# %% [markdown]
# #### generate normal data

# %%
dti=pd.DatetimeIndex(start=start_date,end=end_date, freq='s')
n_timesteps = len(dti)
df = pd.DataFrame()
for s in range(n_series):
    v = np.random.normal(random.random()/2, max_noise_amplitude/random.randint(1, 8), n_timesteps) 
    df['link '+str(s)] = pd.Series(v)
df['Flag']=0
df['auc_score']=0.5
df.index = dti
df.head()
# Out:
#                        link 0    link 1    link 2    link 3    link 4  \
# 2017-08-01 00:00:00  0.407704  0.272301  0.385513  0.103727  0.199788
# 2017-08-01 00:00:01  0.409575  0.249203  0.397225  0.104263  0.175192
# 2017-08-01 00:00:02  0.401627  0.280565  0.389856  0.089948  0.187844
# 2017-08-01 00:00:03  0.393300  0.254429  0.389185  0.094832  0.168733
# 2017-08-01 00:00:04  0.405336  0.257606  0.385601  0.083041  0.182779
#
#                        link 5  Flag  auc_score
# 2017-08-01 00:00:00  0.160806     0        0.5
# 2017-08-01 00:00:01  0.181118     0        0.5
# 2017-08-01 00:00:02  0.166896     0        0.5
# 2017-08-01 00:00:03  0.170334     0        0.5
# 2017-08-01 00:00:04  0.166638     0        0.5

# %% [markdown]
# #### generate anomalies

# %%
to_generate = int(n_timesteps * p_anomaly)
for a in range(to_generate):
    affects = random.sample(range(n_series), random.randint(1, n_series))
    duration = int(max_anomaly_duration * random.random())
    start = int(n_timesteps * random.random())
    end = min(start+duration, n_timesteps)
    print('affected:', affects, df.iloc[start].name, df.iloc[end].name)
    for s in affects:
        df.iloc[start:end,s] = df.iloc[start:end,s] + random.random() * 0.2
    df.iloc[start:end,n_series]=1
# Out:
# affected: [3, 5, 0, 1, 2] 2017-08-06 10:34:50 2017-08-06 11:07:05
# affected: [0, 2] 2017-08-06 03:34:51 2017-08-06 05:44:23
# affected: [4] 2017-08-07 18:05:33 2017-08-07 19:08:58
# affected: [0, 1, 4] 2017-08-03 08:56:10 2017-08-03 11:19:41
# affected: [1, 3, 4, 2, 0, 5] 2017-08-05 13:14:29 2017-08-05 14:43:12
# affected: [0, 1, 5, 4, 3, 2] 2017-08-01 19:40:14 2017-08-01 23:24:01

# %% [markdown]
# #### enforce range

# %%
df[df<0] = 0
df[df>1] = 1

# %% [markdown]
# #### plot timeseries

# %%
#df.plot(figsize=(20,7))
fig = plt.figure(figsize=(20,7))
plt.plot(df)
fig.suptitle('Simulated Data', fontsize=20)
plt.xlabel('Time (Days)', fontsize=18)
plt.ylabel('Variance in Data', fontsize=16)
plt.legend(df)

# %%
#plt.figure(figsize=[16, 17])
# 2017-08-07 23:59:37  0.163020     0        0.5
# 2017-08-07 23:59:38  0.165117     0        0.5
# 2017-08-07 23:59:39  0.156309     0        0.5
# 2017-08-07 23:59:40  0.161833     0        0.5
# 2017-08-07 23:59:41  0.178562     0        0.5
# 2017-08-07 23:59:42  0.149730     0        0.5
# 2017-08-07 23:59:43  0.161692     0        0.5
# 2017-08-07 23:59:44  0.167662     0        0.5
# 2017-08-07 23:59:45  0.181632     0        0.5
# 2017-08-07 23:59:46  0.170862     0        0.5
# 2017-08-07 23:59:47  0.167993     0        0.5
# 2017-08-07 23:59:48  0.170177     0        0.5
# 2017-08-07 23:59:49  0.167674     0        0.5
# 2017-08-07 23:59:50  0.167572     0        0.5
# 2017-08-07 23:59:51  0.158209     0        0.5
# 2017-08-07 23:59:52  0.161008     0        0.5
# 2017-08-07 23:59:53  0.179882     0        0.5
# 2017-08-07 23:59:54  0.175720     0        0.5
# 2017-08-07 23:59:55  0.156935     0        0.5
# 2017-08-07 23:59:56  0.155010     0        0.5
# 2017-08-07 23:59:57  0.159270     0        0.5
# 2017-08-07 23:59:58  0.166192     0        0.5
# 2017-08-07 23:59:59  0.170664     0        0.5
#
# [604800 rows x 8 columns]

# %% [markdown]
# #### functions

# %%
def check_for_anomaly(ref, sub):
    
    y_ref = pd.Series([0] * ref.shape[0])
    X_ref = ref
    #print("y_ref before: ", y_ref)
    #print("x_ref before: ", x_ref)
    del X_ref['Flag']
    del X_ref['auc_score']
    #print("x_ref after: ", X_ref)
    
    y_sub = pd.Series([1] * sub.shape[0])
    X_sub=sub
    #print("y_sub before: ", y_sub)
    #print("x_sub before: ", X_sub)
    del X_sub['Flag']
    del X_sub['auc_score']
    #print("X_sub after: ", X_sub)
    
    # separate Reference and Subject into Train and Test
    X_ref_train, X_ref_test, y_ref_train, y_ref_test = train_test_split(X_ref, y_ref, test_size=0.3, random_state=42)
    X_sub_train, X_sub_test, y_sub_train, y_sub_test = train_test_split(X_sub, y_sub, test_size=0.3, random_state=42)
    
    # combine training ref and sub samples
    X_train = pd.concat([X_ref_train, X_sub_train])
    y_train = pd.concat([y_ref_train, y_sub_train])

    # combine testing ref and sub samples
    X_test = pd.concat([X_ref_test, X_sub_test])
    y_test = pd.concat([y_ref_test, y_sub_test])
    
#     dtc=DecisionTreeClassifier()
    clf = AdaBoostClassifier() #dtc
#     clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1),algorithm="SAMME",n_estimators=200)
    
    #train an AdaBoost model to be able to tell the difference between the reference and subject data
    clf.fit(X_train, y_train) 

    #Predict using the combined test data
    y_predict = clf.predict(X_test)
    
    # scores = cross_val_score(clf, X, y)
    # print(scores)
    
    fpr, tpr, thresholds = roc_curve(y_test, y_predict) # calculate the false positive rate and true positive rate
    auc_score = auc(fpr, tpr) #calculate the AUC score
    print ("auc_score = ", auc_score, "\tfeature importances:", clf.feature_importances_)
    
    if auc_score > cut: 
        plot_roc(fpr, tpr, auc_score)
        #filename='tree_'+sub.index.min().strftime("%Y-%m-%d_%H")
        #tree.export_graphviz(clf.estimators_[0] , out_file=filename +'_1.dot') 
        #tree.export_graphviz(clf.estimators_[1] , out_file=filename +'_2.dot') 
        
    return auc_score

# %%
def plot_roc(fpr,tpr, roc_auc):
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.plot([0, 1], [0, 1], linestyle='--', color='r',label='Luck', alpha=.8)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %%
start = df.index.min()
end = df.index.max()

#print(df)

print(df.index)
# Out:
# DatetimeIndex(['2017-08-01 00:00:00', '2017-08-01 00:00:01',
#                '2017-08-01 00:00:02', '2017-08-01 00:00:03',
#                '2017-08-01 00:00:04', '2017-08-01 00:00:05',
#                '2017-08-01 00:00:06', '2017-08-01 00:00:07',
#                '2017-08-01 00:00:08', '2017-08-01 00:00:09',
#                ...
#                '2017-08-07 23:59:50', '2017-08-07 23:59:51',
#                '2017-08-07 23:59:52', '2017-08-07 23:59:53',
#                '2017-08-07 23:59:54', '2017-08-07 23:59:55',
#                '2017-08-07 23:59:56', '2017-08-07 23:59:57',
#                '2017-08-07 23:59:58', '2017-08-07 23:59:59'],
#               dtype='datetime64[ns]', length=604800, freq='S')

# %% [markdown]
# #### Looping over time intervals

# %%
#find min and max timestamps

start = df.index.min()
end = df.index.max()

#round start 
start.seconds=0
start.minutes=0

ref = window * Hour()
sub = 1 * Hour()

# loop over them
ti=start+ref+sub
count=0
while ti < end + 1 * Minute():
    ref_start = ti-ref-sub
    ref_end = ti-sub
    ref_df = df[(df.index >= ref_start) & (df.index < ref_end)]
    #print("In while loop: ref_df: ", ref_df)
    sub_df = df[(df.index >= ref_end) & (df.index < ti)]
    #print("In while loop: sub_df: ", sub_df)
    auc_score = check_for_anomaly(ref_df, sub_df)
    df.loc[(df.index>=ref_end) & (df.index<=ti),['auc_score']] = auc_score
    #print(ti,"\trefes:" , ref_df.shape[0], "\tsubjects:", sub_df.shape[0], '\tauc:', auc_score)
    ti = ti + sub
    count=count+1
    #if count>2: break
# Out:
# auc_score =  0.499980709877 	feature importances: [ 0.2   0.2   0.28  0.12  0.08  0.12]
# auc_score =  0.499980709877 	feature importances: [ 0.06  0.12  0.34  0.12  0.16  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.16  0.18  0.06  0.26  0.16  0.18]
# auc_score =  0.5 	feature importances: [ 0.14  0.1   0.22  0.16  0.26  0.12]
# auc_score =  0.49994212963 	feature importances: [ 0.22  0.26  0.12  0.22  0.12  0.06]
# auc_score =  0.5 	feature importances: [ 0.08  0.08  0.1   0.36  0.26  0.12]
# auc_score =  0.5 	feature importances: [ 0.18  0.1   0.2   0.2   0.14  0.18]
# auc_score =  0.5 	feature importances: [ 0.24  0.18  0.2   0.12  0.12  0.14]
# auc_score =  0.5 	feature importances: [ 0.14  0.1   0.2   0.18  0.24  0.14]
# auc_score =  0.499980709877 	feature importances: [ 0.2  0.2  0.1  0.2  0.1  0.2]
# auc_score =  0.5 	feature importances: [ 0.26  0.14  0.14  0.14  0.16  0.16]
# auc_score =  0.5 	feature importances: [ 0.24  0.1   0.14  0.14  0.12  0.26]
# auc_score =  0.5 	feature importances: [ 0.16  0.16  0.14  0.16  0.22  0.16]
# auc_score =  0.499922839506 	feature importances: [ 0.22  0.24  0.04  0.18  0.14  0.18]
# auc_score =  0.5 	feature importances: [ 0.18  0.2   0.04  0.18  0.22  0.18]
# auc_score =  0.5 	feature importances: [ 0.12  0.18  0.2   0.24  0.08  0.18]
# auc_score =  0.5 	feature importances: [ 0.18  0.1   0.18  0.12  0.2   0.22]
# auc_score =  0.499980709877 	feature importances: [ 0.24  0.16  0.16  0.14  0.1   0.2 ]
# auc_score =  0.5 	feature importances: [ 0.32  0.12  0.14  0.16  0.18  0.08]
# auc_score =  0.5 	feature importances: [ 0.16  0.18  0.2   0.1   0.14  0.22]
# auc_score =  0.5 	feature importances: [ 0.14  0.14  0.04  0.16  0.32  0.2 ]
# auc_score =  0.49994212963 	feature importances: [ 0.18  0.14  0.06  0.14  0.24  0.24]
# auc_score =  0.5 	feature importances: [ 0.16  0.22  0.16  0.18  0.18  0.1 ]
# auc_score =  0.5 	feature importances: [ 0.18  0.16  0.14  0.16  0.28  0.08]
# auc_score =  0.499961419753 	feature importances: [ 0.14  0.14  0.06  0.28  0.28  0.1 ]
# auc_score =  0.5 	feature importances: [ 0.14  0.06  0.16  0.24  0.22  0.18]
# auc_score =  0.499980709877 	feature importances: [ 0.2   0.14  0.12  0.22  0.12  0.2 ]
# auc_score =  0.499961419753 	feature importances: [ 0.16  0.1   0.1   0.18  0.3   0.16]
# auc_score =  0.499903549383 	feature importances: [ 0.24  0.14  0.12  0.24  0.12  0.14]
# auc_score =  0.5 	feature importances: [ 0.24  0.22  0.14  0.18  0.16  0.06]
# auc_score =  0.5 	feature importances: [ 0.18  0.14  0.16  0.16  0.1   0.26]
# auc_score =  0.5 	feature importances: [ 0.24  0.04  0.22  0.16  0.2   0.14]
# auc_score =  0.532407407407 	feature importances: [ 0.06  0.12  0.14  0.14  0.32  0.22]
# auc_score =  0.998553240741 	feature importances: [ 0.2   0.12  0.2   0.12  0.18  0.18]
# auc_score =  0.637191358025 	feature importances: [ 0.1   0.22  0.1   0.22  0.14  0.22]
# auc_score =  0.5 	feature importances: [ 0.06  0.26  0.26  0.08  0.18  0.16]
# auc_score =  0.49994212963 	feature importances: [ 0.22  0.28  0.08  0.16  0.18  0.08]
# auc_score =  0.500424382716 	feature importances: [ 0.16  0.12  0.2   0.14  0.24  0.14]
# auc_score =  0.499980709877 	feature importances: [ 0.12  0.28  0.06  0.2   0.14  0.2 ]
# auc_score =  0.499980709877 	feature importances: [ 0.16  0.28  0.12  0.12  0.16  0.16]
# auc_score =  0.5 	feature importances: [ 0.18  0.06  0.22  0.32  0.12  0.1 ]
# auc_score =  0.49994212963 	feature importances: [ 0.06  0.14  0.16  0.18  0.22  0.24]
# auc_score =  0.5 	feature importances: [ 0.12  0.26  0.22  0.22  0.16  0.02]
# auc_score =  0.5 	feature importances: [ 0.14  0.12  0.22  0.26  0.18  0.08]
# auc_score =  0.5 	feature importances: [ 0.14  0.2   0.18  0.1   0.28  0.1 ]
# auc_score =  0.5 	feature importances: [ 0.08  0.32  0.14  0.14  0.2   0.12]
# auc_score =  0.5 	feature importances: [ 0.3   0.14  0.16  0.1   0.16  0.14]
# auc_score =  0.499980709877 	feature importances: [ 0.16  0.14  0.08  0.22  0.2   0.2 ]
# auc_score =  0.5 	feature importances: [ 0.16  0.14  0.08  0.22  0.18  0.22]
# auc_score =  0.5 	feature importances: [ 0.12  0.22  0.26  0.12  0.14  0.14]
# auc_score =  0.499980709877 	feature importances: [ 0.08  0.26  0.2   0.14  0.08  0.24]
# auc_score =  0.499980709877 	feature importances: [ 0.14  0.14  0.3   0.12  0.22  0.08]
# auc_score =  0.499980709877 	feature importances: [ 0.2   0.12  0.2   0.12  0.3   0.06]
# auc_score =  0.499961419753 	feature importances: [ 0.18  0.18  0.2   0.2   0.2   0.04]
# auc_score =  0.5 	feature importances: [ 0.18  0.24  0.04  0.12  0.16  0.26]
# auc_score =  0.5 	feature importances: [ 0.22  0.16  0.14  0.12  0.18  0.18]
# auc_score =  0.499980709877 	feature importances: [ 0.08  0.2   0.16  0.22  0.26  0.08]
# auc_score =  0.5 	feature importances: [ 0.08  0.28  0.1   0.18  0.14  0.22]
# auc_score =  0.499980709877 	feature importances: [ 0.18  0.1   0.1   0.16  0.22  0.24]
# auc_score =  0.499980709877 	feature importances: [ 0.26  0.2   0.08  0.12  0.18  0.16]
# auc_score =  0.5 	feature importances: [ 0.12  0.16  0.08  0.2   0.28  0.16]
# auc_score =  0.5 	feature importances: [ 0.22  0.12  0.24  0.06  0.18  0.18]
# auc_score =  0.499903549383 	feature importances: [ 0.16  0.18  0.18  0.14  0.22  0.12]
# auc_score =  0.5 	feature importances: [ 0.22  0.16  0.1   0.22  0.2   0.1 ]
# auc_score =  0.5 	feature importances: [ 0.08  0.22  0.1   0.3   0.16  0.14]
# auc_score =  0.5 	feature importances: [ 0.2   0.2   0.1   0.16  0.14  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.18  0.14  0.26  0.06  0.12  0.24]
# auc_score =  0.499961419753 	feature importances: [ 0.1   0.06  0.16  0.28  0.22  0.18]
# auc_score =  0.5 	feature importances: [ 0.14  0.16  0.14  0.16  0.2   0.2 ]
# auc_score =  0.5 	feature importances: [ 0.16  0.14  0.08  0.12  0.26  0.24]
# auc_score =  0.499980709877 	feature importances: [ 0.08  0.14  0.2   0.2   0.14  0.24]
# auc_score =  0.499980709877 	feature importances: [ 0.24  0.16  0.04  0.24  0.14  0.18]
# auc_score =  0.499961419753 	feature importances: [ 0.14  0.2   0.16  0.1   0.28  0.12]
# auc_score =  0.499903549383 	feature importances: [ 0.16  0.16  0.14  0.16  0.18  0.2 ]
# auc_score =  0.500424382716 	feature importances: [ 0.18  0.24  0.14  0.06  0.22  0.16]
# auc_score =  0.5 	feature importances: [ 0.18  0.12  0.14  0.12  0.16  0.28]
# auc_score =  0.499922839506 	feature importances: [ 0.2   0.14  0.06  0.16  0.2   0.24]
# auc_score =  0.499961419753 	feature importances: [ 0.24  0.18  0.16  0.1   0.26  0.06]
# auc_score =  0.499980709877 	feature importances: [ 0.18  0.2   0.12  0.28  0.12  0.1 ]
# auc_score =  0.499922839506 	feature importances: [ 0.2   0.2   0.14  0.12  0.16  0.18]
# auc_score =  0.5 	feature importances: [ 0.18  0.18  0.18  0.18  0.16  0.12]
# auc_score =  0.5 	feature importances: [ 0.32  0.1   0.06  0.16  0.16  0.2 ]
# auc_score =  0.499903549383 	feature importances: [ 0.26  0.1   0.28  0.18  0.08  0.1 ]
# auc_score =  0.499980709877 	feature importances: [ 0.16  0.22  0.14  0.18  0.16  0.14]
# auc_score =  0.499864969136 	feature importances: [ 0.2   0.18  0.2   0.14  0.2   0.08]
# auc_score =  0.865740740741 	feature importances: [ 0.18  0.22  0.12  0.12  0.14  0.22]
# auc_score =  0.656462191358 	feature importances: [ 0.16  0.22  0.2   0.18  0.16  0.08]
# auc_score =  0.5 	feature importances: [ 0.18  0.16  0.32  0.22  0.08  0.04]
# auc_score =  0.5 	feature importances: [ 0.12  0.26  0.18  0.1   0.18  0.16]
# auc_score =  0.5 	feature importances: [ 0.08  0.14  0.26  0.12  0.18  0.22]
# auc_score =  0.5 	feature importances: [ 0.16  0.14  0.16  0.22  0.16  0.16]
# auc_score =  0.5 	feature importances: [ 0.12  0.1   0.12  0.3   0.14  0.22]
# auc_score =  0.499961419753 	feature importances: [ 0.1   0.22  0.14  0.12  0.22  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.12  0.28  0.16  0.16  0.1   0.18]
# auc_score =  0.499903549383 	feature importances: [ 0.08  0.22  0.24  0.16  0.14  0.16]
# auc_score =  0.5 	feature importances: [ 0.3   0.1   0.08  0.24  0.12  0.16]
# auc_score =  0.5 	feature importances: [ 0.24  0.1   0.12  0.08  0.18  0.28]
# auc_score =  0.5 	feature importances: [ 0.18  0.12  0.22  0.16  0.14  0.18]
# auc_score =  0.5 	feature importances: [ 0.1   0.2   0.24  0.12  0.16  0.18]
# auc_score =  0.701369598765 	feature importances: [ 0.16  0.28  0.1   0.26  0.08  0.12]
# auc_score =  0.988831018519 	feature importances: [ 0.18  0.22  0.2   0.08  0.18  0.14]
# auc_score =  0.500752314815 	feature importances: [ 0.32  0.12  0.16  0.14  0.14  0.12]
# auc_score =  0.499980709877 	feature importances: [ 0.18  0.22  0.16  0.12  0.1   0.22]
# auc_score =  0.499980709877 	feature importances: [ 0.18  0.16  0.16  0.12  0.24  0.14]
# auc_score =  0.500462962963 	feature importances: [ 0.14  0.2   0.18  0.18  0.14  0.16]
# auc_score =  0.499961419753 	feature importances: [ 0.14  0.1   0.14  0.22  0.16  0.24]
# auc_score =  0.701388888889 	feature importances: [ 0.08  0.26  0.16  0.14  0.16  0.2 ]
# auc_score =  0.499961419753 	feature importances: [ 0.28  0.1   0.18  0.1   0.18  0.16]
# auc_score =  0.5 	feature importances: [ 0.18  0.06  0.18  0.18  0.14  0.26]
# auc_score =  0.499980709877 	feature importances: [ 0.18  0.22  0.14  0.22  0.14  0.1 ]
# auc_score =  0.499961419753 	feature importances: [ 0.14  0.34  0.22  0.1   0.1   0.1 ]
# auc_score =  0.499884259259 	feature importances: [ 0.16  0.18  0.28  0.08  0.1   0.2 ]
# auc_score =  0.499961419753 	feature importances: [ 0.26  0.04  0.16  0.34  0.1   0.1 ]
# auc_score =  0.499980709877 	feature importances: [ 0.12  0.18  0.26  0.12  0.1   0.22]
# auc_score =  0.499980709877 	feature importances: [ 0.1   0.16  0.24  0.12  0.2   0.18]
# auc_score =  0.499980709877 	feature importances: [ 0.24  0.08  0.22  0.14  0.22  0.1 ]
# auc_score =  0.499961419753 	feature importances: [ 0.04  0.16  0.2   0.2   0.24  0.16]
# auc_score =  0.5 	feature importances: [ 0.22  0.1   0.2   0.14  0.16  0.18]
# auc_score =  0.500405092593 	feature importances: [ 0.12  0.18  0.16  0.18  0.16  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.2   0.12  0.2   0.28  0.12  0.08]
# auc_score =  0.499980709877 	feature importances: [ 0.26  0.12  0.12  0.08  0.24  0.18]
# auc_score =  0.499980709877 	feature importances: [ 0.18  0.18  0.26  0.12  0.1   0.16]
# auc_score =  0.5 	feature importances: [ 0.18  0.18  0.16  0.2   0.18  0.1 ]
# auc_score =  0.49994212963 	feature importances: [ 0.24  0.14  0.2   0.16  0.12  0.14]
# auc_score =  0.499961419753 	feature importances: [ 0.08  0.28  0.24  0.06  0.14  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.06  0.14  0.3   0.18  0.12  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.2   0.18  0.16  0.18  0.18  0.1 ]
# auc_score =  0.49994212963 	feature importances: [ 0.12  0.16  0.14  0.12  0.26  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.24  0.16  0.14  0.22  0.12  0.12]
# auc_score =  0.499980709877 	feature importances: [ 0.12  0.14  0.14  0.16  0.08  0.36]
# auc_score =  0.5 	feature importances: [ 0.26  0.18  0.16  0.14  0.2   0.06]
# auc_score =  0.5 	feature importances: [ 0.2   0.14  0.22  0.22  0.1   0.12]
# auc_score =  0.5 	feature importances: [ 0.22  0.2   0.12  0.16  0.22  0.08]
# auc_score =  0.5 	feature importances: [ 0.18  0.1   0.22  0.16  0.2   0.14]
# auc_score =  0.5 	feature importances: [ 0.06  0.26  0.18  0.24  0.14  0.12]
# auc_score =  0.5 	feature importances: [ 0.14  0.26  0.14  0.08  0.14  0.24]
# auc_score =  0.5 	feature importances: [ 0.16  0.08  0.24  0.22  0.04  0.26]
# auc_score =  0.499980709877 	feature importances: [ 0.18  0.18  0.2   0.14  0.1   0.2 ]
# auc_score =  0.944444444444 	feature importances: [ 0.2   0.2   0.18  0.18  0.14  0.1 ]
# auc_score =  0.5 	feature importances: [ 0.08  0.3   0.2   0.2   0.04  0.18]
# auc_score =  0.5 	feature importances: [ 0.2   0.14  0.2   0.2   0.18  0.08]
# auc_score =  0.499980709877 	feature importances: [ 0.16  0.06  0.16  0.26  0.2   0.16]
# auc_score =  0.499980709877 	feature importances: [ 0.08  0.08  0.22  0.16  0.24  0.22]
# auc_score =  0.499980709877 	feature importances: [ 0.14  0.2   0.12  0.18  0.2   0.16]

# %%
print(start)
print(end)
# Out:
# 2017-08-01 00:00:00
# 2017-08-07 23:59:59

# %%
df.plot(figsize=(20,7))

# %%
fig, ax = plt.subplots(figsize=(20,7))
df.loc[:,'Detected'] = 0
df.loc[df.auc_score>0.55,'Detected']=1
df.head()
ax.plot(df.Flag, 'r')
ax.plot(df.auc_score,'g')
ax.fill( df.Detected, 'b', alpha=0.3)
ax.legend(loc='upper left')
plt.show()
