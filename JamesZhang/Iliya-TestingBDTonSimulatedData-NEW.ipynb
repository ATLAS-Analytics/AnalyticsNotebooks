# %% [markdown]
# #### This code generates large dataframe containing multiple timeseries

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.model_selection import cross_val_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, auc

from sklearn import tree

from sklearn.metrics import roc_curve, auc
#from sklearn.preprocessing import LabelBinarizer

from pandas.tseries.offsets import *

from graphviz import Source

# %% [markdown]
# #### parameters to set

# %%
n_series = 6
start_date = '2017-08-01 00:00:00'
end_date = '2017-08-07 23:59:59'

# regular behaviour
max_noise_amplitude = 0.05 # all the timeseries will have values between 0 and 1

# anomalies
p_anomaly = 10E-6
max_anomaly_duration = 4*3600 # 4 h

# tuning parameters
cut = 0.55
window = 24

# %% [markdown]
# #### generate normal data

# %%
dti=pd.DatetimeIndex(start=start_date,end=end_date, freq='s')
n_timesteps = len(dti)
df = pd.DataFrame()
for s in range(n_series):
    v = np.random.normal(random.random()/2, max_noise_amplitude/random.randint(1, 8), n_timesteps) 
    df['link '+str(s)] = pd.Series(v)
df['Flag']=0
df['auc_score']=0.5
df.index = dti
df.head()
# Out:
#                        link 0    link 1    link 2    link 3    link 4  \
# 2017-08-01 00:00:00  0.007327  0.090064  0.117063  0.369638  0.038201
# 2017-08-01 00:00:01 -0.002844  0.058098  0.118510  0.415953  0.044229
# 2017-08-01 00:00:02  0.048363  0.048422  0.113421  0.388031  0.020736
# 2017-08-01 00:00:03 -0.070473  0.067219  0.075894  0.403566  0.044046
# 2017-08-01 00:00:04 -0.027402  0.064501  0.073641  0.420786  0.040531
#
#                        link 5  Flag  auc_score
# 2017-08-01 00:00:00  0.462032     0        0.5
# 2017-08-01 00:00:01  0.473175     0        0.5
# 2017-08-01 00:00:02  0.459454     0        0.5
# 2017-08-01 00:00:03  0.474757     0        0.5
# 2017-08-01 00:00:04  0.474979     0        0.5

# %% [markdown]
# #### generate anomalies

# %%
to_generate = int(n_timesteps * p_anomaly)
for a in range(to_generate):
    affects = random.sample(range(n_series), random.randint(1, n_series))
    duration = int(max_anomaly_duration * random.random())
    start = int(n_timesteps * random.random())
    end = min(start+duration, n_timesteps)
    print('affected:', affects, df.iloc[start].name, df.iloc[end].name)
    for s in affects:
        df.iloc[start:end,s] = df.iloc[start:end,s] + random.random() * 0.2
    df.iloc[start:end,n_series]=1
# Out:
# affected: [3, 2, 4, 0, 5, 1] 2017-08-02 13:22:05 2017-08-02 13:49:52
# affected: [0, 5, 2, 3] 2017-08-06 07:37:48 2017-08-06 08:36:58
# affected: [4, 3, 0, 1, 2, 5] 2017-08-02 14:50:48 2017-08-02 15:04:11
# affected: [3, 1, 0, 5, 2, 4] 2017-08-05 16:28:36 2017-08-05 18:04:00
# affected: [2, 3, 0] 2017-08-01 07:26:16 2017-08-01 07:27:03
# affected: [3, 5, 0, 2] 2017-08-07 21:29:25 2017-08-07 23:06:39

# %% [markdown]
# #### enforce range

# %%
df[df<0] = 0
df[df>1] = 1

# %% [markdown]
# #### plot timeseries

# %%
df.plot(figsize=(20,7))

# %%
print(df['auc_score'])
# Out:
# 2017-08-01 00:00:00    0.5
# 2017-08-01 00:00:01    0.5
# 2017-08-01 00:00:02    0.5
# 2017-08-01 00:00:03    0.5
# 2017-08-01 00:00:04    0.5
# 2017-08-01 00:00:05    0.5
# 2017-08-01 00:00:06    0.5
# 2017-08-01 00:00:07    0.5
# 2017-08-01 00:00:08    0.5
# 2017-08-01 00:00:09    0.5
# 2017-08-01 00:00:10    0.5
# 2017-08-01 00:00:11    0.5
# 2017-08-01 00:00:12    0.5
# 2017-08-01 00:00:13    0.5
# 2017-08-01 00:00:14    0.5
# 2017-08-01 00:00:15    0.5
# 2017-08-01 00:00:16    0.5
# 2017-08-01 00:00:17    0.5
# 2017-08-01 00:00:18    0.5
# 2017-08-01 00:00:19    0.5
# 2017-08-01 00:00:20    0.5
# 2017-08-01 00:00:21    0.5
# 2017-08-01 00:00:22    0.5
# 2017-08-01 00:00:23    0.5
# 2017-08-01 00:00:24    0.5
# 2017-08-01 00:00:25    0.5
# 2017-08-01 00:00:26    0.5
# 2017-08-01 00:00:27    0.5
# 2017-08-01 00:00:28    0.5
# 2017-08-01 00:00:29    0.5
#                       ...
# 2017-08-07 23:59:30    0.5
# 2017-08-07 23:59:31    0.5
# 2017-08-07 23:59:32    0.5
# 2017-08-07 23:59:33    0.5
# 2017-08-07 23:59:34    0.5
# 2017-08-07 23:59:35    0.5
# 2017-08-07 23:59:36    0.5
# 2017-08-07 23:59:37    0.5
# 2017-08-07 23:59:38    0.5
# 2017-08-07 23:59:39    0.5
# 2017-08-07 23:59:40    0.5
# 2017-08-07 23:59:41    0.5
# 2017-08-07 23:59:42    0.5
# 2017-08-07 23:59:43    0.5
# 2017-08-07 23:59:44    0.5
# 2017-08-07 23:59:45    0.5
# 2017-08-07 23:59:46    0.5
# 2017-08-07 23:59:47    0.5
# 2017-08-07 23:59:48    0.5
# 2017-08-07 23:59:49    0.5
# 2017-08-07 23:59:50    0.5
# 2017-08-07 23:59:51    0.5
# 2017-08-07 23:59:52    0.5
# 2017-08-07 23:59:53    0.5
# 2017-08-07 23:59:54    0.5
# 2017-08-07 23:59:55    0.5
# 2017-08-07 23:59:56    0.5
# 2017-08-07 23:59:57    0.5
# 2017-08-07 23:59:58    0.5
# 2017-08-07 23:59:59    0.5
# Freq: S, Name: auc_score, Length: 604800, dtype: float64

# %%
print(df)
# Out:
#                        link 0    link 1    link 2    link 3    link 4  \
# 2017-08-01 00:00:00  0.007327  0.090064  0.117063  0.369638  0.038201
# 2017-08-01 00:00:01  0.000000  0.058098  0.118510  0.415953  0.044229
# 2017-08-01 00:00:02  0.048363  0.048422  0.113421  0.388031  0.020736
# 2017-08-01 00:00:03  0.000000  0.067219  0.075894  0.403566  0.044046
# 2017-08-01 00:00:04  0.000000  0.064501  0.073641  0.420786  0.040531
# 2017-08-01 00:00:05  0.035473  0.078056  0.083488  0.413451  0.040538
# 2017-08-01 00:00:06  0.000000  0.067169  0.113340  0.385822  0.038920
# 2017-08-01 00:00:07  0.068752  0.072974  0.077906  0.424266  0.031092
# 2017-08-01 00:00:08  0.000000  0.074041  0.078806  0.393596  0.049977
# 2017-08-01 00:00:09  0.000000  0.075715  0.090841  0.379666  0.035464
# 2017-08-01 00:00:10  0.027514  0.093463  0.103550  0.383450  0.061282
# 2017-08-01 00:00:11  0.106615  0.087114  0.127836  0.448959  0.052011
# 2017-08-01 00:00:12  0.011208  0.068916  0.104987  0.423350  0.015305
# 2017-08-01 00:00:13  0.012268  0.074753  0.068642  0.417185  0.042294
# 2017-08-01 00:00:14  0.000000  0.095710  0.087339  0.424183  0.021381
# 2017-08-01 00:00:15  0.015741  0.066959  0.070502  0.405724  0.036132
# 2017-08-01 00:00:16  0.000000  0.070904  0.078944  0.407102  0.044739
# 2017-08-01 00:00:17  0.000000  0.062512  0.105390  0.394514  0.029060
# 2017-08-01 00:00:18  0.049708  0.059398  0.077501  0.395556  0.063349
# 2017-08-01 00:00:19  0.015189  0.058599  0.116403  0.413079  0.039079
# 2017-08-01 00:00:20  0.000000  0.069395  0.093505  0.406837  0.041009
# 2017-08-01 00:00:21  0.035415  0.079197  0.075672  0.395618  0.048495
# 2017-08-01 00:00:22  0.058892  0.056302  0.089110  0.414399  0.037354
# 2017-08-01 00:00:23  0.000000  0.084230  0.071319  0.386588  0.044124
# 2017-08-01 00:00:24  0.013776  0.092619  0.088292  0.429662  0.047246
# 2017-08-01 00:00:25  0.036133  0.050039  0.085670  0.428296  0.058046
# 2017-08-01 00:00:26  0.023836  0.061544  0.124656  0.447072  0.042553
# 2017-08-01 00:00:27  0.043436  0.064381  0.086929  0.404111  0.041053
# 2017-08-01 00:00:28  0.000000  0.062787  0.066276  0.402714  0.042781
# 2017-08-01 00:00:29  0.000000  0.081856  0.084330  0.388827  0.024131
# ...                       ...       ...       ...       ...       ...
# 2017-08-07 23:59:30  0.000000  0.077960  0.102181  0.435307  0.061079
# 2017-08-07 23:59:31  0.000000  0.053645  0.099582  0.413629  0.030965
# 2017-08-07 23:59:32  0.000000  0.083193  0.100715  0.376416  0.049293
# 2017-08-07 23:59:33  0.046127  0.055462  0.093894  0.373482  0.032929
# 2017-08-07 23:59:34  0.061478  0.083932  0.066443  0.400212  0.045016
# 2017-08-07 23:59:35  0.052563  0.093419  0.097796  0.395491  0.057021
# 2017-08-07 23:59:36  0.000000  0.062401  0.089348  0.394054  0.052319
# 2017-08-07 23:59:37  0.000000  0.073335  0.091439  0.401687  0.060191
# 2017-08-07 23:59:38  0.000000  0.064501  0.087538  0.417277  0.049275
# 2017-08-07 23:59:39  0.000000  0.096716  0.127401  0.384602  0.061092
# 2017-08-07 23:59:40  0.000000  0.064037  0.082960  0.426460  0.045362
# 2017-08-07 23:59:41  0.000000  0.091454  0.087036  0.395267  0.028711
# 2017-08-07 23:59:42  0.022814  0.059009  0.095478  0.368589  0.047359
# 2017-08-07 23:59:43  0.010337  0.077292  0.059244  0.396623  0.053776
# 2017-08-07 23:59:44  0.000000  0.054018  0.097528  0.375221  0.036887
# 2017-08-07 23:59:45  0.000000  0.052160  0.096142  0.371527  0.032900
# 2017-08-07 23:59:46  0.025327  0.083591  0.094778  0.421134  0.058287
# 2017-08-07 23:59:47  0.000000  0.055028  0.083741  0.382071  0.017408
# 2017-08-07 23:59:48  0.020148  0.059340  0.075344  0.401994  0.014408
# 2017-08-07 23:59:49  0.000000  0.059951  0.071987  0.405478  0.015512
# 2017-08-07 23:59:50  0.023267  0.121066  0.085698  0.429820  0.039039
# 2017-08-07 23:59:51  0.000000  0.077047  0.102959  0.396181  0.047326
# 2017-08-07 23:59:52  0.074878  0.089528  0.113037  0.405486  0.037912
# 2017-08-07 23:59:53  0.000000  0.060920  0.112650  0.416311  0.039436
# 2017-08-07 23:59:54  0.047294  0.102501  0.105804  0.379945  0.016373
# 2017-08-07 23:59:55  0.002237  0.073658  0.073146  0.390856  0.052125
# 2017-08-07 23:59:56  0.121681  0.076647  0.074202  0.409658  0.041509
# 2017-08-07 23:59:57  0.000000  0.052986  0.068465  0.406755  0.018673
# 2017-08-07 23:59:58  0.017885  0.076690  0.083100  0.412990  0.028500
# 2017-08-07 23:59:59  0.000000  0.074937  0.124169  0.418936  0.029692
#
#                        link 5  Flag  auc_score
# 2017-08-01 00:00:00  0.462032     0        0.5
# 2017-08-01 00:00:01  0.473175     0        0.5
# 2017-08-01 00:00:02  0.459454     0        0.5
# 2017-08-01 00:00:03  0.474757     0        0.5
# 2017-08-01 00:00:04  0.474979     0        0.5
# 2017-08-01 00:00:05  0.460435     0        0.5
# 2017-08-01 00:00:06  0.468522     0        0.5
# 2017-08-01 00:00:07  0.461454     0        0.5
# 2017-08-01 00:00:08  0.469667     0        0.5
# 2017-08-01 00:00:09  0.468166     0        0.5
# 2017-08-01 00:00:10  0.461520     0        0.5
# 2017-08-01 00:00:11  0.468013     0        0.5
# 2017-08-01 00:00:12  0.463470     0        0.5
# 2017-08-01 00:00:13  0.457029     0        0.5
# 2017-08-01 00:00:14  0.468922     0        0.5
# 2017-08-01 00:00:15  0.461054     0        0.5
# 2017-08-01 00:00:16  0.471476     0        0.5
# 2017-08-01 00:00:17  0.455459     0        0.5
# 2017-08-01 00:00:18  0.457332     0        0.5
# 2017-08-01 00:00:19  0.465607     0        0.5
# 2017-08-01 00:00:20  0.462840     0        0.5
# 2017-08-01 00:00:21  0.461880     0        0.5
# 2017-08-01 00:00:22  0.466881     0        0.5
# 2017-08-01 00:00:23  0.461343     0        0.5
# 2017-08-01 00:00:24  0.467626     0        0.5
# 2017-08-01 00:00:25  0.463190     0        0.5
# 2017-08-01 00:00:26  0.465269     0        0.5
# 2017-08-01 00:00:27  0.469646     0        0.5
# 2017-08-01 00:00:28  0.472666     0        0.5
# 2017-08-01 00:00:29  0.462785     0        0.5
# ...                       ...   ...        ...
# 2017-08-07 23:59:30  0.456616     0        0.5
# 2017-08-07 23:59:31  0.459820     0        0.5
# 2017-08-07 23:59:32  0.482370     0        0.5
# 2017-08-07 23:59:33  0.459712     0        0.5
# 2017-08-07 23:59:34  0.451347     0        0.5
# 2017-08-07 23:59:35  0.470476     0        0.5
# 2017-08-07 23:59:36  0.473556     0        0.5
# 2017-08-07 23:59:37  0.467681     0        0.5
# 2017-08-07 23:59:38  0.466576     0        0.5
# 2017-08-07 23:59:39  0.476296     0        0.5
# 2017-08-07 23:59:40  0.471797     0        0.5
# 2017-08-07 23:59:41  0.475479     0        0.5
# 2017-08-07 23:59:42  0.472541     0        0.5
# 2017-08-07 23:59:43  0.478502     0        0.5
# 2017-08-07 23:59:44  0.457872     0        0.5
# 2017-08-07 23:59:45  0.454595     0        0.5
# 2017-08-07 23:59:46  0.464576     0        0.5
# 2017-08-07 23:59:47  0.459706     0        0.5
# 2017-08-07 23:59:48  0.462673     0        0.5
# 2017-08-07 23:59:49  0.474564     0        0.5
# 2017-08-07 23:59:50  0.472355     0        0.5
# 2017-08-07 23:59:51  0.446518     0        0.5
# 2017-08-07 23:59:52  0.442179     0        0.5
# 2017-08-07 23:59:53  0.467587     0        0.5
# 2017-08-07 23:59:54  0.465844     0        0.5
# 2017-08-07 23:59:55  0.472151     0        0.5
# 2017-08-07 23:59:56  0.452957     0        0.5
# 2017-08-07 23:59:57  0.469141     0        0.5
# 2017-08-07 23:59:58  0.462847     0        0.5
# 2017-08-07 23:59:59  0.469521     0        0.5
#
# [604800 rows x 8 columns]

# %% [markdown]
# #### functions

# %%
def check_for_anomaly(ref, sub):
    
    y_ref = pd.Series([0] * ref.shape[0])
    X_ref = ref
    #print("y_ref before: ", y_ref)
    #print("x_ref before: ", x_ref)
    del X_ref['Flag']
    del X_ref['auc_score']
    #print("x_ref after: ", X_ref)
    
    y_sub = pd.Series([1] * sub.shape[0])
    X_sub=sub
    #print("y_sub before: ", y_sub)
    #print("x_sub before: ", X_sub)
    del X_sub['Flag']
    del X_sub['auc_score']
    #print("X_sub after: ", X_sub)
    
    # separate Reference and Subject into Train and Test
    X_ref_train, X_ref_test, y_ref_train, y_ref_test = train_test_split(X_ref, y_ref, test_size=0.3, random_state=42)
    X_sub_train, X_sub_test, y_sub_train, y_sub_test = train_test_split(X_sub, y_sub, test_size=0.3, random_state=42)
    
    # combine training ref and sub samples
    X_train = pd.concat([X_ref_train, X_sub_train])
    y_train = pd.concat([y_ref_train, y_sub_train])

    # combine testing ref and sub samples
    X_test = pd.concat([X_ref_test, X_sub_test])
    y_test = pd.concat([y_ref_test, y_sub_test])
    
#     dtc=DecisionTreeClassifier()
    clf = AdaBoostClassifier() #dtc
#     clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1),algorithm="SAMME",n_estimators=200)
    
    #train an AdaBoost model to be able to tell the difference between the reference and subject data
    clf.fit(X_train, y_train) 

    #Predict using the combined test data
    y_predict = clf.predict(X_test)
    
    # scores = cross_val_score(clf, X, y)
    # print(scores)
    
    fpr, tpr, thresholds = roc_curve(y_test, y_predict) # calculate the false positive rate and true positive rate
    auc_score = auc(fpr, tpr) #calculate the AUC score
    print ("auc_score = ", auc_score, "\tfeature importances:", clf.feature_importances_)
    
    if auc_score > cut: 
        plot_roc(fpr, tpr, auc_score)
        filename='tree_'+sub.index.min().strftime("%Y-%m-%d_%H")
        tree.export_graphviz(clf.estimators_[0] , out_file=filename +'_1.dot') 
        tree.export_graphviz(clf.estimators_[1] , out_file=filename +'_2.dot') 
        
    return auc_score

# %%
def plot_roc(fpr,tpr, roc_auc):
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.plot([0, 1], [0, 1], linestyle='--', color='r',label='Luck', alpha=.8)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %%
start = df.index.min()
end = df.index.max()

#print(df)

print(df.index)
# Out:
# DatetimeIndex(['2017-08-01 00:00:00', '2017-08-01 00:00:01',
#                '2017-08-01 00:00:02', '2017-08-01 00:00:03',
#                '2017-08-01 00:00:04', '2017-08-01 00:00:05',
#                '2017-08-01 00:00:06', '2017-08-01 00:00:07',
#                '2017-08-01 00:00:08', '2017-08-01 00:00:09',
#                ...
#                '2017-08-07 23:59:50', '2017-08-07 23:59:51',
#                '2017-08-07 23:59:52', '2017-08-07 23:59:53',
#                '2017-08-07 23:59:54', '2017-08-07 23:59:55',
#                '2017-08-07 23:59:56', '2017-08-07 23:59:57',
#                '2017-08-07 23:59:58', '2017-08-07 23:59:59'],
#               dtype='datetime64[ns]', length=604800, freq='S')

# %% [markdown]
# #### Looping over time intervals

# %%
#find min and max timestamps

start = df.index.min()
end = df.index.max()

#round start 
start.seconds=0
start.minutes=0

ref = window * Hour()
sub = 1 * Hour()

# loop over them
ti=start+ref+sub
count=0
while ti < end + 1 * Minute():
    ref_start = ti-ref-sub
    ref_end = ti-sub
    ref_df = df[(df.index >= ref_start) & (df.index < ref_end)]
    #print("In while loop: ref_df: ", ref_df)
    sub_df = df[(df.index >= ref_end) & (df.index < ti)]
    #print("In while loop: sub_df: ", sub_df)
    auc_score = check_for_anomaly(ref_df, sub_df)
    df.loc[(df.index>=ref_end) & (df.index<=ti),['auc_score']] = auc_score
    #print(ti,"\trefes:" , ref_df.shape[0], "\tsubjects:", sub_df.shape[0], '\tauc:', auc_score)
    ti = ti + sub
    count=count+1
    #if count>2: break
# Out:
# auc_score =  0.5 	feature importances: [ 0.1   0.3   0.18  0.12  0.14  0.16]
# auc_score =  0.5 	feature importances: [ 0.14  0.18  0.22  0.16  0.1   0.2 ]
# auc_score =  0.499980709877 	feature importances: [ 0.16  0.2   0.1   0.2   0.2   0.14]
# auc_score =  0.500405092593 	feature importances: [ 0.04  0.3   0.18  0.32  0.1   0.06]
# auc_score =  0.499922839506 	feature importances: [ 0.    0.32  0.24  0.12  0.2   0.12]
# auc_score =  0.5 	feature importances: [ 0.12  0.3   0.16  0.16  0.1   0.16]
# auc_score =  0.5 	feature importances: [ 0.08  0.26  0.14  0.18  0.14  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.14  0.12  0.18  0.12  0.24  0.2 ]
# auc_score =  0.500385802469 	feature importances: [ 0.08  0.22  0.26  0.2   0.18  0.06]
# auc_score =  0.499980709877 	feature importances: [ 0.1   0.1   0.1   0.22  0.3   0.18]
# auc_score =  0.5 	feature importances: [ 0.18  0.14  0.14  0.12  0.26  0.16]
# auc_score =  0.499980709877 	feature importances: [ 0.    0.12  0.22  0.26  0.22  0.18]
# auc_score =  0.499961419753 	feature importances: [ 0.06  0.32  0.2   0.14  0.12  0.16]
# auc_score =  0.719888117284 	feature importances: [ 0.08  0.16  0.12  0.24  0.14  0.26]
# auc_score =  0.574517746914 	feature importances: [ 0.1   0.18  0.18  0.24  0.08  0.22]
# auc_score =  0.500868055556 	feature importances: [ 0.1   0.08  0.12  0.3   0.22  0.18]
# auc_score =  0.5 	feature importances: [ 0.14  0.18  0.12  0.22  0.2   0.14]
# auc_score =  0.499922839506 	feature importances: [ 0.1   0.14  0.26  0.18  0.2   0.12]
# auc_score =  0.5 	feature importances: [ 0.14  0.14  0.18  0.16  0.14  0.24]
# auc_score =  0.5 	feature importances: [ 0.14  0.16  0.18  0.18  0.2   0.14]
# auc_score =  0.5 	feature importances: [ 0.06  0.12  0.26  0.2   0.14  0.22]
# auc_score =  0.5 	feature importances: [ 0.18  0.08  0.24  0.1   0.16  0.24]
# auc_score =  0.5 	feature importances: [ 0.12  0.14  0.16  0.22  0.18  0.18]
# auc_score =  0.5 	feature importances: [ 0.12  0.24  0.16  0.2   0.14  0.14]
# auc_score =  0.5 	feature importances: [ 0.08  0.08  0.14  0.12  0.3   0.28]
# auc_score =  0.49994212963 	feature importances: [ 0.08  0.18  0.1   0.24  0.18  0.22]
# auc_score =  0.499961419753 	feature importances: [ 0.08  0.12  0.24  0.12  0.18  0.26]
# auc_score =  0.5 	feature importances: [ 0.1   0.16  0.08  0.32  0.12  0.22]
# auc_score =  0.49994212963 	feature importances: [ 0.12  0.16  0.16  0.16  0.22  0.18]
# auc_score =  0.49994212963 	feature importances: [ 0.06  0.14  0.16  0.24  0.04  0.36]
# auc_score =  0.5 	feature importances: [ 0.1   0.12  0.16  0.18  0.18  0.26]
# auc_score =  0.5 	feature importances: [ 0.06  0.24  0.24  0.12  0.12  0.22]
# auc_score =  0.499961419753 	feature importances: [ 0.12  0.12  0.18  0.26  0.14  0.18]
# auc_score =  0.499980709877 	feature importances: [ 0.06  0.18  0.2   0.2   0.18  0.18]
# auc_score =  0.499922839506 	feature importances: [ 0.12  0.16  0.16  0.18  0.06  0.32]
# auc_score =  0.500424382716 	feature importances: [ 0.12  0.12  0.22  0.26  0.16  0.12]
# auc_score =  0.5 	feature importances: [ 0.2   0.1   0.16  0.16  0.26  0.12]
# auc_score =  0.499980709877 	feature importances: [ 0.08  0.26  0.2   0.1   0.2   0.16]
# auc_score =  0.500462962963 	feature importances: [ 0.08  0.16  0.16  0.12  0.34  0.14]
# auc_score =  0.5 	feature importances: [ 0.04  0.14  0.26  0.24  0.16  0.16]
# auc_score =  0.499980709877 	feature importances: [ 0.12  0.14  0.2   0.22  0.18  0.14]
# auc_score =  0.5 	feature importances: [ 0.14  0.16  0.1   0.16  0.24  0.2 ]
# auc_score =  0.499961419753 	feature importances: [ 0.06  0.24  0.18  0.16  0.22  0.14]
# auc_score =  0.5 	feature importances: [ 0.14  0.32  0.14  0.08  0.14  0.18]
# auc_score =  0.5 	feature importances: [ 0.12  0.28  0.1   0.24  0.16  0.1 ]
# auc_score =  0.5 	feature importances: [ 0.08  0.2   0.1   0.2   0.12  0.3 ]
# auc_score =  0.5 	feature importances: [ 0.04  0.16  0.16  0.12  0.26  0.26]
# auc_score =  0.499961419753 	feature importances: [ 0.14  0.22  0.16  0.24  0.1   0.14]
# auc_score =  0.499980709877 	feature importances: [ 0.1   0.14  0.14  0.22  0.22  0.18]
# auc_score =  0.499961419753 	feature importances: [ 0.1   0.3   0.18  0.2   0.1   0.12]
# auc_score =  0.499980709877 	feature importances: [ 0.14  0.1   0.16  0.2   0.16  0.24]
# auc_score =  0.499961419753 	feature importances: [ 0.06  0.14  0.26  0.24  0.08  0.22]
# auc_score =  0.499980709877 	feature importances: [ 0.1   0.12  0.18  0.24  0.24  0.12]
# auc_score =  0.50044367284 	feature importances: [ 0.08  0.06  0.14  0.18  0.3   0.24]
# auc_score =  0.499845679012 	feature importances: [ 0.22  0.18  0.2   0.16  0.12  0.12]
# auc_score =  0.5 	feature importances: [ 0.12  0.12  0.12  0.2   0.18  0.26]
# auc_score =  0.499980709877 	feature importances: [ 0.12  0.32  0.16  0.14  0.08  0.18]
# auc_score =  0.500462962963 	feature importances: [ 0.2   0.1   0.14  0.22  0.06  0.28]
# auc_score =  0.499980709877 	feature importances: [ 0.1   0.16  0.06  0.12  0.28  0.28]
# auc_score =  0.5 	feature importances: [ 0.12  0.14  0.24  0.12  0.22  0.16]
# auc_score =  0.5 	feature importances: [ 0.08  0.2   0.26  0.12  0.22  0.12]
# auc_score =  0.499980709877 	feature importances: [ 0.16  0.1   0.18  0.1   0.26  0.2 ]
# auc_score =  0.499980709877 	feature importances: [ 0.    0.22  0.18  0.08  0.12  0.4 ]
# auc_score =  0.5 	feature importances: [ 0.12  0.02  0.16  0.28  0.22  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.06  0.12  0.18  0.22  0.12  0.3 ]
# auc_score =  0.499961419753 	feature importances: [ 0.12  0.18  0.16  0.18  0.12  0.24]
# auc_score =  0.5 	feature importances: [ 0.18  0.22  0.14  0.24  0.16  0.06]
# auc_score =  0.499961419753 	feature importances: [ 0.08  0.2   0.26  0.12  0.26  0.08]
# auc_score =  0.5 	feature importances: [ 0.1   0.18  0.2   0.1   0.22  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.18  0.14  0.16  0.3   0.1   0.12]
# auc_score =  0.5 	feature importances: [ 0.12  0.18  0.16  0.08  0.3   0.16]
# auc_score =  0.5 	feature importances: [ 0.16  0.2   0.16  0.28  0.02  0.18]
# auc_score =  0.499961419753 	feature importances: [ 0.04  0.14  0.36  0.12  0.12  0.22]
# auc_score =  0.5 	feature importances: [ 0.06  0.12  0.16  0.28  0.24  0.14]
# auc_score =  0.5 	feature importances: [ 0.06  0.28  0.18  0.2   0.16  0.12]
# auc_score =  0.499903549383 	feature importances: [ 0.2   0.1   0.2   0.14  0.22  0.14]
# auc_score =  0.5 	feature importances: [ 0.08  0.26  0.18  0.1   0.18  0.2 ]
# auc_score =  0.499961419753 	feature importances: [ 0.2   0.22  0.18  0.16  0.12  0.12]
# auc_score =  0.5 	feature importances: [ 0.1   0.3   0.16  0.04  0.22  0.18]
# auc_score =  0.499980709877 	feature importances: [ 0.06  0.12  0.28  0.24  0.2   0.1 ]
# auc_score =  0.499961419753 	feature importances: [ 0.02  0.34  0.16  0.22  0.16  0.1 ]
# auc_score =  0.5 	feature importances: [ 0.12  0.24  0.14  0.22  0.14  0.14]
# auc_score =  0.5 	feature importances: [ 0.12  0.18  0.18  0.3   0.08  0.14]
# auc_score =  0.49994212963 	feature importances: [ 0.12  0.2   0.14  0.14  0.16  0.24]
# auc_score =  0.5 	feature importances: [ 0.08  0.16  0.22  0.16  0.28  0.1 ]
# auc_score =  0.5 	feature importances: [ 0.08  0.06  0.18  0.2   0.36  0.12]
# auc_score =  0.5 	feature importances: [ 0.22  0.16  0.16  0.24  0.12  0.1 ]
# auc_score =  0.499980709877 	feature importances: [ 0.1   0.3   0.16  0.08  0.22  0.14]
# auc_score =  0.750925925926 	feature importances: [ 0.08  0.12  0.2   0.22  0.16  0.22]
# auc_score =  0.97762345679 	feature importances: [ 0.16  0.18  0.16  0.08  0.22  0.2 ]
# auc_score =  0.499980709877 	feature importances: [ 0.    0.28  0.24  0.1   0.2   0.18]
# auc_score =  0.5 	feature importances: [ 0.02  0.26  0.16  0.14  0.18  0.24]
# auc_score =  0.499980709877 	feature importances: [ 0.06  0.22  0.2   0.14  0.14  0.24]
# auc_score =  0.499922839506 	feature importances: [ 0.1   0.18  0.24  0.2   0.06  0.22]
# auc_score =  0.499980709877 	feature importances: [ 0.16  0.14  0.1   0.18  0.2   0.22]
# auc_score =  0.5 	feature importances: [ 0.08  0.18  0.08  0.22  0.16  0.28]
# auc_score =  0.5 	feature importances: [ 0.08  0.28  0.1   0.18  0.22  0.14]
# auc_score =  0.5 	feature importances: [ 0.08  0.14  0.2   0.18  0.12  0.28]
# auc_score =  0.5 	feature importances: [ 0.18  0.22  0.18  0.08  0.2   0.14]
# auc_score =  0.499961419753 	feature importances: [ 0.12  0.28  0.14  0.08  0.18  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.1   0.2   0.3   0.12  0.14  0.14]
# auc_score =  0.5 	feature importances: [ 0.08  0.2   0.18  0.1   0.18  0.26]
# auc_score =  0.499980709877 	feature importances: [ 0.06  0.14  0.2   0.16  0.2   0.24]
# auc_score =  0.676832561728 	feature importances: [ 0.2   0.26  0.2   0.18  0.1   0.06]
# auc_score =  0.761265432099 	feature importances: [ 0.08  0.12  0.28  0.26  0.14  0.12]
# auc_score =  0.5 	feature importances: [ 0.04  0.2   0.14  0.24  0.16  0.22]
# auc_score =  0.5 	feature importances: [ 0.12  0.28  0.08  0.28  0.16  0.08]
# auc_score =  0.49994212963 	feature importances: [ 0.12  0.18  0.14  0.18  0.08  0.3 ]
# auc_score =  0.499980709877 	feature importances: [ 0.    0.22  0.28  0.1   0.14  0.26]
# auc_score =  0.499980709877 	feature importances: [ 0.1   0.16  0.26  0.24  0.04  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.12  0.16  0.12  0.3   0.12  0.18]
# auc_score =  0.499961419753 	feature importances: [ 0.12  0.24  0.2   0.2   0.12  0.12]
# auc_score =  0.49994212963 	feature importances: [ 0.12  0.16  0.18  0.08  0.26  0.2 ]
# auc_score =  0.499980709877 	feature importances: [ 0.04  0.24  0.16  0.12  0.22  0.22]
# auc_score =  0.499980709877 	feature importances: [ 0.06  0.18  0.18  0.24  0.16  0.18]
# auc_score =  0.5 	feature importances: [ 0.14  0.08  0.14  0.16  0.18  0.3 ]
# auc_score =  0.499980709877 	feature importances: [ 0.08  0.26  0.1   0.16  0.2   0.2 ]
# auc_score =  0.500462962963 	feature importances: [ 0.04  0.3   0.24  0.1   0.12  0.2 ]
# auc_score =  0.499980709877 	feature importances: [ 0.08  0.12  0.24  0.3   0.14  0.12]
# auc_score =  0.499961419753 	feature importances: [ 0.1   0.34  0.1   0.34  0.06  0.06]
# auc_score =  0.5 	feature importances: [ 0.2   0.26  0.08  0.14  0.16  0.16]
# auc_score =  0.499961419753 	feature importances: [ 0.1   0.12  0.2   0.22  0.16  0.2 ]
# auc_score =  0.499961419753 	feature importances: [ 0.1   0.34  0.18  0.2   0.08  0.1 ]
# auc_score =  0.5 	feature importances: [ 0.16  0.12  0.18  0.22  0.2   0.12]
# auc_score =  0.499980709877 	feature importances: [ 0.14  0.2   0.26  0.14  0.02  0.24]
# auc_score =  0.499884259259 	feature importances: [ 0.18  0.16  0.16  0.18  0.24  0.08]
# auc_score =  0.499961419753 	feature importances: [ 0.12  0.1   0.2   0.22  0.24  0.12]
# auc_score =  0.5 	feature importances: [ 0.04  0.18  0.22  0.24  0.2   0.12]
# auc_score =  0.5 	feature importances: [ 0.12  0.06  0.18  0.22  0.24  0.18]
# auc_score =  0.5 	feature importances: [ 0.14  0.12  0.3   0.1   0.04  0.3 ]
# auc_score =  0.5 	feature importances: [ 0.12  0.16  0.12  0.24  0.12  0.24]
# auc_score =  0.5 	feature importances: [ 0.    0.16  0.24  0.16  0.26  0.18]
# auc_score =  0.5 	feature importances: [ 0.06  0.12  0.22  0.3   0.12  0.18]
# auc_score =  0.499980709877 	feature importances: [ 0.06  0.18  0.16  0.22  0.24  0.14]
# auc_score =  0.5 	feature importances: [ 0.06  0.2   0.3   0.16  0.08  0.2 ]
# auc_score =  0.5 	feature importances: [ 0.04  0.14  0.16  0.26  0.2   0.2 ]
# auc_score =  0.499980709877 	feature importances: [ 0.14  0.14  0.24  0.12  0.14  0.22]
# auc_score =  0.5 	feature importances: [ 0.1   0.18  0.2   0.1   0.14  0.28]
# auc_score =  0.499961419753 	feature importances: [ 0.16  0.16  0.12  0.18  0.1   0.28]
# auc_score =  0.5 	feature importances: [ 0.06  0.18  0.16  0.12  0.22  0.26]
# auc_score =  0.499980709877 	feature importances: [ 0.06  0.24  0.12  0.2   0.2   0.18]
# auc_score =  0.743942901235 	feature importances: [ 0.06  0.16  0.16  0.34  0.14  0.14]
# auc_score =  0.971489197531 	feature importances: [ 0.22  0.1   0.14  0.1   0.2   0.24]
# auc_score =  0.499903549383 	feature importances: [ 0.06  0.1   0.26  0.24  0.22  0.12]

# %%
print(start)
print(end)
# Out:
# 2017-08-01 00:00:00
# 2017-08-07 23:59:59

# %%
df.plot(figsize=(20,7))

# %%
fig, ax = plt.subplots(figsize=(20,7))
df.loc[:,'Detected'] = 0
df.loc[df.auc_score>0.55,'Detected']=1
df.head()
ax.plot(df.Flag, 'r')
ax.plot(df.auc_score,'g')
ax.fill( df.Detected, 'b', alpha=0.3)
ax.legend(loc='upper left')
plt.show()
