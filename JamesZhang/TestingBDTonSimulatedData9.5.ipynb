# %% [markdown]
# #### This code generates large dataframe containing multiple timeseries

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn import tree

from sklearn.model_selection import cross_val_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

import time

# %% [markdown]
# #### parameters to set

# %%
n_series = 6
n_timesteps = 8*24*3600 # 8 days

# regular behaviour
max_noise_amplitude = 0.05 # all the timeseries will have values between 0 and 1

# anomalies
p_anomaly = 10E-6
max_anomaly_duration = 4*3600 # 4 h

# %% [markdown]
# #### generate normal data

# %%
df = pd.DataFrame()
for s in range(n_series):
    v = np.random.normal(random.random()/2, max_noise_amplitude/random.randint(1, 8), n_timesteps) 
    df[s]=pd.Series(v)
df['Flag']=0
#df.head()

# %% [markdown]
# #### generate anomalies

# %%
to_generate = int(n_timesteps * p_anomaly)
for a in range(to_generate):
    affects = random.sample(range(n_series), random.randint(1, n_series))
    duration = int(max_anomaly_duration * random.random())
    start = (n_timesteps * random.random())
    end = min(start+duration, n_timesteps)
    for s in affects:
        df.loc[start:end,s] = df.loc[start:end,s] + random.random() * 0.3
    if len(affects)>1:
        df.loc[start:end,"Flag"]=1

# %% [markdown]
# #### enforce range

# %%
df[df<0] = 0
df[df>1] = 1

# %% [markdown]
# #### plot timeseries

# %%
df.plot(figsize=(20,10))
#print df[147599]

# %% [markdown]
# #### running BDT

# %%
start_time = time.clock()

# clf = AdaBoostClassifier(n_estimators=100)
# y=df.Flag
# X=df.loc[:,range(n_series)]
# scores = cross_val_score(clf, X, y)
# print(scores)
predicted_flag_array = np.zeros((24*3600), dtype=np.int)
auc_score_array = np.zeros((24*3600), dtype=np.float)
score_holder_array = np.zeros(3600, dtype=np.float)
anomaly_array = np.ones(3600, dtype=np.int)
not_anomaly_array = np.zeros(3600, dtype=np.int)

#print df

#trying to print out the columns where the flag is 1

#if (df.iloc[ 2:, -1:] == 1):
#    print df
#print df.iloc[ :, -1:]
#if(df.iloc[-1] == 1):
#    print df

# %% [markdown]
# #### Train a model for all hours after the first day

# %%
#separate data into Reference and Subject
def trainer(reference, subject):
    refTrainSize = (int)(reference.shape[0] * 0.7) #training size of reference data is 70% of the data
    subTrainSize = (int)(subject.shape[0] * 0.7) #training size of subject data is 70% of the data
    
    reference.loc[:].Flag = 0 # Flagging the reference data as 0
    X_ref = reference.loc[:, range(n_series)] #refers to the feature set data
    y_ref = reference.Flag #refers to the label data
    
    subject.loc[:].Flag = 1 # Flagging the subject data as 1
    X_sub = subject.loc[:, range(n_series)] #refers to the feature set data
    y_sub = subject.Flag #refers to the label data

    #separate Reference into Train and Test
    X_ref_train = X_ref.loc[:refTrainSize, range(n_series)] #take 70% of the reference feature data
    X_ref_test  = X_ref.loc[refTrainSize:, range(n_series)] #take 30% of the reference feature data
    y_ref_train = y_ref.loc[:refTrainSize] #take 70% of the reference label data
    y_ref_test  = y_ref.loc[refTrainSize:] #take 30% of the reference label data

    #separate Subject into Train and Test
    X_sub_train = X_sub.loc[:subTrainSize, range(n_series)] #take 70% of the subject feature data
    X_sub_test  = X_sub.loc[subTrainSize:, range(n_series)] #take 30% of the subject feature data
    y_sub_train = y_sub.loc[:subTrainSize] #take 70% of the subject label data
    y_sub_test  = y_sub.loc[subTrainSize:] #take 30% of the subject label data

    #Combine reference and subject train datasets
    X_train_frames = [X_ref_train, X_sub_train] 
    X_train = pd.concat(X_train_frames, ignore_index=True) #combine the 70% training data features from both reference and subject
    
    y_train_frames = [y_ref_train, y_sub_train]
    y_train = pd.concat(y_train_frames, ignore_index=True) #combine the 70% training data label from both reference and subject

    #Combine reference and subject test datasets
    X_test_frames = [X_ref_test, X_sub_test]
    X_test = pd.concat(X_test_frames, ignore_index=True) #combine the 30% training data features from both reference and subject
    
    y_test_frames = [y_ref_test, y_sub_test]
    y_test = pd.concat(y_test_frames, ignore_index=True) #combine the 30% training data label from both reference and subject

    #Train model using the combined train data
    clf = AdaBoostClassifier(n_estimators=50)
    clf.fit(X_train, y_train) 
    #train an AdaBoost model to be able to tell the difference between the reference and subject data

    #Predict using the combined test data
    y_predict = clf.predict(X_test)
    #use the trained AdaBoost model on the testing data. This is the predicted result
        
    from sklearn.metrics import roc_curve, auc
        
    #Calculate the AUC
        
    #from sklearn.preprocessing import LabelBinarizer

    # convert False and True to 0 and 1
    #lb = LabelBinarizer()
    #y_test_transformed = lb.fit_transform(y_test)
    #y_predict_transformed = lb.fit_transform(y_predict)
    fpr, tpr, thresholds = roc_curve(y_test, y_predict) # calculate the false positive rate and true positive rate
    auc_score = auc(fpr, tpr) #calculate the AUC score
    #if (auc_score != 0.5):
    #    auc_score = 1.0
    
    score_holder_array.fill(auc_score)
    #print ("score_holder_array = ", score_holder_array)
    print ("auc_score = ", auc_score) #finds the auc score. If auc~.5, then no anomalies. If auc>0.5, then there are anomalies
    print ("feature importance = ", clf.feature_importances_)
    
    
    #from sklearn.externals.six import StringIO  
    
    #if(auc_score >= 0.55):
        #decision_function = clf.staged_decision_function(X_test)
        #print ("decision_function = ", decision_function)
        #   tree.export_graphviz(clf)
        #  with open("tree.txt", "w") as f:
        #     f = tree.export_graphviz(clf, out_file=f)
        #dot_data = StringIO() 
        #tree.export_graphviz(clf, out_file=dot_data) 
        #graph = pydot.graph_from_dot_data(dot_data.getvalue()) 
        #graph.write_pdf("iris.pdf") 
    
    return [clf, auc_score]

# %%
#from graphviz import Source
#from sklearn import tree
#def drawTree(clf, sequenceNumber, auc_score):
#    estimators = clf.estimators_
#    decision_tree = estimators[0]
    
    # This loop is not needed because AdaBoostClassifier uses 1 depth of trees
    # for dtree in estimators:
    #    if (dtree.max_depth > decision_tree.max_depth):
    #        decision_tree = dtree
    
#    graph = Source(tree.export_graphviz(decision_tree, out_file=None))
#    graph = Source(tree.export_graphviz(clf, max_depth=None,  out_file="tree.dot"))
    
    # display tree diagram in Jupyter
#    graph.format = 'png'
#    graph.render('dtree_render',view=True)
    
    # save the tree diagram into PNG file
#    png_bytes = graph.pipe(format='png')
#    with open('decision_tree_{0}_{1}.png'.format(sequenceNumber, auc_score),'wb') as f:
#        f.write(png_bytes)

# %%
from graphviz import Source
from sklearn import tree
def drawTree(clf, sequenceNumber, auc_score):
    estimators = clf.estimators_ 
    for index, decision_tree in enumerate(estimators):
        # decision_tree = estimators[0]
    
        # This loop is not needed because AdaBoostClassifier uses 1 depth of trees
        # for dtree in estimators:
        #    if (dtree.max_depth > decision_tree.max_depth):
        #        decision_tree = dtree
        graph = Source(tree.export_graphviz(decision_tree, out_file=None))
    
        # display tree diagram in Jupyter
        # graph.format = 'png'
        # graph.render('dtree_render',view=True)
    
        # save the tree diagram into PNG file
        png_bytes = graph.pipe(format='png')
        with open('decision_tree_{0}_{1}_{2}.png'.format(sequenceNumber, auc_score, index),'wb') as f:
            f.write(png_bytes)

# %%
def rankImportance(clf):
    f = 0
    importances = clf.feature_importances_
    indices = np.argsort(importances)[::-1]
    print("Feature ranking:")
    while f < 6:
        print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
        f = f + 1

# %% [markdown]
# #### Calculate AUC

# %%
#from sklearn.metrics import roc_curve, auc
#from sklearn.preprocessing import LabelBinarizer

n = 24*3600 # number of seconds in the first day
m = 0
hour = 3600
k = 0
#trains an AdaBoost model for every hour after the first day

#data from the first day
#sub = df[n:n+hour] #subject data refers to the data collected from the last hour
#sub_reset_index = sub.reset_index(drop=True)
#ref = df[m:n]
#ref_reset_index = ref.reset_index(drop=True)
#clf, auc_score = trainer(ref_reset_index, sub_reset_index)
#drawTree(clf, k, auc_score);

while(n <= n_timesteps):
    print("n = ", n)
    
    k = k + 1
    ref = df[m:n] #reference data refers to the data collected from the first day
    ref_reset_index = ref.reset_index(drop=True)
    
    sub = df[n:n+hour] #subject data refers to the data collected from the last hour
    sub_reset_index = sub.reset_index(drop=True)
    
    clf, auc_score = trainer(ref_reset_index, sub_reset_index)
    
    # detect and record anormaly                
    if(auc_score >= 0.55):
        #or auc_score <= 0.45
        predicted_flag_array = np.append(predicted_flag_array, anomaly_array)
        #drawTree(clf, k, auc_score) #draws each tree that is produced
        rankImportance(clf)
        
    else:
        predicted_flag_array = np.append(predicted_flag_array, not_anomaly_array)
    
    auc_score_array = np.append(auc_score_array, score_holder_array)
        
    m = m + hour
    n = n + hour

    #print("score_holder_array = ", score_holder_array)
    #print("auc_score_array = ", auc_score_array)
    #print("predicted_flag_array =", predicted_flag_array)
    #print ("auc_score = ", auc_score)
    #print ("feature importance = ", clf.feature_importances_)
        
# convert False and True to 0 and 1
#lb = LabelBinarizer()
#y_test_transformed = lb.fit_transform(y_test)
#y_predict_transformed = lb.fit_transform(y_predict)
#fpr, tpr, thresholds = roc_curve(y_test, y_predict) # calculate the false positive rate and true positive rate
#auc_score = auc(fpr, tpr) #calculate the AUC score
#print auc_score #finds the auc score. If auc~.5, then no anomalies. If auc>=0.55 or <=0.45, then there are anomalies
# Out:
# ('n = ', 86400)
# ('auc_score = ', 0.44942324755989355)
# ('feature importance = ', array([ 0.06,  0.18,  0.12,  0.1 ,  0.3 ,  0.24]))
# ('n = ', 90000)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.1 ,  0.08,  0.22,  0.2 ,  0.28,  0.12]))
# ('n = ', 93600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.18,  0.2 ,  0.12,  0.22,  0.12,  0.16]))
# ('n = ', 97200)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.18,  0.08,  0.24,  0.26,  0.06,  0.18]))
# ('n = ', 100800)
# ('auc_score = ', 0.49994213186219666)
# ('feature importance = ', array([ 0.24,  0.1 ,  0.24,  0.28,  0.02,  0.12]))
# ('n = ', 104400)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.18,  0.16,  0.06,  0.26,  0.2 ,  0.14]))
# ('n = ', 108000)
# ('auc_score = ', 1.0)
# ('feature importance = ', array([ 0.14,  0.12,  0.18,  0.18,  0.2 ,  0.18]))
# Feature ranking:
# 1. feature 4 (0.200000)
# 2. feature 5 (0.180000)
# 3. feature 3 (0.180000)
# 4. feature 2 (0.180000)
# 5. feature 0 (0.140000)
# 6. feature 1 (0.120000)
# ('n = ', 111600)
# ('auc_score = ', 0.93213996373596697)
# ('feature importance = ', array([ 0.,  0.,  0.,  1.,  0.,  0.]))
# Feature ranking:
# 1. feature 3 (1.000000)
# 2. feature 5 (0.000000)
# 3. feature 4 (0.000000)
# 4. feature 2 (0.000000)
# 5. feature 1 (0.000000)
# 6. feature 0 (0.000000)
# ('n = ', 115200)
# ('auc_score = ', 0.86269819837197637)
# ('feature importance = ', array([ 0.,  0.,  0.,  1.,  0.,  0.]))
# Feature ranking:
# 1. feature 3 (1.000000)
# 2. feature 5 (0.000000)
# 3. feature 4 (0.000000)
# 4. feature 2 (0.000000)
# 5. feature 1 (0.000000)
# 6. feature 0 (0.000000)
# ('n = ', 118800)
# ('auc_score = ', 0.48862680337835612)
# ('feature importance = ', array([ 0.,  1.,  0.,  0.,  0.,  0.]))
# ('n = ', 122400)
# ('auc_score = ', 0.49868832220979131)
# ('feature importance = ', array([ 0.14,  0.18,  0.08,  0.22,  0.22,  0.16]))
# ('n = ', 126000)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.14,  0.24,  0.16,  0.12,  0.12,  0.22]))
# ('n = ', 129600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.22,  0.18,  0.18,  0.14,  0.16,  0.12]))
# ('n = ', 133200)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.12,  0.14,  0.18,  0.16,  0.24,  0.16]))
# ('n = ', 136800)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.18,  0.2 ,  0.12,  0.2 ,  0.16,  0.14]))
# ('n = ', 140400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.16,  0.1 ,  0.06,  0.1 ,  0.22,  0.36]))
# ('n = ', 144000)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.2 ,  0.08,  0.18,  0.24,  0.16,  0.14]))
# ('n = ', 147600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.1 ,  0.18,  0.14,  0.18,  0.16,  0.24]))
# ('n = ', 151200)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.08,  0.06,  0.22,  0.24,  0.1 ,  0.3 ]))
# ('n = ', 154800)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.18,  0.2 ,  0.26,  0.12,  0.1 ,  0.14]))
# ('n = ', 158400)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.14,  0.14,  0.14,  0.16,  0.14,  0.28]))
# ('n = ', 162000)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.2 ,  0.16,  0.24,  0.14,  0.08,  0.18]))
# ('n = ', 165600)
# ('auc_score = ', 0.49994213186219666)
# ('feature importance = ', array([ 0.12,  0.14,  0.14,  0.26,  0.1 ,  0.24]))
# ('n = ', 169200)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.3 ,  0.18,  0.16,  0.14,  0.1 ,  0.12]))
# ('n = ', 172800)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.14,  0.12,  0.16,  0.18,  0.28,  0.12]))
# ('n = ', 176400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.18,  0.1 ,  0.18,  0.28,  0.14,  0.12]))
# ('n = ', 180000)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.18,  0.06,  0.16,  0.2 ,  0.12,  0.28]))
# ('n = ', 183600)
# ('auc_score = ', 0.49984568496585779)
# ('feature importance = ', array([ 0.14,  0.08,  0.2 ,  0.22,  0.06,  0.3 ]))
# ('n = ', 187200)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.12,  0.08,  0.32,  0.14,  0.26,  0.08]))
# ('n = ', 190800)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.2 ,  0.16,  0.22,  0.12,  0.08,  0.22]))
# ('n = ', 194400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.06,  0.16,  0.28,  0.12,  0.18,  0.2 ]))
# ('n = ', 198000)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.12,  0.16,  0.2 ,  0.12,  0.24,  0.16]))
# ('n = ', 201600)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.12,  0.16,  0.32,  0.2 ,  0.06,  0.14]))
# ('n = ', 205200)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.26,  0.14,  0.12,  0.16,  0.1 ,  0.22]))
# ('n = ', 208800)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.12,  0.2 ,  0.18,  0.22,  0.2 ,  0.08]))
# ('n = ', 212400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.22,  0.24,  0.1 ,  0.12,  0.24,  0.08]))
# ('n = ', 216000)
# ('auc_score = ', 0.500462962962963)
# ('feature importance = ', array([ 0.18,  0.22,  0.2 ,  0.1 ,  0.14,  0.16]))
# ('n = ', 219600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.26,  0.24,  0.12,  0.1 ,  0.16,  0.12]))
# ('n = ', 223200)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.12,  0.2 ,  0.2 ,  0.14,  0.16,  0.18]))
# ('n = ', 226800)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.1 ,  0.24,  0.2 ,  0.1 ,  0.26,  0.1 ]))
# ('n = ', 230400)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.18,  0.1 ,  0.12,  0.12,  0.34,  0.14]))
# ('n = ', 234000)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.08,  0.2 ,  0.12,  0.14,  0.12,  0.34]))
# ('n = ', 237600)
# ('auc_score = ', 0.50036651606662419)
# ('feature importance = ', array([ 0.12,  0.26,  0.1 ,  0.06,  0.24,  0.22]))
# ('n = ', 241200)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.2 ,  0.16,  0.26,  0.16,  0.1 ,  0.12]))
# ('n = ', 244800)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.16,  0.16,  0.14,  0.24,  0.12,  0.18]))
# ('n = ', 248400)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.1 ,  0.26,  0.16,  0.14,  0.16,  0.18]))
# ('n = ', 252000)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.06,  0.02,  0.28,  0.16,  0.32,  0.16]))
# ('n = ', 255600)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.36,  0.18,  0.1 ,  0.14,  0.12,  0.1 ]))
# ('n = ', 259200)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.16,  0.16,  0.18,  0.12,  0.28,  0.1 ]))
# ('n = ', 262800)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.16,  0.24,  0.2 ,  0.06,  0.12,  0.22]))
# ('n = ', 266400)
# ('auc_score = ', 0.4999228424829289)
# ('feature importance = ', array([ 0.18,  0.14,  0.12,  0.16,  0.2 ,  0.2 ]))
# ('n = ', 270000)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.1 ,  0.1 ,  0.12,  0.16,  0.24,  0.28]))
# ('n = ', 273600)
# ('auc_score = ', 0.99996142124146448)
# ('feature importance = ', array([ 0.2 ,  0.12,  0.16,  0.18,  0.08,  0.26]))
# Feature ranking:
# 1. feature 5 (0.260000)
# 2. feature 0 (0.200000)
# 3. feature 3 (0.180000)
# 4. feature 2 (0.160000)
# 5. feature 1 (0.120000)
# 6. feature 4 (0.080000)
# ('n = ', 277200)
# ('auc_score = ', 0.93987500482234476)
# ('feature importance = ', array([ 0.,  0.,  0.,  0.,  0.,  1.]))
# Feature ranking:
# 1. feature 5 (1.000000)
# 2. feature 4 (0.000000)
# 3. feature 3 (0.000000)
# 4. feature 2 (0.000000)
# 5. feature 1 (0.000000)
# 6. feature 0 (0.000000)
# ('n = ', 280800)
# ('auc_score = ', 0.87043323945835427)
# ('feature importance = ', array([ 0.,  0.,  1.,  0.,  0.,  0.]))
# Feature ranking:
# 1. feature 2 (1.000000)
# 2. feature 5 (0.000000)
# 3. feature 4 (0.000000)
# 4. feature 3 (0.000000)
# 5. feature 1 (0.000000)
# 6. feature 0 (0.000000)
# ('n = ', 284400)
# ('auc_score = ', 0.51812110372399334)
# ('feature importance = ', array([ 0.,  0.,  0.,  1.,  0.,  0.]))
# ('n = ', 288000)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.14,  0.12,  0.14,  0.24,  0.14,  0.22]))
# ('n = ', 291600)
# ('auc_score = ', 0.57322568073648272)
# ('feature importance = ', array([ 0.14,  0.18,  0.22,  0.14,  0.14,  0.18]))
# Feature ranking:
# 1. feature 2 (0.220000)
# 2. feature 5 (0.180000)
# 3. feature 1 (0.180000)
# 4. feature 4 (0.140000)
# 5. feature 3 (0.140000)
# 6. feature 0 (0.140000)
# ('n = ', 295200)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.12,  0.22,  0.16,  0.16,  0.1 ,  0.24]))
# ('n = ', 298800)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.18,  0.06,  0.26,  0.1 ,  0.16,  0.24]))
# ('n = ', 302400)
# ('auc_score = ', 0.47042938158250069)
# ('feature importance = ', array([ 0.12,  0.12,  0.22,  0.18,  0.22,  0.14]))
# ('n = ', 306000)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.24,  0.14,  0.08,  0.18,  0.24,  0.12]))
# ('n = ', 309600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.18,  0.14,  0.36,  0.16,  0.04,  0.12]))
# ('n = ', 313200)
# ('auc_score = ', 0.49984568496585779)
# ('feature importance = ', array([ 0.14,  0.1 ,  0.2 ,  0.16,  0.26,  0.14]))
# ('n = ', 316800)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.26,  0.2 ,  0.14,  0.08,  0.12,  0.2 ]))
# ('n = ', 320400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.12,  0.1 ,  0.22,  0.3 ,  0.1 ,  0.16]))
# ('n = ', 324000)
# ('auc_score = ', 0.49978781682805445)
# ('feature importance = ', array([ 0.12,  0.12,  0.18,  0.14,  0.24,  0.2 ]))
# ('n = ', 327600)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.16,  0.16,  0.08,  0.26,  0.22,  0.12]))
# ('n = ', 331200)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.14,  0.18,  0.22,  0.08,  0.24,  0.14]))
# ('n = ', 334800)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.2 ,  0.18,  0.1 ,  0.18,  0.12,  0.22]))
# ('n = ', 338400)
# ('auc_score = ', 0.49988426372439337)
# ('feature importance = ', array([ 0.22,  0.18,  0.1 ,  0.18,  0.14,  0.18]))
# ('n = ', 342000)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.14,  0.3 ,  0.1 ,  0.2 ,  0.18,  0.08]))
# ('n = ', 345600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.14,  0.18,  0.2 ,  0.12,  0.18,  0.18]))
# ('n = ', 349200)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.26,  0.24,  0.02,  0.12,  0.22,  0.14]))
# ('n = ', 352800)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.08,  0.26,  0.04,  0.16,  0.14,  0.32]))
# ('n = ', 356400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.18,  0.12,  0.22,  0.16,  0.16,  0.16]))
# ('n = ', 360000)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.22,  0.14,  0.14,  0.3 ,  0.08,  0.12]))
# ('n = ', 363600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.1 ,  0.24,  0.14,  0.06,  0.24,  0.22]))
# ('n = ', 367200)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.18,  0.18,  0.14,  0.14,  0.16,  0.2 ]))
# ('n = ', 370800)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.24,  0.06,  0.28,  0.12,  0.08,  0.22]))
# ('n = ', 374400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.12,  0.2 ,  0.22,  0.06,  0.2 ,  0.2 ]))
# ('n = ', 378000)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.14,  0.1 ,  0.28,  0.14,  0.18,  0.16]))
# ('n = ', 381600)
# ('auc_score = ', 0.52312885876888038)
# ('feature importance = ', array([ 0.18,  0.16,  0.18,  0.14,  0.2 ,  0.14]))
# ('n = ', 385200)
# ('auc_score = ', 0.99903553103661125)
# ('feature importance = ', array([ 1.,  0.,  0.,  0.,  0.,  0.]))
# Feature ranking:
# 1. feature 0 (1.000000)
# 2. feature 5 (0.000000)
# 3. feature 4 (0.000000)
# 4. feature 3 (0.000000)
# 5. feature 2 (0.000000)
# 6. feature 1 (0.000000)
# ('n = ', 388800)
# ('auc_score = ', 0.42959376567262064)
# ('feature importance = ', array([ 0.16,  0.08,  0.26,  0.24,  0.1 ,  0.16]))
# ('n = ', 392400)
# ('auc_score = ', 0.41375718529377725)
# ('feature importance = ', array([ 0.12,  0.14,  0.12,  0.18,  0.18,  0.26]))
# ('n = ', 396000)
# ('auc_score = ', 0.49328729601481425)
# ('feature importance = ', array([ 0.14,  0.16,  0.22,  0.22,  0.1 ,  0.16]))
# ('n = ', 399600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.16,  0.2 ,  0.14,  0.1 ,  0.28,  0.12]))
# ('n = ', 403200)
# ('auc_score = ', 0.48117356583465143)
# ('feature importance = ', array([ 0.24,  0.06,  0.12,  0.24,  0.16,  0.18]))
# ('n = ', 406800)
# ('auc_score = ', 0.49706801435129816)
# ('feature importance = ', array([ 0.22,  0.2 ,  0.2 ,  0.12,  0.1 ,  0.16]))
# ('n = ', 410400)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.18,  0.16,  0.18,  0.18,  0.16,  0.14]))
# ('n = ', 414000)
# ('auc_score = ', 0.49994213186219666)
# ('feature importance = ', array([ 0.16,  0.24,  0.16,  0.14,  0.14,  0.16]))
# ('n = ', 417600)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.18,  0.12,  0.12,  0.16,  0.26,  0.16]))
# ('n = ', 421200)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.2 ,  0.14,  0.1 ,  0.16,  0.18,  0.22]))
# ('n = ', 424800)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.18,  0.2 ,  0.14,  0.12,  0.22,  0.14]))
# ('n = ', 428400)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.24,  0.18,  0.12,  0.2 ,  0.06,  0.2 ]))
# ('n = ', 432000)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.14,  0.16,  0.14,  0.12,  0.24,  0.2 ]))
# ('n = ', 435600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.14,  0.2 ,  0.14,  0.16,  0.18,  0.18]))
# ('n = ', 439200)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.32,  0.1 ,  0.18,  0.2 ,  0.12,  0.08]))
# ('n = ', 442800)
# ('auc_score = ', 0.49994213186219666)
# ('feature importance = ', array([ 0.14,  0.12,  0.06,  0.26,  0.2 ,  0.22]))
# ('n = ', 446400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.32,  0.28,  0.1 ,  0.12,  0.04,  0.14]))
# ('n = ', 450000)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.12,  0.18,  0.06,  0.16,  0.3 ,  0.18]))
# ('n = ', 453600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.22,  0.1 ,  0.08,  0.2 ,  0.22,  0.18]))
# ('n = ', 457200)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.18,  0.1 ,  0.3 ,  0.12,  0.18,  0.12]))
# ('n = ', 460800)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.22,  0.12,  0.06,  0.16,  0.26,  0.18]))
# ('n = ', 464400)
# ('auc_score = ', 0.49976852744878669)
# ('feature importance = ', array([ 0.2 ,  0.12,  0.22,  0.14,  0.14,  0.18]))
# ('n = ', 468000)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.12,  0.2 ,  0.14,  0.14,  0.22,  0.18]))
# ('n = ', 471600)
# ('auc_score = ', 0.50042438420442747)
# ('feature importance = ', array([ 0.18,  0.12,  0.22,  0.06,  0.22,  0.2 ]))
# ('n = ', 475200)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.1 ,  0.24,  0.18,  0.12,  0.26,  0.1 ]))
# ('n = ', 478800)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.14,  0.22,  0.14,  0.18,  0.18,  0.14]))
# ('n = ', 482400)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.1 ,  0.14,  0.22,  0.1 ,  0.18,  0.26]))
# ('n = ', 486000)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.2 ,  0.1 ,  0.16,  0.18,  0.16,  0.2 ]))
# ('n = ', 489600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.16,  0.12,  0.06,  0.2 ,  0.28,  0.18]))
# ('n = ', 493200)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.12,  0.22,  0.26,  0.1 ,  0.12,  0.18]))
# ('n = ', 496800)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.14,  0.2 ,  0.16,  0.26,  0.16,  0.08]))
# ('n = ', 500400)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.22,  0.1 ,  0.16,  0.1 ,  0.16,  0.26]))
# ('n = ', 504000)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.24,  0.12,  0.16,  0.16,  0.06,  0.26]))
# ('n = ', 507600)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.12,  0.12,  0.2 ,  0.14,  0.24,  0.18]))
# ('n = ', 511200)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.2 ,  0.12,  0.1 ,  0.22,  0.18,  0.18]))
# ('n = ', 514800)
# ('auc_score = ', 0.4999228424829289)
# ('feature importance = ', array([ 0.22,  0.18,  0.24,  0.12,  0.16,  0.08]))
# ('n = ', 518400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.24,  0.12,  0.08,  0.14,  0.16,  0.26]))
# ('n = ', 522000)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.16,  0.1 ,  0.16,  0.1 ,  0.22,  0.26]))
# ('n = ', 525600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.14,  0.26,  0.18,  0.12,  0.12,  0.18]))
# ('n = ', 529200)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.14,  0.14,  0.22,  0.14,  0.26,  0.1 ]))
# ('n = ', 532800)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.38,  0.08,  0.14,  0.16,  0.1 ,  0.14]))
# ('n = ', 536400)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.16,  0.12,  0.1 ,  0.2 ,  0.3 ,  0.12]))
# ('n = ', 540000)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.16,  0.12,  0.16,  0.36,  0.12,  0.08]))
# ('n = ', 543600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.2 ,  0.18,  0.16,  0.16,  0.16,  0.14]))
# ('n = ', 547200)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.24,  0.18,  0.1 ,  0.18,  0.14,  0.16]))
# ('n = ', 550800)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.1 ,  0.2 ,  0.14,  0.32,  0.22,  0.02]))
# ('n = ', 554400)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.12,  0.18,  0.14,  0.3 ,  0.16,  0.1 ]))
# ('n = ', 558000)
# ('auc_score = ', 0.4999228424829289)
# ('feature importance = ', array([ 0.22,  0.16,  0.12,  0.22,  0.1 ,  0.18]))
# ('n = ', 561600)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.14,  0.16,  0.24,  0.22,  0.12,  0.12]))
# ('n = ', 565200)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.08,  0.1 ,  0.22,  0.22,  0.24,  0.14]))
# ('n = ', 568800)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.12,  0.28,  0.1 ,  0.14,  0.2 ,  0.16]))
# ('n = ', 572400)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.12,  0.2 ,  0.28,  0.18,  0.08,  0.14]))
# ('n = ', 576000)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.18,  0.12,  0.16,  0.1 ,  0.28,  0.16]))
# ('n = ', 579600)
# ('auc_score = ', 0.50079090027105144)
# ('feature importance = ', array([ 0.12,  0.32,  0.12,  0.2 ,  0.18,  0.06]))
# ('n = ', 583200)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.18,  0.28,  0.04,  0.2 ,  0.16,  0.14]))
# ('n = ', 586800)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.18,  0.16,  0.14,  0.18,  0.2 ,  0.14]))
# ('n = ', 590400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.18,  0.14,  0.16,  0.22,  0.14,  0.16]))
# ('n = ', 594000)
# ('auc_score = ', 0.500462962962963)
# ('feature importance = ', array([ 0.24,  0.16,  0.16,  0.14,  0.14,  0.16]))
# ('n = ', 597600)
# ('auc_score = ', 0.50044367358369524)
# ('feature importance = ', array([ 0.22,  0.12,  0.14,  0.18,  0.16,  0.18]))
# ('n = ', 601200)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.2 ,  0.24,  0.22,  0.08,  0.12,  0.14]))
# ('n = ', 604800)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.22,  0.24,  0.1 ,  0.24,  0.06,  0.14]))
# ('n = ', 608400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.24,  0.08,  0.2 ,  0.14,  0.12,  0.22]))
# ('n = ', 612000)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.18,  0.06,  0.18,  0.16,  0.24,  0.18]))
# ('n = ', 615600)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.08,  0.14,  0.14,  0.18,  0.28,  0.18]))
# ('n = ', 619200)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.18,  0.24,  0.16,  0.18,  0.08,  0.16]))
# ('n = ', 622800)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.12,  0.16,  0.1 ,  0.08,  0.2 ,  0.34]))
# ('n = ', 626400)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.1 ,  0.22,  0.08,  0.22,  0.26,  0.12]))
# ('n = ', 630000)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.18,  0.08,  0.16,  0.12,  0.18,  0.28]))
# ('n = ', 633600)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.12,  0.16,  0.24,  0.18,  0.12,  0.18]))
# ('n = ', 637200)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.16,  0.22,  0.14,  0.08,  0.14,  0.26]))
# ('n = ', 640800)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.16,  0.14,  0.16,  0.14,  0.26,  0.14]))
# ('n = ', 644400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.18,  0.12,  0.3 ,  0.08,  0.22,  0.1 ]))
# ('n = ', 648000)
# ('auc_score = ', 0.49998071062073224)
# ('feature importance = ', array([ 0.1 ,  0.16,  0.12,  0.26,  0.18,  0.18]))
# ('n = ', 651600)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.2 ,  0.36,  0.2 ,  0.04,  0.08,  0.12]))
# ('n = ', 655200)
# ('auc_score = ', 0.5004050948251596)
# ('feature importance = ', array([ 0.12,  0.18,  0.22,  0.16,  0.18,  0.14]))
# ('n = ', 658800)
# ('auc_score = ', 0.9994984582785017)
# ('feature importance = ', array([ 0.26,  0.22,  0.16,  0.18,  0.08,  0.1 ]))
# Feature ranking:
# 1. feature 0 (0.260000)
# 2. feature 1 (0.220000)
# 3. feature 3 (0.180000)
# 4. feature 2 (0.160000)
# 5. feature 5 (0.100000)
# 6. feature 4 (0.080000)
# ('n = ', 662400)
# ('auc_score = ', 0.97482736005555348)
# ('feature importance = ', array([ 0.,  1.,  0.,  0.,  0.,  0.]))
# Feature ranking:
# 1. feature 1 (1.000000)
# 2. feature 5 (0.000000)
# 3. feature 4 (0.000000)
# 4. feature 3 (0.000000)
# 5. feature 2 (0.000000)
# 6. feature 0 (0.000000)
# ('n = ', 666000)
# ('auc_score = ', 0.90538559469156277)
# ('feature importance = ', array([ 0.,  1.,  0.,  0.,  0.,  0.]))
# Feature ranking:
# 1. feature 1 (1.000000)
# 2. feature 5 (0.000000)
# 3. feature 4 (0.000000)
# 4. feature 3 (0.000000)
# 5. feature 2 (0.000000)
# 6. feature 0 (0.000000)
# ('n = ', 669600)
# ('auc_score = ', 0.33594382932757227)
# ('feature importance = ', array([ 0.12,  0.28,  0.1 ,  0.24,  0.14,  0.12]))
# ('n = ', 673200)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.16,  0.2 ,  0.12,  0.22,  0.14,  0.16]))
# ('n = ', 676800)
# ('auc_score = ', 0.49996142124146448)
# ('feature importance = ', array([ 0.16,  0.14,  0.12,  0.08,  0.3 ,  0.2 ]))
# ('n = ', 680400)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.22,  0.18,  0.12,  0.18,  0.16,  0.14]))
# ('n = ', 684000)
# ('auc_score = ', 0.49936345048416342)
# ('feature importance = ', array([ 0.16,  0.22,  0.26,  0.18,  0.08,  0.1 ]))
# ('n = ', 687600)
# ('auc_score = ', 0.5)
# ('feature importance = ', array([ 0.1 ,  0.22,  0.24,  0.12,  0.16,  0.16]))
# ('n = ', 691200)
# ('auc_score = ', nan)
# ('feature importance = ', array([ 0.,  0.,  0.,  0.,  0.,  0.]))
# /Users/jameszhang/anaconda2/lib/python2.7/site-packages/sklearn/metrics/ranking.py:542: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
print time.clock() - start_time, "seconds"

#X=df.loc[:,range(n_series)] # get all the features
#y_predict = clf.predict(X)  # predict whole list of Flags
y_predict_df = pd.DataFrame(predicted_flag_array[0:n_timesteps], columns=['Predict_Flag']) #label my predicted anomalies
# X_test_reset_index = X_test.reset_index(drop=True)

x_y_combined = pd.concat([df, y_predict_df], axis=1) #append the column to the right of the original table
x_y_combined.plot(style=['-', '-', '-', '-', '-', '-', '-', 'bs--'], figsize=(20,10))
# Out:
# 674.511009 seconds

# %%
y_predict_df.plot(style=['bs--'], figsize=(20,10))

# %%
half_array = np.zeros(n_timesteps, dtype=np.float)
half_array.fill(0.5)
#print half_array
half_df = pd.DataFrame(half_array[0:n_timesteps], columns=['AUC = 0.5'])

upper_threshold_array = np.zeros(n_timesteps, dtype=np.float)
upper_threshold_array.fill(0.55)
upper_threshold_df = pd.DataFrame(upper_threshold_array[0:n_timesteps], columns=['Upperthreshold = 0.55'])

auc_score_df = pd.DataFrame(auc_score_array[0:n_timesteps], columns=['AUC Score'])

tuner = pd.concat([y_predict_df, auc_score_df], axis=1)
tuner2 = pd.concat([tuner, half_df], axis=1)
tuner3 = pd.concat([tuner2, upper_threshold_df], axis=1)
tuner3.plot(style=['bs--', '-', '-', '-'], figsize=(20,10))
