# %%
#import numpy as np

def print_characters(word):
    for char in word:
        print char
    
'''print_characters('reddit')

letter = 'z'
for letter in 'abc':
    print letter
print 'after the loop, letter is', letter'''

#print len('octopus')

def print_N(number):
    p = number + 1
    r = range(1, p)
    for n in r:
        print n
        
#print_N(3)

def expo(a, b):
    p = b - 1
    amount = range(p)
    n = a
    for m in amount:
        n = n * a
#        print 5
    print n
#expo(2, 4)

'''def rev(word):
    a = len(word) - 1
    for letter in word:
        print word[a]
        a = a - 1
print rev('octopus')''' 

def rev(word):
    result = ''
    for x in range(0, len(word)):
        result = result + word[(-x-1)]
    return result
#print rev('python')

odds = [1, 3, 5, 7]
'''print 'odds are: ', odds

print 'first, last: ', odds[0], odds[-1]

for number in odds:
    print number
    
print 'odds before: ', odds
odds[1] = 2
print 'odds now: ', odds'''

odds.append(23)
#print odds

def total(data):
    result = 0
    for n in data:
        result = result + n
    return result
print total([1, 7, 7])

import glob
print glob.glob('*.ipynb')
print glob.glob('*.csv')

def analyze_all(pattern):
    """
    Analyze and plot min, max, average for all csv files that 
    match given pattern
    
    :param pattern: string with pattern to use
    :return: None
    """
    filenames = glob.glob(pattern)
    for f in filenames:
        print f
        analyze(f)
analyze_all('inflammation-0[123].csv')
analyze_all('inflammation*.csv')
# Out:
# 15
# ['01.ipynb', '02.ipynb', '03.ipynb']
# []
