# %%
#from ipythonblocks import ImageGrid

num = 39
if num == 100:
    print 'number is ', num
elif num < 40:
    print 'ok'
else:
    print 'wat'
print 'done'


# elif = else if

def sign(num):
    if num > 0:
        return 1
    elif num == 0:
        return 0
    else:
        return -1

print 'sign of -3:', sign(-3)


def thing(ok):
    if (ok > 1) or (ok < 1):
        return 'this value is not one'
    else:
        return 'one'
print thing(1)


print ('lz' < 'ri')
print ('la' < 'lb')
print ('lar' < 'laa')

if '': print 'empty string is true'
if 'word': print 'word is true'
if []: print 'empty list is true'
if [1, 2, 3]: print 'non-empty list is true'
if 0: print 'zero is true'
if 1: print 'one is true


def near(a, b):
    if (a > b * 0.9) and (a < b * 1.10):
        return 'true'
    else:
        return 'false'
print near(5.4, 6)

numbers = [-5, 3, 2, -1, 9, 6]
total = 0
for n in numbers:
    if n >= 0:
        total = total + n
print 'sum of positive values:', total

for consonant in 'bcd':
    for vowel in 'ae':
        print consonant + vowel



def sort(a):
    positive = 0
    negative = 0
    for n in a:
        if n<0:
            positive = positive + n
        elif n == 0:
            print 'zero'
        else:
            negative = negative + n
print sort([1, 2, 3, 4, 5])


numbers = [-5, 3, 2, -1, 9, 6]

pos_total = 0
neg_total = 0
for n in numbers:
    if n >= 0:
        pos_total += n
    else:
        neg_total += n
        
print 'negative and positive sums are:', neg_total, pos_total
# Out:
#   File "<ipython-input-1-ebd31086ae7d>", line 43
#     if 1: print 'one is true
#                            ^
# SyntaxError: EOL while scanning string literal
