# %% [markdown]
# # Send alert emails based on alarms

# %% [markdown]
# This Jupyter notebook is run by a cron job every hour, and its purpose is to send alert emails based on alarms and user subscribing records.
#
# NOTE that currently this code only deal with packet loss!
#
# This notebook works following such procedure:
#
# (1) Get user subscribing data (well formatted) for the monitoring task Packet Loss (user site as source and/or destination) from Google Sheets
#
# (2) Get the packet loss alarms for the past hour (call it NEW), and also for the past past hour (call it OLD) from Elasticsearch
#
# (3) If an alarm is not in OLD, but in NEW, then it means a new problem appears, and we should send email to relevant users
#
# (4) If an alarm is in OLD, but not in NEW, then it means an old problem disappears, and we should send email to relevant users
#
# (5) If an alarm is in both OLD and NEW, then it is a problem known to users, so we do not send any email to users
#
# (6) There is a corner case within (5), which is any newly registered user will not receive email about an existing old problem
#
# (7) So we should send all the alarms in NEW (i.e. currently exist) to newly registered users (i.e. who registered exactly in the past hour)
#
# (8) There is another corner case, which is when a user updates settings and includes new sites or tasks, it is effectively a newly registered user for these newly added sites or tasks.
#
# (9) At the same time, note that when a user updates settings, in Google Sheets the contents of the original record updates (instead of creating a new record) and the timestamp becomes the new time.
#
# (10) So, combining the above design and implementation, when a user updates settings, as we detect newly registered users only based on timestamp, we will regard this old user (with new settings) as a new user, so we will send all currently existing alarms to this user (despite the fact that this user should already know most of these alarms, assuming the setting update is minor), but this kind of possibly repeated alarms only happen one time everytime the user updates settings. So I think overall this scheme is reasonable.

# %% [markdown]
# ## Import necessary packages and classes

# %%
# Retrieve user subscribing records from google sheets. Using Xinran version based on Ilija version.
from subscribers import subscribers
google = subscribers()

# Related to Elasticsearch queries
from elasticsearch import Elasticsearch, exceptions as es_exceptions, helpers
import sys
import datetime

# %% [markdown]
# ## Establish Elasticsearch connection

# %%
es = Elasticsearch(hosts=[{'host':'atlas-kibana.mwt2.org', 'port':9200}],timeout=60)

# %% [markdown]
# ## List all alarms-yyyy.mm indices

# %%
indices = es.cat.indices(index="alarms-*", h="index", request_timeout=600).split('\n')
indices = [x for x in indices if x != '']
indices = [x.strip() for x in indices]
print(indices)
# Out:
# ['alarms-2016.08']

# %% [markdown]
# ## Find indices to be used

# %%
cday = datetime.datetime.utcnow()
pday = cday - datetime.timedelta(days=1)
ind1 = 'alarms-%d.%02d' % (cday.year, cday.month)
ind2 = 'alarms-%d.%02d' % (pday.year, pday.month)

print('checking for indices:', ind1, ind2)

ind=[]
if ind1 in indices:
    ind.append(ind1)
if ind2 != ind1 and ind2 in indices and cday.hour<3:
    ind.append(ind2)

if len(ind)==0:
    print('no current indices found. Aborting.')
    sys.exit(1)
else:
    print('will use indices:', ind)
# Out:
# checking for indices: alarms-2016.08 alarms-2016.08
# will use indices: ['alarms-2016.08']

# %% [markdown]
# ## Queries to find all the alarms of type Packet Loss for the past hour and past past hour

# %%
query_new = {
    "size": 1000,
    "query": {
        "bool": {
            "must": [
                {"term": { "_type": "packetloss" }}
            ],
            "filter": {
                "range": {
                    "alarmTime": {
                        "gt": "now-1h"
                    }
                }
            }
        }
    }
}

query_old = {
    "size": 1000,
    "query": {
        "bool": {
            "must": [
                {"term": { "_type": "packetloss" }}
            ],
            "filter": {
                "range": {
                    "alarmTime": {
                        "gt": "now-2h",
                        "lt": "now-1h"
                    }
                }
            }
        }
    }
}

print(query_new)
print(query_old)
# Out:
# {'size': 1000, 'query': {'bool': {'filter': {'range': {'alarmTime': {'gt': 'now-1h'}}}, 'must': [{'term': {'_type': 'packetloss'}}]}}}
# {'size': 1000, 'query': {'bool': {'filter': {'range': {'alarmTime': {'lt': 'now-1h', 'gt': 'now-2h'}}}, 'must': [{'term': {'_type': 'packetloss'}}]}}}

# %% [markdown]
# ## Execute the query

# %%
result_new = es.search(index=ind, body=query_new, request_timeout=120)
print('Number of hits of new alarms:', result_new['hits']['total'] )

result_old = es.search(index=ind, body=query_old, request_timeout=120)
print('Number of hits of old alarms:', result_old['hits']['total'] )

hits_new = result_new['hits']['hits']
hits_old = result_old['hits']['hits']
# Out:
# Number of hits of new alarms: 239
# Number of hits of old alarms: 255

# %% [markdown]
# ## Generate the site ip and name dictionary, and vice versa

# %%
site_ip_name = {}

for hit in hits_new:
    info = hit['_source']
    site_ip_name[info['src']] = info['srcSite']
    site_ip_name[info['dest']] = info['destSite']

for hit in hits_old:
    info = hit['_source']
    site_ip_name[info['src']] = info['srcSite']
    site_ip_name[info['dest']] = info['destSite']

site_ip_name
# Out:
# {'109.105.124.86': 'NDGF-T1',
#  '109.105.125.232': 'FI_HIP_T2',
#  '117.103.105.191': 'Taiwan-LCG2',
#  '128.142.223.247': 'CERN-PROD',
#  '128.227.221.44': 'UFlorida-HPC',
#  '129.107.255.29': 'UTA_SWT2',
#  '129.15.40.231': 'OU_OCHEP_SWT2',
#  '129.215.213.70': 'UKI-SCOTGRID-ECDF',
#  '129.93.239.148': 'Nebraska',
#  '130.246.176.109': 'RAL-LCG2',
#  '130.246.47.129': 'UKI-SOUTHGRID-RALPP',
#  '131.111.66.196': 'UKI-SOUTHGRID-CAM-HEP',
#  '131.154.254.12': 'INFN-T1',
#  '131.169.98.30': 'DESY-HH',
#  '131.225.205.12': 'UnknownSite',
#  '131.243.24.11': 'UnknownSite',
#  '132.195.125.213': 'wuppertalprod',
#  '132.206.245.252': 'CA-MCGILL-CLUMEQ-T2',
#  '132.230.202.235': 'UNI-FREIBURG',
#  '134.158.103.10': 'IN2P3-LAPP',
#  '134.158.123.183': 'IN2P3-LPC',
#  '134.158.132.200': 'GRIF',
#  '134.158.159.85': 'GRIF',
#  '134.158.20.192': 'IN2P3-CPPM',
#  '134.158.73.243': 'GRIF',
#  '134.61.24.193': 'UnknownSite',
#  '134.75.125.241': 'UnknownSite',
#  '134.79.118.72': 'WT2',
#  '137.222.74.15': 'UKI-SOUTHGRID-BRIS-HEP',
#  '138.253.60.82': 'UKI-NORTHGRID-LIV-HEP',
#  '141.108.35.18': 'INFN-ROMA1',
#  '141.34.200.28': 'DESY-ZN',
#  '142.150.19.61': 'CA-SCINET-T2',
#  '143.167.3.116': 'UKI-NORTHGRID-SHEF-HEP',
#  '143.215.129.69': 'UnknownSite',
#  '144.16.111.26': 'INDIACMS-TIFR',
#  '144.92.180.75': 'GLOW',
#  '145.100.17.8': 'SARA-MATRIX',
#  '146.83.90.7': 'EELA-UTFSM',
#  '147.156.116.40': 'IFIC-LCG2',
#  '147.213.204.112': 'IEPSAS-Kosice',
#  '147.231.25.192': 'praguelcg2',
#  '148.187.64.25': 'CSCS-LCG2',
#  '148.6.8.251': 'BUDAPEST',
#  '149.165.225.223': 'MWT2',
#  '150.244.247.2': 'UAM-LCG2',
#  '152.84.101.141': 'UnknownSite',
#  '157.82.112.68': 'TOKYO-LCG2',
#  '158.195.14.26': 'FMPhI-UNIBA',
#  '159.93.226.102': 'JINR-LCG2',
#  '159.93.229.151': 'JINR-T1',
#  '161.116.81.235': 'UnknownSite',
#  '163.1.5.210': 'UKI-SOUTHGRID-OX-HEP',
#  '165.91.55.4': 'UnknownSite',
#  '169.228.130.40': 'UnknownSite',
#  '18.12.1.171': 'UnknownSite',
#  '192.108.47.12': 'FZK-LCG2',
#  '192.111.108.112': 'Vanderbilt',
#  '192.114.101.125': 'TECHNION-HEP',
#  '192.12.15.26': 'BNL-ATLAS',
#  '192.135.14.32': 'INFN-MILANO-ATLASC',
#  '192.170.227.160': 'MWT2',
#  '192.231.127.41': 'Australia-ATLAS',
#  '192.41.230.59': 'AGLT2',
#  '192.41.236.31': 'AGLT2',
#  '192.5.207.251': 'BU_ATLAS_Tier2',
#  '192.54.207.250': 'GRIF',
#  '193.109.172.188': 'pic',
#  '193.136.75.146': 'NCG-INGRID-PT',
#  '193.144.80.12': 'UnknownSite',
#  '193.146.75.138': 'IFCA-LCG2',
#  '193.205.76.76': 'UnknownSite',
#  '193.206.93.45': 'UnknownSite',
#  '193.239.180.211': 'UnknownSite',
#  '193.48.83.165': 'IN2P3-LPSC',
#  '193.48.99.76': 'IN2P3-CC',
#  '193.60.193.3': 'UKI-SCOTGRID-DURHAM',
#  '193.62.56.9': 'UKI-SOUTHGRID-BHAM-HEP',
#  '194.190.165.192': 'RU-Protvino-IHEP',
#  '194.36.11.38': 'UKI-LT2-QMUL',
#  '194.80.35.169': 'UKI-NORTHGRID-LANCS-HEP',
#  '194.85.69.75': 'ITEP',
#  '195.194.105.178': 'UKI-NORTHGRID-MAN-HEP',
#  '200.136.80.20': 'SPRACE',
#  '200.17.30.135': 'UnknownSite',
#  '202.122.32.170': 'BEIJING-LCG2',
#  '206.12.154.60': 'CA-VICTORIA-WESTGRID-T2',
#  '206.12.24.251': 'SFU-LCG2',
#  '206.12.9.2': 'TRIUMF-LCG2',
#  '212.191.227.174': 'CYFRONET-LCG2',
#  '62.40.126.129': 'UnknownSite',
#  '72.36.96.4': 'MWT2',
#  '81.180.86.38': 'RO-02-NIPNE',
#  '81.180.86.64': 'RO-07-NIPNE',
#  '85.122.31.74': 'RO-16-UAIC',
#  '90.147.66.50': 'UnknownSite',
#  '90.147.67.252': 'INFN-NAPOLI-ATLAS'}

# %%
site_name_ip = {}

for ip in site_ip_name:
    name = site_ip_name[ip]
    if name in site_name_ip:
        site_name_ip[name].append(ip)
    else:
        site_name_ip[name] = [ip]

site_name_ip
# Out:
# {'AGLT2': ['192.41.236.31', '192.41.230.59'],
#  'Australia-ATLAS': ['192.231.127.41'],
#  'BEIJING-LCG2': ['202.122.32.170'],
#  'BNL-ATLAS': ['192.12.15.26'],
#  'BUDAPEST': ['148.6.8.251'],
#  'BU_ATLAS_Tier2': ['192.5.207.251'],
#  'CA-MCGILL-CLUMEQ-T2': ['132.206.245.252'],
#  'CA-SCINET-T2': ['142.150.19.61'],
#  'CA-VICTORIA-WESTGRID-T2': ['206.12.154.60'],
#  'CERN-PROD': ['128.142.223.247'],
#  'CSCS-LCG2': ['148.187.64.25'],
#  'CYFRONET-LCG2': ['212.191.227.174'],
#  'DESY-HH': ['131.169.98.30'],
#  'DESY-ZN': ['141.34.200.28'],
#  'EELA-UTFSM': ['146.83.90.7'],
#  'FI_HIP_T2': ['109.105.125.232'],
#  'FMPhI-UNIBA': ['158.195.14.26'],
#  'FZK-LCG2': ['192.108.47.12'],
#  'GLOW': ['144.92.180.75'],
#  'GRIF': ['134.158.132.200',
#   '192.54.207.250',
#   '134.158.159.85',
#   '134.158.73.243'],
#  'IEPSAS-Kosice': ['147.213.204.112'],
#  'IFCA-LCG2': ['193.146.75.138'],
#  'IFIC-LCG2': ['147.156.116.40'],
#  'IN2P3-CC': ['193.48.99.76'],
#  'IN2P3-CPPM': ['134.158.20.192'],
#  'IN2P3-LAPP': ['134.158.103.10'],
#  'IN2P3-LPC': ['134.158.123.183'],
#  'IN2P3-LPSC': ['193.48.83.165'],
#  'INDIACMS-TIFR': ['144.16.111.26'],
#  'INFN-MILANO-ATLASC': ['192.135.14.32'],
#  'INFN-NAPOLI-ATLAS': ['90.147.67.252'],
#  'INFN-ROMA1': ['141.108.35.18'],
#  'INFN-T1': ['131.154.254.12'],
#  'ITEP': ['194.85.69.75'],
#  'JINR-LCG2': ['159.93.226.102'],
#  'JINR-T1': ['159.93.229.151'],
#  'MWT2': ['192.170.227.160', '149.165.225.223', '72.36.96.4'],
#  'NCG-INGRID-PT': ['193.136.75.146'],
#  'NDGF-T1': ['109.105.124.86'],
#  'Nebraska': ['129.93.239.148'],
#  'OU_OCHEP_SWT2': ['129.15.40.231'],
#  'RAL-LCG2': ['130.246.176.109'],
#  'RO-02-NIPNE': ['81.180.86.38'],
#  'RO-07-NIPNE': ['81.180.86.64'],
#  'RO-16-UAIC': ['85.122.31.74'],
#  'RU-Protvino-IHEP': ['194.190.165.192'],
#  'SARA-MATRIX': ['145.100.17.8'],
#  'SFU-LCG2': ['206.12.24.251'],
#  'SPRACE': ['200.136.80.20'],
#  'TECHNION-HEP': ['192.114.101.125'],
#  'TOKYO-LCG2': ['157.82.112.68'],
#  'TRIUMF-LCG2': ['206.12.9.2'],
#  'Taiwan-LCG2': ['117.103.105.191'],
#  'UAM-LCG2': ['150.244.247.2'],
#  'UFlorida-HPC': ['128.227.221.44'],
#  'UKI-LT2-QMUL': ['194.36.11.38'],
#  'UKI-NORTHGRID-LANCS-HEP': ['194.80.35.169'],
#  'UKI-NORTHGRID-LIV-HEP': ['138.253.60.82'],
#  'UKI-NORTHGRID-MAN-HEP': ['195.194.105.178'],
#  'UKI-NORTHGRID-SHEF-HEP': ['143.167.3.116'],
#  'UKI-SCOTGRID-DURHAM': ['193.60.193.3'],
#  'UKI-SCOTGRID-ECDF': ['129.215.213.70'],
#  'UKI-SOUTHGRID-BHAM-HEP': ['193.62.56.9'],
#  'UKI-SOUTHGRID-BRIS-HEP': ['137.222.74.15'],
#  'UKI-SOUTHGRID-CAM-HEP': ['131.111.66.196'],
#  'UKI-SOUTHGRID-OX-HEP': ['163.1.5.210'],
#  'UKI-SOUTHGRID-RALPP': ['130.246.47.129'],
#  'UNI-FREIBURG': ['132.230.202.235'],
#  'UTA_SWT2': ['129.107.255.29'],
#  'UnknownSite': ['165.91.55.4',
#   '131.225.205.12',
#   '62.40.126.129',
#   '169.228.130.40',
#   '193.144.80.12',
#   '152.84.101.141',
#   '193.206.93.45',
#   '193.205.76.76',
#   '200.17.30.135',
#   '134.61.24.193',
#   '193.239.180.211',
#   '134.75.125.241',
#   '161.116.81.235',
#   '131.243.24.11',
#   '90.147.66.50',
#   '143.215.129.69',
#   '18.12.1.171'],
#  'Vanderbilt': ['192.111.108.112'],
#  'WT2': ['134.79.118.72'],
#  'pic': ['193.109.172.188'],
#  'praguelcg2': ['147.231.25.192'],
#  'wuppertalprod': ['132.195.125.213']}

# %% [markdown]
# ## Generate the suitable representation of old and new packet loss alarms, based on ip

# %%
srcIP_destIP_alarm_new = set()
srcIP_destIP_alarm_old = set()

for hit in hits_new:
    info = hit['_source']
    srcIP_destIP_alarm_new.add('{}_{}'.format(info['src'], info['dest']))

for hit in hits_old:
    info = hit['_source']
    srcIP_destIP_alarm_old.add('{}_{}'.format(info['src'], info['dest']))

# %% [markdown]
# ## Distinguish the three kinds of scenarios, as described at the beginning of this notebook

# %%
alarm_kind_new_appear = set()
alarm_kind_old_disappear = set()
alarm_kind_exist_as_before = set()

for alarm in srcIP_destIP_alarm_old:
    if alarm not in srcIP_destIP_alarm_new:
        alarm_kind_old_disappear.add(alarm)
    else:
        alarm_kind_exist_as_before.add(alarm)

for alarm in srcIP_destIP_alarm_new:
    if alarm not in srcIP_destIP_alarm_old:
        alarm_kind_new_appear.add(alarm)
    else:
        alarm_kind_exist_as_before.add(alarm)

print('Number of new appear alarm: {}'.format(len(alarm_kind_new_appear)))
print('Number of old disappear alarm: {}'.format(len(alarm_kind_old_disappear)))
print('Number of exist as before alarm: {}'.format(len(alarm_kind_exist_as_before)))
print()
print('Number of currently existing alarm (i.e. what newly registered users will receive, == 1 + 3): {}'.format(len(srcIP_destIP_alarm_new)))
# Out:
# Number of new appear alarm: 51
# Number of old disappear alarm: 67
# Number of exist as before alarm: 188
#
# Number of currently existing alarm (i.e. what newly registered users will receive, == 1 + 3): 239

# %% [markdown]
# ## The variable user_alert_all holds all the needed info to send an email to a specific user

# %%
user_alert_all = {}

for user in google.getUserInfo():
    user_info = {}
    user_info['email'] = user[0]
    user_info['fullname'] = user[1]
    user_info['link'] = user[2]
    user_info['freshuser'] = user[3]
    user_info['alerts'] = []
    user_alert_all[user[0]] = user_info    # email should be unique globally, so it is used as key

user_alert_all
# Out:
# {'LINCOLNB@UCHICAGO.EDU': {'alerts': [],
#   'email': 'LINCOLNB@UCHICAGO.EDU',
#   'freshuser': False,
#   'fullname': 'Lincoln Bryant',
#   'link': 'https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnufEkC3ZkGEJM7YrjIK5M9zZCa8Fg0C58snIuKzECJRbScqS5po96bBVKA'},
#  'elancon@bnl.gov': {'alerts': [],
#   'email': 'elancon@bnl.gov',
#   'freshuser': False,
#   'fullname': 'Eric Lancon',
#   'link': 'https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnuf_umrjRScBiYvJ_aUfteZA2eiV-yUK9DMa3q7VefVJtC5bEQnNSPOg4A'},
#  'ilijav@gmail.com': {'alerts': [],
#   'email': 'ilijav@gmail.com',
#   'freshuser': False,
#   'fullname': 'Ilija Vukotic',
#   'link': 'https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnuezuteui57-PrydNWrUuZf5fmChNqtjEeDab6h5V6lik_-x790uKsPu5Q'},
#  'ivukotic@cern.ch': {'alerts': [],
#   'email': 'ivukotic@cern.ch',
#   'freshuser': False,
#   'fullname': 'Ilija Vukotic',
#   'link': 'https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnuf8m2xilpIjaTt3jlTf-1Fw9r42smGVmYATJ2Jap7Y_9Ym0hL_AzhCZIQ'},
#  'marian.babik@cern.ch': {'alerts': [],
#   'email': 'marian.babik@cern.ch',
#   'freshuser': False,
#   'fullname': 'Marian Babik',
#   'link': 'https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnudgR9Vt18--Jd7nn_VU0BgZZVVjGrfGPDf5qS7pUrxmkFMUcNPVVUGVtw'},
#  'xinran@uchicago.edu': {'alerts': [],
#   'email': 'xinran@uchicago.edu',
#   'freshuser': False,
#   'fullname': 'Xinran Wang',
#   'link': 'https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnufsgT2puMcVDEaB3G7iKg_oQghurim7L-4_uA0f7ce4THFb8LEf6oUZRQ'}}

# %% [markdown]
# ## Generate the list about which users are interested in packet loss alerts for which sites and their sites are _source_ sites

# %%
interest_packet_loss_source = {}

def reg_interest_src(sitename, email):
    if sitename in interest_packet_loss_source:
        interest_packet_loss_source[sitename].append(email)
    else:
        interest_packet_loss_source[sitename] = [email]

taskName = 'Packet loss increase for link(s) where your site is a source'

subscribe_records = google.getSubscribers_withSiteName(taskName)

for record in subscribe_records:
    sitenames = record[3]
    email = record[1]
    if len(sitenames) == 0:   # blank, so all sites
        reg_interest_src('*', email)
    else:
        for sitename in sitenames:
            reg_interest_src(sitename, email)

interest_packet_loss_source
# Out:
# {'*': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  'CERN-PROD': ['xinran@uchicago.edu'],
#  'MWT2': ['LINCOLNB@UCHICAGO.EDU', 'xinran@uchicago.edu'],
#  'SFU-LCG2': ['xinran@uchicago.edu']}

# %% [markdown]
# ## Convert from site name -> email to site ip -> email

# %%
interest_packet_loss_source_ip = {}

def reg_interest_src_ip(siteip, email):
    if siteip in interest_packet_loss_source_ip:
        interest_packet_loss_source_ip[siteip].append(email)
    else:
        interest_packet_loss_source_ip[siteip] = [email]

for sitename in interest_packet_loss_source:
    if sitename == '*':
        for ip in site_ip_name:
            for email in interest_packet_loss_source[sitename]:
                reg_interest_src_ip(ip, email)
    else:
        for ip in site_name_ip[sitename]:
            for email in interest_packet_loss_source[sitename]:
                reg_interest_src_ip(ip, email)

interest_packet_loss_source_ip
# Out:
# {'109.105.124.86': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '109.105.125.232': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '117.103.105.191': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '128.142.223.247': ['elancon@bnl.gov',
#   'marian.babik@cern.ch',
#   'xinran@uchicago.edu'],
#  '128.227.221.44': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '129.107.255.29': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '129.15.40.231': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '129.215.213.70': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '129.93.239.148': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '130.246.176.109': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '130.246.47.129': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '131.111.66.196': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '131.154.254.12': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '131.169.98.30': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '131.225.205.12': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '131.243.24.11': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '132.195.125.213': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '132.206.245.252': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '132.230.202.235': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '134.158.103.10': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '134.158.123.183': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '134.158.132.200': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '134.158.159.85': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '134.158.20.192': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '134.158.73.243': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '134.61.24.193': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '134.75.125.241': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '134.79.118.72': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '137.222.74.15': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '138.253.60.82': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '141.108.35.18': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '141.34.200.28': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '142.150.19.61': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '143.167.3.116': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '143.215.129.69': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '144.16.111.26': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '144.92.180.75': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '145.100.17.8': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '146.83.90.7': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '147.156.116.40': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '147.213.204.112': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '147.231.25.192': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '148.187.64.25': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '148.6.8.251': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '149.165.225.223': ['LINCOLNB@UCHICAGO.EDU',
#   'xinran@uchicago.edu',
#   'elancon@bnl.gov',
#   'marian.babik@cern.ch'],
#  '150.244.247.2': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '152.84.101.141': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '157.82.112.68': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '158.195.14.26': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '159.93.226.102': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '159.93.229.151': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '161.116.81.235': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '163.1.5.210': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '165.91.55.4': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '169.228.130.40': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '18.12.1.171': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '192.108.47.12': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '192.111.108.112': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '192.114.101.125': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '192.12.15.26': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '192.135.14.32': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '192.170.227.160': ['LINCOLNB@UCHICAGO.EDU',
#   'xinran@uchicago.edu',
#   'elancon@bnl.gov',
#   'marian.babik@cern.ch'],
#  '192.231.127.41': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '192.41.230.59': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '192.41.236.31': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '192.5.207.251': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '192.54.207.250': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '193.109.172.188': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '193.136.75.146': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '193.144.80.12': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '193.146.75.138': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '193.205.76.76': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '193.206.93.45': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '193.239.180.211': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '193.48.83.165': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '193.48.99.76': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '193.60.193.3': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '193.62.56.9': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '194.190.165.192': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '194.36.11.38': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '194.80.35.169': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '194.85.69.75': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '195.194.105.178': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '200.136.80.20': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '200.17.30.135': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '202.122.32.170': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '206.12.154.60': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '206.12.24.251': ['xinran@uchicago.edu',
#   'elancon@bnl.gov',
#   'marian.babik@cern.ch'],
#  '206.12.9.2': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '212.191.227.174': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '62.40.126.129': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '72.36.96.4': ['LINCOLNB@UCHICAGO.EDU',
#   'xinran@uchicago.edu',
#   'elancon@bnl.gov',
#   'marian.babik@cern.ch'],
#  '81.180.86.38': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '81.180.86.64': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '85.122.31.74': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '90.147.66.50': ['elancon@bnl.gov', 'marian.babik@cern.ch'],
#  '90.147.67.252': ['elancon@bnl.gov', 'marian.babik@cern.ch']}

# %% [markdown]
# ## Iterate over all alarms in the three scenarios, and generate the info for emails

# %%
for alarm in alarm_kind_new_appear:
    src_ip = alarm.split('_')[0]    # Note that [0] is source ip, [1] is destination ip
    dest_ip = alarm.split('_')[1]
    for email in interest_packet_loss_source_ip[src_ip]:    # when dealing with as_destination_site, change this line accordingly
        line = '[New problem appeared]  ' + taskName
        line += '\n\n'
        line += '    From {} ({}) to {} ({})'.format(site_ip_name[src_ip], src_ip, site_ip_name[dest_ip], dest_ip)
        line += '\n'
        print(email)
        print(line)
        user_alert_all[email]['alerts'].append(line)
# Out:
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to INFN-ROMA1 (141.108.35.18)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to INFN-ROMA1 (141.108.35.18)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CSCS-LCG2 (148.187.64.25) to OU_OCHEP_SWT2 (129.15.40.231)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CSCS-LCG2 (148.187.64.25) to OU_OCHEP_SWT2 (129.15.40.231)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CYFRONET-LCG2 (212.191.227.174) to UnknownSite (161.116.81.235)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CYFRONET-LCG2 (212.191.227.174) to UnknownSite (161.116.81.235)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to UKI-NORTHGRID-LIV-HEP (138.253.60.82)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to UKI-NORTHGRID-LIV-HEP (138.253.60.82)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From AGLT2 (192.41.230.59) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From AGLT2 (192.41.230.59) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-MCGILL-CLUMEQ-T2 (132.206.245.252) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-MCGILL-CLUMEQ-T2 (132.206.245.252) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CSCS-LCG2 (148.187.64.25) to ITEP (194.85.69.75)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CSCS-LCG2 (148.187.64.25) to ITEP (194.85.69.75)
#
# xinran@uchicago.edu
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SFU-LCG2 (206.12.24.251) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SFU-LCG2 (206.12.24.251) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SFU-LCG2 (206.12.24.251) to RAL-LCG2 (130.246.176.109)
#
# LINCOLNB@UCHICAGO.EDU
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (149.165.225.223) to BEIJING-LCG2 (202.122.32.170)
#
# xinran@uchicago.edu
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (149.165.225.223) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (149.165.225.223) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (149.165.225.223) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From JINR-T1 (159.93.229.151) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From JINR-T1 (159.93.229.151) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From AGLT2 (192.41.236.31) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From AGLT2 (192.41.236.31) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CERN-PROD (128.142.223.247) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CERN-PROD (128.142.223.247) to BEIJING-LCG2 (202.122.32.170)
#
# xinran@uchicago.edu
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CERN-PROD (128.142.223.247) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From BEIJING-LCG2 (202.122.32.170) to INFN-ROMA1 (141.108.35.18)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From BEIJING-LCG2 (202.122.32.170) to INFN-ROMA1 (141.108.35.18)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-CAM-HEP (131.111.66.196) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-CAM-HEP (131.111.66.196) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From GLOW (144.92.180.75) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From GLOW (144.92.180.75) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From FMPhI-UNIBA (158.195.14.26) to TRIUMF-LCG2 (206.12.9.2)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From FMPhI-UNIBA (158.195.14.26) to TRIUMF-LCG2 (206.12.9.2)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From DESY-HH (131.169.98.30) to UnknownSite (62.40.126.129)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From DESY-HH (131.169.98.30) to UnknownSite (62.40.126.129)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SPRACE (200.136.80.20) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SPRACE (200.136.80.20) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From Nebraska (129.93.239.148) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From Nebraska (129.93.239.148) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From Vanderbilt (192.111.108.112) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From Vanderbilt (192.111.108.112) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-BHAM-HEP (193.62.56.9) to INFN-MILANO-ATLASC (192.135.14.32)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-BHAM-HEP (193.62.56.9) to INFN-MILANO-ATLASC (192.135.14.32)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CYFRONET-LCG2 (212.191.227.174) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CYFRONET-LCG2 (212.191.227.174) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From BU_ATLAS_Tier2 (192.5.207.251) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From BU_ATLAS_Tier2 (192.5.207.251) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to UnknownSite (161.116.81.235)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to UnknownSite (161.116.81.235)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (152.84.101.141) to UnknownSite (161.116.81.235)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (152.84.101.141) to UnknownSite (161.116.81.235)
#
# LINCOLNB@UCHICAGO.EDU
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to BEIJING-LCG2 (202.122.32.170)
#
# xinran@uchicago.edu
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UTA_SWT2 (129.107.255.29) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UTA_SWT2 (129.107.255.29) to BEIJING-LCG2 (202.122.32.170)
#
# xinran@uchicago.edu
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SFU-LCG2 (206.12.24.251) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SFU-LCG2 (206.12.24.251) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SFU-LCG2 (206.12.24.251) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to TRIUMF-LCG2 (206.12.9.2)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to TRIUMF-LCG2 (206.12.9.2)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UFlorida-HPC (128.227.221.44) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UFlorida-HPC (128.227.221.44) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From GRIF (192.54.207.250) to UnknownSite (161.116.81.235)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From GRIF (192.54.207.250) to UnknownSite (161.116.81.235)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From FZK-LCG2 (192.108.47.12) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From FZK-LCG2 (192.108.47.12) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-SCINET-T2 (142.150.19.61) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-SCINET-T2 (142.150.19.61) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From INDIACMS-TIFR (144.16.111.26) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From INDIACMS-TIFR (144.16.111.26) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to INFN-ROMA1 (141.108.35.18)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to INFN-ROMA1 (141.108.35.18)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-CAM-HEP (131.111.66.196) to UnknownSite (161.116.81.235)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-CAM-HEP (131.111.66.196) to UnknownSite (161.116.81.235)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (18.12.1.171) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (18.12.1.171) to BEIJING-LCG2 (202.122.32.170)
#
# LINCOLNB@UCHICAGO.EDU
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to RAL-LCG2 (130.246.176.109)
#
# xinran@uchicago.edu
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to RO-16-UAIC (85.122.31.74)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to RO-16-UAIC (85.122.31.74)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (152.84.101.141) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (152.84.101.141) to RAL-LCG2 (130.246.176.109)
#
# LINCOLNB@UCHICAGO.EDU
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# xinran@uchicago.edu
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From EELA-UTFSM (146.83.90.7) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From EELA-UTFSM (146.83.90.7) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CYFRONET-LCG2 (212.191.227.174) to INFN-ROMA1 (141.108.35.18)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CYFRONET-LCG2 (212.191.227.174) to INFN-ROMA1 (141.108.35.18)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From GRIF (134.158.132.200) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From GRIF (134.158.132.200) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From BEIJING-LCG2 (202.122.32.170) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From BEIJING-LCG2 (202.122.32.170) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to Taiwan-LCG2 (117.103.105.191)
#
# marian.babik@cern.ch
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to Taiwan-LCG2 (117.103.105.191)

# %%
for alarm in alarm_kind_old_disappear:
    src_ip = alarm.split('_')[0]    # Note that [0] is source ip, [1] is destination ip
    dest_ip = alarm.split('_')[1]
    for email in interest_packet_loss_source_ip[src_ip]:    # when dealing with as_destination_site, change this line accordingly
        line = '[Old problem disappeared]  ' + taskName
        line += '\n\n'
        line += '    From {} ({}) to {} ({})'.format(site_ip_name[src_ip], src_ip, site_ip_name[dest_ip], dest_ip)
        line += '\n'
        print(email)
        print(line)
        user_alert_all[email]['alerts'].append(line)
# Out:
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From praguelcg2 (147.231.25.192) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From praguelcg2 (147.231.25.192) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-VICTORIA-WESTGRID-T2 (206.12.154.60) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-VICTORIA-WESTGRID-T2 (206.12.154.60) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From JINR-T1 (159.93.229.151) to INDIACMS-TIFR (144.16.111.26)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From JINR-T1 (159.93.229.151) to INDIACMS-TIFR (144.16.111.26)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to UKI-SOUTHGRID-OX-HEP (163.1.5.210)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to UKI-SOUTHGRID-OX-HEP (163.1.5.210)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BNL-ATLAS (192.12.15.26) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BNL-ATLAS (192.12.15.26) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BU_ATLAS_Tier2 (192.5.207.251) to ITEP (194.85.69.75)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BU_ATLAS_Tier2 (192.5.207.251) to ITEP (194.85.69.75)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SCOTGRID-DURHAM (193.60.193.3) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SCOTGRID-DURHAM (193.60.193.3) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CSCS-LCG2 (148.187.64.25)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CSCS-LCG2 (148.187.64.25)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to IN2P3-LPSC (193.48.83.165)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to IN2P3-LPSC (193.48.83.165)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From TOKYO-LCG2 (157.82.112.68) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From TOKYO-LCG2 (157.82.112.68) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to ITEP (194.85.69.75)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to ITEP (194.85.69.75)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to FMPhI-UNIBA (158.195.14.26)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to FMPhI-UNIBA (158.195.14.26)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CERN-PROD (128.142.223.247)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CERN-PROD (128.142.223.247)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to GRIF (192.54.207.250)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to GRIF (192.54.207.250)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (143.215.129.69) to UnknownSite (131.243.24.11)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (143.215.129.69) to UnknownSite (131.243.24.11)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-LAPP (134.158.103.10) to UnknownSite (193.206.93.45)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-LAPP (134.158.103.10) to UnknownSite (193.206.93.45)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IEPSAS-Kosice (147.213.204.112)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IEPSAS-Kosice (147.213.204.112)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (193.206.93.45) to NCG-INGRID-PT (193.136.75.146)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (193.206.93.45) to NCG-INGRID-PT (193.136.75.146)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IFIC-LCG2 (147.156.116.40)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IFIC-LCG2 (147.156.116.40)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-07-NIPNE (81.180.86.64) to IEPSAS-Kosice (147.213.204.112)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-07-NIPNE (81.180.86.64) to IEPSAS-Kosice (147.213.204.112)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (161.116.81.235)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (161.116.81.235)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IN2P3-CPPM (134.158.20.192)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IN2P3-CPPM (134.158.20.192)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to RO-16-UAIC (85.122.31.74)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to RO-16-UAIC (85.122.31.74)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-VICTORIA-WESTGRID-T2 (206.12.154.60) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-VICTORIA-WESTGRID-T2 (206.12.154.60) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-02-NIPNE (81.180.86.38) to FMPhI-UNIBA (158.195.14.26)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-02-NIPNE (81.180.86.38) to FMPhI-UNIBA (158.195.14.26)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to EELA-UTFSM (146.83.90.7)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to EELA-UTFSM (146.83.90.7)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CA-MCGILL-CLUMEQ-T2 (132.206.245.252)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CA-MCGILL-CLUMEQ-T2 (132.206.245.252)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IFCA-LCG2 (193.146.75.138) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IFCA-LCG2 (193.146.75.138) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (18.12.1.171)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (18.12.1.171)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-BRIS-HEP (137.222.74.15) to AGLT2 (192.41.236.31)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-BRIS-HEP (137.222.74.15) to AGLT2 (192.41.236.31)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-CPPM (134.158.20.192) to UnknownSite (161.116.81.235)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-CPPM (134.158.20.192) to UnknownSite (161.116.81.235)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to IEPSAS-Kosice (147.213.204.112)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to IEPSAS-Kosice (147.213.204.112)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-02-NIPNE (81.180.86.38) to IEPSAS-Kosice (147.213.204.112)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-02-NIPNE (81.180.86.38) to IEPSAS-Kosice (147.213.204.112)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to SFU-LCG2 (206.12.24.251)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to SFU-LCG2 (206.12.24.251)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to RO-16-UAIC (85.122.31.74)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to RO-16-UAIC (85.122.31.74)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to IFIC-LCG2 (147.156.116.40)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to IFIC-LCG2 (147.156.116.40)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SCOTGRID-ECDF (129.215.213.70) to UnknownSite (161.116.81.235)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SCOTGRID-ECDF (129.215.213.70) to UnknownSite (161.116.81.235)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-CPPM (134.158.20.192) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-CPPM (134.158.20.192) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to GRIF (134.158.73.243)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to GRIF (134.158.73.243)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to AGLT2 (192.41.236.31)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to AGLT2 (192.41.236.31)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (193.239.180.211)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (193.239.180.211)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to BEIJING-LCG2 (202.122.32.170)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to BEIJING-LCG2 (202.122.32.170)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From TECHNION-HEP (192.114.101.125) to UnknownSite (161.116.81.235)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From TECHNION-HEP (192.114.101.125) to UnknownSite (161.116.81.235)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BNL-ATLAS (192.12.15.26) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BNL-ATLAS (192.12.15.26) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (193.206.93.45) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (193.206.93.45) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SCOTGRID-ECDF (129.215.213.70) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SCOTGRID-ECDF (129.215.213.70) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to UFlorida-HPC (128.227.221.44)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to UFlorida-HPC (128.227.221.44)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (193.144.80.12)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (193.144.80.12)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to FMPhI-UNIBA (158.195.14.26)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to FMPhI-UNIBA (158.195.14.26)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to DESY-ZN (141.34.200.28)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to DESY-ZN (141.34.200.28)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CA-SCINET-T2 (142.150.19.61)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CA-SCINET-T2 (142.150.19.61)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to SARA-MATRIX (145.100.17.8)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to SARA-MATRIX (145.100.17.8)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UKI-NORTHGRID-LIV-HEP (138.253.60.82)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UKI-NORTHGRID-LIV-HEP (138.253.60.82)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UKI-SOUTHGRID-RALPP (130.246.47.129)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UKI-SOUTHGRID-RALPP (130.246.47.129)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to RU-Protvino-IHEP (194.190.165.192)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to RU-Protvino-IHEP (194.190.165.192)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BNL-ATLAS (192.12.15.26) to ITEP (194.85.69.75)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BNL-ATLAS (192.12.15.26) to ITEP (194.85.69.75)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From Taiwan-LCG2 (117.103.105.191) to RAL-LCG2 (130.246.176.109)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From Taiwan-LCG2 (117.103.105.191) to RAL-LCG2 (130.246.176.109)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-07-NIPNE (81.180.86.64) to FMPhI-UNIBA (158.195.14.26)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-07-NIPNE (81.180.86.64) to FMPhI-UNIBA (158.195.14.26)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (131.225.205.12)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (131.225.205.12)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IN2P3-CC (193.48.99.76)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IN2P3-CC (193.48.99.76)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From Taiwan-LCG2 (117.103.105.191) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From Taiwan-LCG2 (117.103.105.191) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-CPPM (134.158.20.192) to IEPSAS-Kosice (147.213.204.112)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-CPPM (134.158.20.192) to IEPSAS-Kosice (147.213.204.112)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IFCA-LCG2 (193.146.75.138)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IFCA-LCG2 (193.146.75.138)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UTA_SWT2 (129.107.255.29) to TRIUMF-LCG2 (206.12.9.2)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UTA_SWT2 (129.107.255.29) to TRIUMF-LCG2 (206.12.9.2)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to BUDAPEST (148.6.8.251)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to BUDAPEST (148.6.8.251)
#
# elancon@bnl.gov
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From GRIF (192.54.207.250) to RO-16-UAIC (85.122.31.74)
#
# marian.babik@cern.ch
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From GRIF (192.54.207.250) to RO-16-UAIC (85.122.31.74)

# %%
for alarm in alarm_kind_exist_as_before:
    src_ip = alarm.split('_')[0]    # Note that [0] is source ip, [1] is destination ip
    dest_ip = alarm.split('_')[1]
    for email in interest_packet_loss_source_ip[src_ip]:    # when dealing with as_destination_site, change this line accordingly
        if user_alert_all[email]['freshuser']:
            line = '[Old problem continues]  ' + taskName
            line += '\n\n'
            line += '    From {} ({}) to {} ({})'.format(site_ip_name[src_ip], src_ip, site_ip_name[dest_ip], dest_ip)
            line += '\n'
            print(email)
            print(line)
            user_alert_all[email]['alerts'].append(line)

# %%
user_alert_all
# Out:
# {'LINCOLNB@UCHICAGO.EDU': {'alerts': ['[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (149.165.225.223) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (72.36.96.4) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (72.36.96.4) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (72.36.96.4) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n'],
#   'email': 'LINCOLNB@UCHICAGO.EDU',
#   'freshuser': False,
#   'fullname': 'Lincoln Bryant',
#   'link': 'https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnufEkC3ZkGEJM7YrjIK5M9zZCa8Fg0C58snIuKzECJRbScqS5po96bBVKA'},
#  'elancon@bnl.gov': {'alerts': ['[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to INFN-ROMA1 (141.108.35.18)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CSCS-LCG2 (148.187.64.25) to OU_OCHEP_SWT2 (129.15.40.231)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CYFRONET-LCG2 (212.191.227.174) to UnknownSite (161.116.81.235)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From OU_OCHEP_SWT2 (129.15.40.231) to UKI-NORTHGRID-LIV-HEP (138.253.60.82)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From AGLT2 (192.41.230.59) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CA-MCGILL-CLUMEQ-T2 (132.206.245.252) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CSCS-LCG2 (148.187.64.25) to ITEP (194.85.69.75)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From SFU-LCG2 (206.12.24.251) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (149.165.225.223) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From JINR-T1 (159.93.229.151) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From AGLT2 (192.41.236.31) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CERN-PROD (128.142.223.247) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From BEIJING-LCG2 (202.122.32.170) to INFN-ROMA1 (141.108.35.18)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SOUTHGRID-CAM-HEP (131.111.66.196) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From OU_OCHEP_SWT2 (129.15.40.231) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From GLOW (144.92.180.75) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From FMPhI-UNIBA (158.195.14.26) to TRIUMF-LCG2 (206.12.9.2)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From DESY-HH (131.169.98.30) to UnknownSite (62.40.126.129)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From SPRACE (200.136.80.20) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From Nebraska (129.93.239.148) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From Vanderbilt (192.111.108.112) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From RU-Protvino-IHEP (194.190.165.192) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SOUTHGRID-BHAM-HEP (193.62.56.9) to INFN-MILANO-ATLASC (192.135.14.32)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CYFRONET-LCG2 (212.191.227.174) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From BU_ATLAS_Tier2 (192.5.207.251) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to UnknownSite (161.116.81.235)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UnknownSite (152.84.101.141) to UnknownSite (161.116.81.235)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (72.36.96.4) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UTA_SWT2 (129.107.255.29) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From SFU-LCG2 (206.12.24.251) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to TRIUMF-LCG2 (206.12.9.2)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UFlorida-HPC (128.227.221.44) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From GRIF (192.54.207.250) to UnknownSite (161.116.81.235)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From FZK-LCG2 (192.108.47.12) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-16-UAIC (85.122.31.74) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CA-SCINET-T2 (142.150.19.61) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From INDIACMS-TIFR (144.16.111.26) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to INFN-ROMA1 (141.108.35.18)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-16-UAIC (85.122.31.74) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SOUTHGRID-CAM-HEP (131.111.66.196) to UnknownSite (161.116.81.235)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UnknownSite (18.12.1.171) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (72.36.96.4) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From OU_OCHEP_SWT2 (129.15.40.231) to RO-16-UAIC (85.122.31.74)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UnknownSite (152.84.101.141) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (72.36.96.4) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From EELA-UTFSM (146.83.90.7) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CYFRONET-LCG2 (212.191.227.174) to INFN-ROMA1 (141.108.35.18)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From GRIF (134.158.132.200) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From BEIJING-LCG2 (202.122.32.170) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to Taiwan-LCG2 (117.103.105.191)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From praguelcg2 (147.231.25.192) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From CA-VICTORIA-WESTGRID-T2 (206.12.154.60) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From JINR-T1 (159.93.229.151) to INDIACMS-TIFR (144.16.111.26)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RU-Protvino-IHEP (194.190.165.192) to UKI-SOUTHGRID-OX-HEP (163.1.5.210)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From BNL-ATLAS (192.12.15.26) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From BU_ATLAS_Tier2 (192.5.207.251) to ITEP (194.85.69.75)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SCOTGRID-DURHAM (193.60.193.3) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to CSCS-LCG2 (148.187.64.25)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-16-UAIC (85.122.31.74) to IN2P3-LPSC (193.48.83.165)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From TOKYO-LCG2 (157.82.112.68) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to ITEP (194.85.69.75)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-16-UAIC (85.122.31.74) to FMPhI-UNIBA (158.195.14.26)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to CERN-PROD (128.142.223.247)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to GRIF (192.54.207.250)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UnknownSite (143.215.129.69) to UnknownSite (131.243.24.11)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From IN2P3-LAPP (134.158.103.10) to UnknownSite (193.206.93.45)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to IEPSAS-Kosice (147.213.204.112)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UnknownSite (193.206.93.45) to NCG-INGRID-PT (193.136.75.146)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to IFIC-LCG2 (147.156.116.40)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-07-NIPNE (81.180.86.64) to IEPSAS-Kosice (147.213.204.112)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UnknownSite (161.116.81.235)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to IN2P3-CPPM (134.158.20.192)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to RO-16-UAIC (85.122.31.74)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From CA-VICTORIA-WESTGRID-T2 (206.12.154.60) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-02-NIPNE (81.180.86.38) to FMPhI-UNIBA (158.195.14.26)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From OU_OCHEP_SWT2 (129.15.40.231) to EELA-UTFSM (146.83.90.7)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to CA-MCGILL-CLUMEQ-T2 (132.206.245.252)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From IFCA-LCG2 (193.146.75.138) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UnknownSite (18.12.1.171)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SOUTHGRID-BRIS-HEP (137.222.74.15) to AGLT2 (192.41.236.31)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From IN2P3-CPPM (134.158.20.192) to UnknownSite (161.116.81.235)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-16-UAIC (85.122.31.74) to IEPSAS-Kosice (147.213.204.112)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-02-NIPNE (81.180.86.38) to IEPSAS-Kosice (147.213.204.112)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to SFU-LCG2 (206.12.24.251)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RU-Protvino-IHEP (194.190.165.192) to RO-16-UAIC (85.122.31.74)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-16-UAIC (85.122.31.74) to IFIC-LCG2 (147.156.116.40)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SCOTGRID-ECDF (129.215.213.70) to UnknownSite (161.116.81.235)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From IN2P3-CPPM (134.158.20.192) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to GRIF (134.158.73.243)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to AGLT2 (192.41.236.31)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UnknownSite (193.239.180.211)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From TECHNION-HEP (192.114.101.125) to UnknownSite (161.116.81.235)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From BNL-ATLAS (192.12.15.26) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UnknownSite (193.206.93.45) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SCOTGRID-ECDF (129.215.213.70) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RU-Protvino-IHEP (194.190.165.192) to UFlorida-HPC (128.227.221.44)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UnknownSite (193.144.80.12)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to FMPhI-UNIBA (158.195.14.26)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to DESY-ZN (141.34.200.28)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to CA-SCINET-T2 (142.150.19.61)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to SARA-MATRIX (145.100.17.8)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UKI-NORTHGRID-LIV-HEP (138.253.60.82)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UKI-SOUTHGRID-RALPP (130.246.47.129)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to RU-Protvino-IHEP (194.190.165.192)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From BNL-ATLAS (192.12.15.26) to ITEP (194.85.69.75)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From Taiwan-LCG2 (117.103.105.191) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-07-NIPNE (81.180.86.64) to FMPhI-UNIBA (158.195.14.26)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UnknownSite (131.225.205.12)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to IN2P3-CC (193.48.99.76)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From Taiwan-LCG2 (117.103.105.191) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From IN2P3-CPPM (134.158.20.192) to IEPSAS-Kosice (147.213.204.112)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to IFCA-LCG2 (193.146.75.138)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UTA_SWT2 (129.107.255.29) to TRIUMF-LCG2 (206.12.9.2)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to BUDAPEST (148.6.8.251)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From GRIF (192.54.207.250) to RO-16-UAIC (85.122.31.74)\n'],
#   'email': 'elancon@bnl.gov',
#   'freshuser': False,
#   'fullname': 'Eric Lancon',
#   'link': 'https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnuf_umrjRScBiYvJ_aUfteZA2eiV-yUK9DMa3q7VefVJtC5bEQnNSPOg4A'},
#  'ilijav@gmail.com': {'alerts': [],
#   'email': 'ilijav@gmail.com',
#   'freshuser': False,
#   'fullname': 'Ilija Vukotic',
#   'link': 'https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnuezuteui57-PrydNWrUuZf5fmChNqtjEeDab6h5V6lik_-x790uKsPu5Q'},
#  'ivukotic@cern.ch': {'alerts': [],
#   'email': 'ivukotic@cern.ch',
#   'freshuser': False,
#   'fullname': 'Ilija Vukotic',
#   'link': 'https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnuf8m2xilpIjaTt3jlTf-1Fw9r42smGVmYATJ2Jap7Y_9Ym0hL_AzhCZIQ'},
#  'marian.babik@cern.ch': {'alerts': ['[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to INFN-ROMA1 (141.108.35.18)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CSCS-LCG2 (148.187.64.25) to OU_OCHEP_SWT2 (129.15.40.231)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CYFRONET-LCG2 (212.191.227.174) to UnknownSite (161.116.81.235)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From OU_OCHEP_SWT2 (129.15.40.231) to UKI-NORTHGRID-LIV-HEP (138.253.60.82)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From AGLT2 (192.41.230.59) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CA-MCGILL-CLUMEQ-T2 (132.206.245.252) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CSCS-LCG2 (148.187.64.25) to ITEP (194.85.69.75)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From SFU-LCG2 (206.12.24.251) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (149.165.225.223) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From JINR-T1 (159.93.229.151) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From AGLT2 (192.41.236.31) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CERN-PROD (128.142.223.247) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From BEIJING-LCG2 (202.122.32.170) to INFN-ROMA1 (141.108.35.18)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SOUTHGRID-CAM-HEP (131.111.66.196) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From OU_OCHEP_SWT2 (129.15.40.231) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From GLOW (144.92.180.75) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From FMPhI-UNIBA (158.195.14.26) to TRIUMF-LCG2 (206.12.9.2)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From DESY-HH (131.169.98.30) to UnknownSite (62.40.126.129)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From SPRACE (200.136.80.20) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From Nebraska (129.93.239.148) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From Vanderbilt (192.111.108.112) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From RU-Protvino-IHEP (194.190.165.192) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SOUTHGRID-BHAM-HEP (193.62.56.9) to INFN-MILANO-ATLASC (192.135.14.32)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CYFRONET-LCG2 (212.191.227.174) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From BU_ATLAS_Tier2 (192.5.207.251) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to UnknownSite (161.116.81.235)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UnknownSite (152.84.101.141) to UnknownSite (161.116.81.235)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (72.36.96.4) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UTA_SWT2 (129.107.255.29) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From SFU-LCG2 (206.12.24.251) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to TRIUMF-LCG2 (206.12.9.2)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UFlorida-HPC (128.227.221.44) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From GRIF (192.54.207.250) to UnknownSite (161.116.81.235)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From FZK-LCG2 (192.108.47.12) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-16-UAIC (85.122.31.74) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CA-SCINET-T2 (142.150.19.61) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From INDIACMS-TIFR (144.16.111.26) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to INFN-ROMA1 (141.108.35.18)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-16-UAIC (85.122.31.74) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SOUTHGRID-CAM-HEP (131.111.66.196) to UnknownSite (161.116.81.235)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UnknownSite (18.12.1.171) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (72.36.96.4) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From OU_OCHEP_SWT2 (129.15.40.231) to RO-16-UAIC (85.122.31.74)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UnknownSite (152.84.101.141) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (72.36.96.4) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From EELA-UTFSM (146.83.90.7) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CYFRONET-LCG2 (212.191.227.174) to INFN-ROMA1 (141.108.35.18)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From GRIF (134.158.132.200) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From BEIJING-LCG2 (202.122.32.170) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to Taiwan-LCG2 (117.103.105.191)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From praguelcg2 (147.231.25.192) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From CA-VICTORIA-WESTGRID-T2 (206.12.154.60) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From JINR-T1 (159.93.229.151) to INDIACMS-TIFR (144.16.111.26)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RU-Protvino-IHEP (194.190.165.192) to UKI-SOUTHGRID-OX-HEP (163.1.5.210)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From BNL-ATLAS (192.12.15.26) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From BU_ATLAS_Tier2 (192.5.207.251) to ITEP (194.85.69.75)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SCOTGRID-DURHAM (193.60.193.3) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to CSCS-LCG2 (148.187.64.25)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-16-UAIC (85.122.31.74) to IN2P3-LPSC (193.48.83.165)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From TOKYO-LCG2 (157.82.112.68) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to ITEP (194.85.69.75)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-16-UAIC (85.122.31.74) to FMPhI-UNIBA (158.195.14.26)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to CERN-PROD (128.142.223.247)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to GRIF (192.54.207.250)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UnknownSite (143.215.129.69) to UnknownSite (131.243.24.11)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From IN2P3-LAPP (134.158.103.10) to UnknownSite (193.206.93.45)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to IEPSAS-Kosice (147.213.204.112)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UnknownSite (193.206.93.45) to NCG-INGRID-PT (193.136.75.146)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to IFIC-LCG2 (147.156.116.40)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-07-NIPNE (81.180.86.64) to IEPSAS-Kosice (147.213.204.112)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UnknownSite (161.116.81.235)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to IN2P3-CPPM (134.158.20.192)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to RO-16-UAIC (85.122.31.74)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From CA-VICTORIA-WESTGRID-T2 (206.12.154.60) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-02-NIPNE (81.180.86.38) to FMPhI-UNIBA (158.195.14.26)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From OU_OCHEP_SWT2 (129.15.40.231) to EELA-UTFSM (146.83.90.7)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to CA-MCGILL-CLUMEQ-T2 (132.206.245.252)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From IFCA-LCG2 (193.146.75.138) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UnknownSite (18.12.1.171)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SOUTHGRID-BRIS-HEP (137.222.74.15) to AGLT2 (192.41.236.31)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From IN2P3-CPPM (134.158.20.192) to UnknownSite (161.116.81.235)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-16-UAIC (85.122.31.74) to IEPSAS-Kosice (147.213.204.112)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-02-NIPNE (81.180.86.38) to IEPSAS-Kosice (147.213.204.112)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to SFU-LCG2 (206.12.24.251)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RU-Protvino-IHEP (194.190.165.192) to RO-16-UAIC (85.122.31.74)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-16-UAIC (85.122.31.74) to IFIC-LCG2 (147.156.116.40)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SCOTGRID-ECDF (129.215.213.70) to UnknownSite (161.116.81.235)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From IN2P3-CPPM (134.158.20.192) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to GRIF (134.158.73.243)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to AGLT2 (192.41.236.31)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UnknownSite (193.239.180.211)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From TECHNION-HEP (192.114.101.125) to UnknownSite (161.116.81.235)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From BNL-ATLAS (192.12.15.26) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UnknownSite (193.206.93.45) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UKI-SCOTGRID-ECDF (129.215.213.70) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RU-Protvino-IHEP (194.190.165.192) to UFlorida-HPC (128.227.221.44)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UnknownSite (193.144.80.12)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to FMPhI-UNIBA (158.195.14.26)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to DESY-ZN (141.34.200.28)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to CA-SCINET-T2 (142.150.19.61)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to SARA-MATRIX (145.100.17.8)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UKI-NORTHGRID-LIV-HEP (138.253.60.82)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UKI-SOUTHGRID-RALPP (130.246.47.129)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to RU-Protvino-IHEP (194.190.165.192)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From BNL-ATLAS (192.12.15.26) to ITEP (194.85.69.75)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From Taiwan-LCG2 (117.103.105.191) to RAL-LCG2 (130.246.176.109)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RO-07-NIPNE (81.180.86.64) to FMPhI-UNIBA (158.195.14.26)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to UnknownSite (131.225.205.12)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to IN2P3-CC (193.48.99.76)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From Taiwan-LCG2 (117.103.105.191) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From IN2P3-CPPM (134.158.20.192) to IEPSAS-Kosice (147.213.204.112)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to IFCA-LCG2 (193.146.75.138)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From UTA_SWT2 (129.107.255.29) to TRIUMF-LCG2 (206.12.9.2)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From RAL-LCG2 (130.246.176.109) to BUDAPEST (148.6.8.251)\n',
#    '[Old problem disappeared]  Packet loss increase for link(s) where your site is a source\n\n    From GRIF (192.54.207.250) to RO-16-UAIC (85.122.31.74)\n'],
#   'email': 'marian.babik@cern.ch',
#   'freshuser': False,
#   'fullname': 'Marian Babik',
#   'link': 'https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnudgR9Vt18--Jd7nn_VU0BgZZVVjGrfGPDf5qS7pUrxmkFMUcNPVVUGVtw'},
#  'xinran@uchicago.edu': {'alerts': ['[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From SFU-LCG2 (206.12.24.251) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (149.165.225.223) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From CERN-PROD (128.142.223.247) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (72.36.96.4) to BEIJING-LCG2 (202.122.32.170)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From SFU-LCG2 (206.12.24.251) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (72.36.96.4) to RAL-LCG2 (130.246.176.109)\n',
#    '[New problem appeared]  Packet loss increase for link(s) where your site is a source\n\n    From MWT2 (72.36.96.4) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)\n'],
#   'email': 'xinran@uchicago.edu',
#   'freshuser': False,
#   'fullname': 'Xinran Wang',
#   'link': 'https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnufsgT2puMcVDEaB3G7iKg_oQghurim7L-4_uA0f7ce4THFb8LEf6oUZRQ'}}

# %% [markdown]
# ## Dummy sendMail function for development purpose

# %%
def sendMailDummy(subject, to, body):
    if len(body['alerts']) == 0:
        print('======== Do not send alert email to {} as there is no alert for this user ========'.format(to))
    else:
        print('========= Send the following email to a user =========')
        print('------ Email subject ------')
        subject = 'Alert email customized for {}'.format(body['fullname'])
        print(subject)
        print('------ Email to -----------')
        print(to)
        print('------ Email body ---------')
        text = 'Hi {},\n\n'.format(body['fullname'])
        text += '    The following are all the alerts about packet loss that you are interested in:\n\n\n'
        for alert in body['alerts']:
            text += alert
            text += '\n\n'
        text += 'Thank you for using this system. If you want to update your settings or unsubscribe, please use this link: {}'.format(body['link'])
        text += '\n\nBest,\nThe team\n\n\n'
        print(text)
        print('======================================================')
    print()
    print()

# %% [markdown]
# ## Send out alert email customized for each user

# %%
for email in user_alert_all:
    sendMailDummy('auto', email, user_alert_all[email])
# Out:
# ======== Do not send alert email to ilijav@gmail.com as there is no alert for this user ========
#
#
# ========= Send the following email to a user =========
# ------ Email subject ------
# Alert email customized for Xinran Wang
# ------ Email to -----------
# xinran@uchicago.edu
# ------ Email body ---------
# Hi Xinran Wang,
#
#     The following are all the alerts about packet loss that you are interested in:
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SFU-LCG2 (206.12.24.251) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (149.165.225.223) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CERN-PROD (128.142.223.247) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SFU-LCG2 (206.12.24.251) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# Thank you for using this system. If you want to update your settings or unsubscribe, please use this link: https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnufsgT2puMcVDEaB3G7iKg_oQghurim7L-4_uA0f7ce4THFb8LEf6oUZRQ
#
# Best,
# The team
#
#
#
# ======================================================
#
#
# ========= Send the following email to a user =========
# ------ Email subject ------
# Alert email customized for Marian Babik
# ------ Email to -----------
# marian.babik@cern.ch
# ------ Email body ---------
# Hi Marian Babik,
#
#     The following are all the alerts about packet loss that you are interested in:
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to INFN-ROMA1 (141.108.35.18)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CSCS-LCG2 (148.187.64.25) to OU_OCHEP_SWT2 (129.15.40.231)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CYFRONET-LCG2 (212.191.227.174) to UnknownSite (161.116.81.235)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to UKI-NORTHGRID-LIV-HEP (138.253.60.82)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From AGLT2 (192.41.230.59) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-MCGILL-CLUMEQ-T2 (132.206.245.252) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CSCS-LCG2 (148.187.64.25) to ITEP (194.85.69.75)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SFU-LCG2 (206.12.24.251) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (149.165.225.223) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From JINR-T1 (159.93.229.151) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From AGLT2 (192.41.236.31) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CERN-PROD (128.142.223.247) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From BEIJING-LCG2 (202.122.32.170) to INFN-ROMA1 (141.108.35.18)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-CAM-HEP (131.111.66.196) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From GLOW (144.92.180.75) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From FMPhI-UNIBA (158.195.14.26) to TRIUMF-LCG2 (206.12.9.2)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From DESY-HH (131.169.98.30) to UnknownSite (62.40.126.129)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SPRACE (200.136.80.20) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From Nebraska (129.93.239.148) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From Vanderbilt (192.111.108.112) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-BHAM-HEP (193.62.56.9) to INFN-MILANO-ATLASC (192.135.14.32)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CYFRONET-LCG2 (212.191.227.174) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From BU_ATLAS_Tier2 (192.5.207.251) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to UnknownSite (161.116.81.235)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (152.84.101.141) to UnknownSite (161.116.81.235)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UTA_SWT2 (129.107.255.29) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SFU-LCG2 (206.12.24.251) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to TRIUMF-LCG2 (206.12.9.2)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UFlorida-HPC (128.227.221.44) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From GRIF (192.54.207.250) to UnknownSite (161.116.81.235)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From FZK-LCG2 (192.108.47.12) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-SCINET-T2 (142.150.19.61) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From INDIACMS-TIFR (144.16.111.26) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to INFN-ROMA1 (141.108.35.18)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-CAM-HEP (131.111.66.196) to UnknownSite (161.116.81.235)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (18.12.1.171) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to RO-16-UAIC (85.122.31.74)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (152.84.101.141) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From EELA-UTFSM (146.83.90.7) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CYFRONET-LCG2 (212.191.227.174) to INFN-ROMA1 (141.108.35.18)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From GRIF (134.158.132.200) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From BEIJING-LCG2 (202.122.32.170) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to Taiwan-LCG2 (117.103.105.191)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From praguelcg2 (147.231.25.192) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-VICTORIA-WESTGRID-T2 (206.12.154.60) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From JINR-T1 (159.93.229.151) to INDIACMS-TIFR (144.16.111.26)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to UKI-SOUTHGRID-OX-HEP (163.1.5.210)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BNL-ATLAS (192.12.15.26) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BU_ATLAS_Tier2 (192.5.207.251) to ITEP (194.85.69.75)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SCOTGRID-DURHAM (193.60.193.3) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CSCS-LCG2 (148.187.64.25)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to IN2P3-LPSC (193.48.83.165)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From TOKYO-LCG2 (157.82.112.68) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to ITEP (194.85.69.75)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to FMPhI-UNIBA (158.195.14.26)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CERN-PROD (128.142.223.247)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to GRIF (192.54.207.250)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (143.215.129.69) to UnknownSite (131.243.24.11)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-LAPP (134.158.103.10) to UnknownSite (193.206.93.45)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IEPSAS-Kosice (147.213.204.112)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (193.206.93.45) to NCG-INGRID-PT (193.136.75.146)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IFIC-LCG2 (147.156.116.40)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-07-NIPNE (81.180.86.64) to IEPSAS-Kosice (147.213.204.112)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (161.116.81.235)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IN2P3-CPPM (134.158.20.192)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to RO-16-UAIC (85.122.31.74)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-VICTORIA-WESTGRID-T2 (206.12.154.60) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-02-NIPNE (81.180.86.38) to FMPhI-UNIBA (158.195.14.26)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to EELA-UTFSM (146.83.90.7)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CA-MCGILL-CLUMEQ-T2 (132.206.245.252)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IFCA-LCG2 (193.146.75.138) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (18.12.1.171)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-BRIS-HEP (137.222.74.15) to AGLT2 (192.41.236.31)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-CPPM (134.158.20.192) to UnknownSite (161.116.81.235)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to IEPSAS-Kosice (147.213.204.112)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-02-NIPNE (81.180.86.38) to IEPSAS-Kosice (147.213.204.112)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to SFU-LCG2 (206.12.24.251)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to RO-16-UAIC (85.122.31.74)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to IFIC-LCG2 (147.156.116.40)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SCOTGRID-ECDF (129.215.213.70) to UnknownSite (161.116.81.235)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-CPPM (134.158.20.192) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to GRIF (134.158.73.243)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to AGLT2 (192.41.236.31)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (193.239.180.211)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to BEIJING-LCG2 (202.122.32.170)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From TECHNION-HEP (192.114.101.125) to UnknownSite (161.116.81.235)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BNL-ATLAS (192.12.15.26) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (193.206.93.45) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SCOTGRID-ECDF (129.215.213.70) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to UFlorida-HPC (128.227.221.44)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (193.144.80.12)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to FMPhI-UNIBA (158.195.14.26)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to DESY-ZN (141.34.200.28)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CA-SCINET-T2 (142.150.19.61)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to SARA-MATRIX (145.100.17.8)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UKI-NORTHGRID-LIV-HEP (138.253.60.82)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UKI-SOUTHGRID-RALPP (130.246.47.129)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to RU-Protvino-IHEP (194.190.165.192)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BNL-ATLAS (192.12.15.26) to ITEP (194.85.69.75)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From Taiwan-LCG2 (117.103.105.191) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-07-NIPNE (81.180.86.64) to FMPhI-UNIBA (158.195.14.26)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (131.225.205.12)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IN2P3-CC (193.48.99.76)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From Taiwan-LCG2 (117.103.105.191) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-CPPM (134.158.20.192) to IEPSAS-Kosice (147.213.204.112)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IFCA-LCG2 (193.146.75.138)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UTA_SWT2 (129.107.255.29) to TRIUMF-LCG2 (206.12.9.2)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to BUDAPEST (148.6.8.251)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From GRIF (192.54.207.250) to RO-16-UAIC (85.122.31.74)
#
#
# Thank you for using this system. If you want to update your settings or unsubscribe, please use this link: https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnudgR9Vt18--Jd7nn_VU0BgZZVVjGrfGPDf5qS7pUrxmkFMUcNPVVUGVtw
#
# Best,
# The team
#
#
#
# ======================================================
#
#
# ======== Do not send alert email to ivukotic@cern.ch as there is no alert for this user ========
#
#
# ========= Send the following email to a user =========
# ------ Email subject ------
# Alert email customized for Eric Lancon
# ------ Email to -----------
# elancon@bnl.gov
# ------ Email body ---------
# Hi Eric Lancon,
#
#     The following are all the alerts about packet loss that you are interested in:
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to INFN-ROMA1 (141.108.35.18)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CSCS-LCG2 (148.187.64.25) to OU_OCHEP_SWT2 (129.15.40.231)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CYFRONET-LCG2 (212.191.227.174) to UnknownSite (161.116.81.235)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to UKI-NORTHGRID-LIV-HEP (138.253.60.82)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From AGLT2 (192.41.230.59) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-MCGILL-CLUMEQ-T2 (132.206.245.252) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CSCS-LCG2 (148.187.64.25) to ITEP (194.85.69.75)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SFU-LCG2 (206.12.24.251) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (149.165.225.223) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From JINR-T1 (159.93.229.151) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From AGLT2 (192.41.236.31) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CERN-PROD (128.142.223.247) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From BEIJING-LCG2 (202.122.32.170) to INFN-ROMA1 (141.108.35.18)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-CAM-HEP (131.111.66.196) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From GLOW (144.92.180.75) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From FMPhI-UNIBA (158.195.14.26) to TRIUMF-LCG2 (206.12.9.2)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From DESY-HH (131.169.98.30) to UnknownSite (62.40.126.129)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SPRACE (200.136.80.20) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From Nebraska (129.93.239.148) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From Vanderbilt (192.111.108.112) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-BHAM-HEP (193.62.56.9) to INFN-MILANO-ATLASC (192.135.14.32)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CYFRONET-LCG2 (212.191.227.174) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From BU_ATLAS_Tier2 (192.5.207.251) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-LANCS-HEP (194.80.35.169) to UnknownSite (161.116.81.235)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (152.84.101.141) to UnknownSite (161.116.81.235)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UTA_SWT2 (129.107.255.29) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From SFU-LCG2 (206.12.24.251) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to TRIUMF-LCG2 (206.12.9.2)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UFlorida-HPC (128.227.221.44) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From GRIF (192.54.207.250) to UnknownSite (161.116.81.235)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From FZK-LCG2 (192.108.47.12) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-SCINET-T2 (142.150.19.61) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From INDIACMS-TIFR (144.16.111.26) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to INFN-ROMA1 (141.108.35.18)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-CAM-HEP (131.111.66.196) to UnknownSite (161.116.81.235)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (18.12.1.171) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to RO-16-UAIC (85.122.31.74)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (152.84.101.141) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From EELA-UTFSM (146.83.90.7) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From CYFRONET-LCG2 (212.191.227.174) to INFN-ROMA1 (141.108.35.18)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From GRIF (134.158.132.200) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From BEIJING-LCG2 (202.122.32.170) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-NORTHGRID-MAN-HEP (195.194.105.178) to Taiwan-LCG2 (117.103.105.191)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From praguelcg2 (147.231.25.192) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-VICTORIA-WESTGRID-T2 (206.12.154.60) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From JINR-T1 (159.93.229.151) to INDIACMS-TIFR (144.16.111.26)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to UKI-SOUTHGRID-OX-HEP (163.1.5.210)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BNL-ATLAS (192.12.15.26) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BU_ATLAS_Tier2 (192.5.207.251) to ITEP (194.85.69.75)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SCOTGRID-DURHAM (193.60.193.3) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CSCS-LCG2 (148.187.64.25)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to IN2P3-LPSC (193.48.83.165)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From TOKYO-LCG2 (157.82.112.68) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to ITEP (194.85.69.75)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to FMPhI-UNIBA (158.195.14.26)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CERN-PROD (128.142.223.247)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to GRIF (192.54.207.250)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (143.215.129.69) to UnknownSite (131.243.24.11)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-LAPP (134.158.103.10) to UnknownSite (193.206.93.45)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IEPSAS-Kosice (147.213.204.112)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (193.206.93.45) to NCG-INGRID-PT (193.136.75.146)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IFIC-LCG2 (147.156.116.40)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-07-NIPNE (81.180.86.64) to IEPSAS-Kosice (147.213.204.112)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (161.116.81.235)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IN2P3-CPPM (134.158.20.192)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to RO-16-UAIC (85.122.31.74)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From CA-VICTORIA-WESTGRID-T2 (206.12.154.60) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-02-NIPNE (81.180.86.38) to FMPhI-UNIBA (158.195.14.26)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From OU_OCHEP_SWT2 (129.15.40.231) to EELA-UTFSM (146.83.90.7)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CA-MCGILL-CLUMEQ-T2 (132.206.245.252)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IFCA-LCG2 (193.146.75.138) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (18.12.1.171)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SOUTHGRID-BRIS-HEP (137.222.74.15) to AGLT2 (192.41.236.31)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-CPPM (134.158.20.192) to UnknownSite (161.116.81.235)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to IEPSAS-Kosice (147.213.204.112)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-02-NIPNE (81.180.86.38) to IEPSAS-Kosice (147.213.204.112)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to SFU-LCG2 (206.12.24.251)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to RO-16-UAIC (85.122.31.74)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-16-UAIC (85.122.31.74) to IFIC-LCG2 (147.156.116.40)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SCOTGRID-ECDF (129.215.213.70) to UnknownSite (161.116.81.235)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-CPPM (134.158.20.192) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to GRIF (134.158.73.243)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to AGLT2 (192.41.236.31)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (193.239.180.211)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to BEIJING-LCG2 (202.122.32.170)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From TECHNION-HEP (192.114.101.125) to UnknownSite (161.116.81.235)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BNL-ATLAS (192.12.15.26) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UnknownSite (193.206.93.45) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UKI-SCOTGRID-ECDF (129.215.213.70) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RU-Protvino-IHEP (194.190.165.192) to UFlorida-HPC (128.227.221.44)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (193.144.80.12)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to FMPhI-UNIBA (158.195.14.26)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to DESY-ZN (141.34.200.28)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to CA-SCINET-T2 (142.150.19.61)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to SARA-MATRIX (145.100.17.8)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UKI-NORTHGRID-LIV-HEP (138.253.60.82)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UKI-SOUTHGRID-RALPP (130.246.47.129)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to RU-Protvino-IHEP (194.190.165.192)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From BNL-ATLAS (192.12.15.26) to ITEP (194.85.69.75)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From Taiwan-LCG2 (117.103.105.191) to RAL-LCG2 (130.246.176.109)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RO-07-NIPNE (81.180.86.64) to FMPhI-UNIBA (158.195.14.26)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to UnknownSite (131.225.205.12)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IN2P3-CC (193.48.99.76)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From Taiwan-LCG2 (117.103.105.191) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From IN2P3-CPPM (134.158.20.192) to IEPSAS-Kosice (147.213.204.112)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to IFCA-LCG2 (193.146.75.138)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From UTA_SWT2 (129.107.255.29) to TRIUMF-LCG2 (206.12.9.2)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From RAL-LCG2 (130.246.176.109) to BUDAPEST (148.6.8.251)
#
#
# [Old problem disappeared]  Packet loss increase for link(s) where your site is a source
#
#     From GRIF (192.54.207.250) to RO-16-UAIC (85.122.31.74)
#
#
# Thank you for using this system. If you want to update your settings or unsubscribe, please use this link: https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnuf_umrjRScBiYvJ_aUfteZA2eiV-yUK9DMa3q7VefVJtC5bEQnNSPOg4A
#
# Best,
# The team
#
#
#
# ======================================================
#
#
# ========= Send the following email to a user =========
# ------ Email subject ------
# Alert email customized for Lincoln Bryant
# ------ Email to -----------
# LINCOLNB@UCHICAGO.EDU
# ------ Email body ---------
# Hi Lincoln Bryant,
#
#     The following are all the alerts about packet loss that you are interested in:
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (149.165.225.223) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to BEIJING-LCG2 (202.122.32.170)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to RAL-LCG2 (130.246.176.109)
#
#
# [New problem appeared]  Packet loss increase for link(s) where your site is a source
#
#     From MWT2 (72.36.96.4) to UKI-NORTHGRID-MAN-HEP (195.194.105.178)
#
#
# Thank you for using this system. If you want to update your settings or unsubscribe, please use this link: https://docs.google.com/forms/d/e/1FAIpQLSfwwtAvMrqp4Ot_LYfmNu75_v33dtAxiXg7ZvVdn1X5v7TEgg/viewform?edit2=2_ABaOnufEkC3ZkGEJM7YrjIK5M9zZCa8Fg0C58snIuKzECJRbScqS5po96bBVKA
#
# Best,
# The team
#
#
#
# ======================================================
