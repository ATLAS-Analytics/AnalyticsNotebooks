# %%
# %matplotlib inline

# DataFrame
import pandas as pd

# Elasticsearch
from elasticsearch import Elasticsearch, helpers

# datetime
from datetime import datetime

# isnan()
import math

# plot
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt


# import numpy as np
# from sklearn.covariance import EllipticEnvelope
from sklearn.svm import OneClassSVM
# import matplotlib.pyplot as plt
# import matplotlib.font_manager
# from sklearn.datasets import load_boston

from scipy import stats

# %%
# MWT2_a = 192.170.227.160    University of Chicago
# MWT2_b = 149.165.225.223    Indiana University
# MWT2_c = 72.36.96.4         UIUC

# From MWT2_a to MWT2_b

src_ip = '192.170.227.160'
dest_ip = '149.165.225.223'

a = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))

d = a.delay_median
d = d[d.notnull()]

fig = plt.figure(figsize=[9, 6])
plt.hist(d, 100, facecolor='green', alpha=0.75)
plt.xlabel('One way delay (ms)'), plt.ylabel('Count')
plt.title('Delay_median  -  University of Chicago / Indiana University')

print(d.max())
print(d.min())

ax = fig.add_subplot(111)
ax.text(-22, 6500, 'Max delay = {} ms \nMin delay = {} ms'.format(d.max(), d.min()), fontsize=12)
# Out:
# 12.3
# -24.5

# %%
# MWT2_a = 192.170.227.160    University of Chicago
# MWT2_b = 149.165.225.223    Indiana University
# MWT2_c = 72.36.96.4         UIUC

# From MWT2_a to MWT2_c

src_ip = '192.170.227.160'
dest_ip = '72.36.96.4'

a = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))

d = a.delay_median
d = d[d.notnull()]

fig = plt.figure(figsize=[9, 6])
plt.hist(d, 100, facecolor='green', alpha=0.75)
plt.xlabel('One way delay (ms)'), plt.ylabel('Count')
plt.title('Delay_median  -  University of Chicago / UIUC')

print(d.max())
print(d.min())

ax = fig.add_subplot(111)
ax.text(20, 10000, 'Max delay = {} ms \nMin delay = {} ms'.format(d.max(), d.min()), fontsize=12)
# Out:
# 37.8
# -5.7

# %%
# MWT2_a = 192.170.227.160    University of Chicago
# MWT2_b = 149.165.225.223    Indiana University
# MWT2_c = 72.36.96.4         UIUC

# From MWT2_b to MWT2_a

src_ip = '149.165.225.223'
dest_ip = '192.170.227.160'

a = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))

d = a.delay_median
d = d[d.notnull()]

fig = plt.figure(figsize=[9, 6])
plt.hist(d, 100, facecolor='green', alpha=0.75)
plt.xlabel('One way delay (ms)'), plt.ylabel('Count')
plt.title('Delay_median  -  Indiana University / University of Chicago')

print(d.max())
print(d.min())

ax = fig.add_subplot(111)
ax.text(120, 8000, 'Max delay = {} ms \nMin delay = {} ms'.format(d.max(), d.min()), fontsize=12)
# Out:
# 234.75
# -12.0

# %%
# MWT2_a = 192.170.227.160    University of Chicago
# MWT2_b = 149.165.225.223    Indiana University
# MWT2_c = 72.36.96.4         UIUC

# From MWT2_b to MWT2_c

src_ip = '149.165.225.223'
dest_ip = '72.36.96.4'

a = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))

d = a.delay_median
d = d[d.notnull()]

fig = plt.figure(figsize=[9, 6])
plt.hist(d, 100, facecolor='green', alpha=0.75)
plt.xlabel('One way delay (ms)'), plt.ylabel('Count')
plt.title('Delay_median  -  Indiana University / UIUC')

print(d.max())
print(d.min())

ax = fig.add_subplot(111)
ax.text(33, 7000, 'Max delay = {} ms \nMin delay = {} ms'.format(d.max(), d.min()), fontsize=12)
# Out:
# 59.4
# -4.3

# %%
# MWT2_a = 192.170.227.160    University of Chicago
# MWT2_b = 149.165.225.223    Indiana University
# MWT2_c = 72.36.96.4         UIUC

# From MWT2_c to MWT2_a

src_ip = '72.36.96.4'
dest_ip = '192.170.227.160'

a = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))

d = a.delay_median
d = d[d.notnull()]

fig = plt.figure(figsize=[9, 6])
plt.hist(d, 100, facecolor='green', alpha=0.75)
plt.xlabel('One way delay (ms)'), plt.ylabel('Count')
plt.title('Delay_median  -  UIUC / University of Chicago')

print(d.max())
print(d.min())

ax = fig.add_subplot(111)
# ax.text(45, 9000, 'Max delay = {} ms \nMin delay = {} ms'.format(d.max(), d.min()), fontsize=12)
ax.text(45, 9000, 'Max delay = {} ms \nMin delay = {} ms'.format(96.3, d.min()), fontsize=12)
# Out:
# 96.3
# -40.0

# %%
# MWT2_a = 192.170.227.160    University of Chicago
# MWT2_b = 149.165.225.223    Indiana University
# MWT2_c = 72.36.96.4         UIUC

# From MWT2_c to MWT2_b

src_ip = '72.36.96.4'
dest_ip = '149.165.225.223'

a = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))

d = a.delay_median
d = d[d.notnull()]

fig = plt.figure(figsize=[9, 6])
plt.hist(d, 100, facecolor='green', alpha=0.75)
plt.xlabel('One way delay (ms)'), plt.ylabel('Count')
plt.title('Delay_median  -  UIUC / Indiana University')

print(d.max())
print(d.min())

ax = fig.add_subplot(111)
ax.text(25, 4000, 'Max delay = {} ms \nMin delay = {} ms'.format(d.max(), d.min()), fontsize=12)
# Out:
# 45.8
# -24.0

# %% [markdown]
# # ================= Part one ends. Part two begins. =================

# %%
# MWT2_a = 192.170.227.160    University of Chicago
# MWT2_b = 149.165.225.223    Indiana University
# MWT2_c = 72.36.96.4         UIUC

# a / b
src_ip = '192.170.227.160'
dest_ip = '149.165.225.223'
pkl = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))
temp = pkl.delay_median
delay_ab = temp[temp.notnull()]

# a / c
src_ip = '192.170.227.160'
dest_ip = '72.36.96.4'
pkl = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))
temp = pkl.delay_median
delay_ac = temp[temp.notnull()]

# b / a
src_ip = '149.165.225.223'
dest_ip = '192.170.227.160'
pkl = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))
temp = pkl.delay_median
delay_ba = temp[temp.notnull()]

# b / c
src_ip = '149.165.225.223'
dest_ip = '72.36.96.4'
pkl = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))
temp = pkl.delay_median
delay_bc = temp[temp.notnull()]

# c / a
src_ip = '72.36.96.4'
dest_ip = '192.170.227.160'
pkl = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))
temp = pkl.delay_median
delay_ca = temp[temp.notnull()]

# c / b
src_ip = '72.36.96.4'
dest_ip = '149.165.225.223'
pkl = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))
temp = pkl.delay_median
delay_cb = temp[temp.notnull()]


# delay_ab
# delay_ac
# delay_ba
# delay_bc
# delay_ca
# delay_cb

# %%
# MWT2_a = 192.170.227.160    University of Chicago
# MWT2_b = 149.165.225.223    Indiana University
# MWT2_c = 72.36.96.4         UIUC

plt.figure(figsize=[9, 6])
plt.plot(delay_ab.index, delay_ab.values, c='k', label='From a to b')
plt.plot(delay_ba.index, delay_ba.values, c='r', label='From b to a')
plt.legend()

plt.axhline(y=0, xmin=0, xmax=1500000000000, color='y')


x = [1451606400000, 1454284800000, 1456790400000, 1459468800000, 1462060800000, 1464739200000]
lbl = ['2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01']
plt.xticks(x, lbl, rotation=0)

plt.ylim([-30, 30])

plt.xlabel('Date')
plt.ylabel('Delay (ms)')
plt.title('University of Chicago (a)  and  Indiana University (b)')
plt.show()

# %%
# MWT2_a = 192.170.227.160    University of Chicago
# MWT2_b = 149.165.225.223    Indiana University
# MWT2_c = 72.36.96.4         UIUC

plt.figure(figsize=[9, 6])
plt.plot(delay_ac.index, delay_ac.values, c='k', label='From a to c')
plt.plot(delay_ca.index, delay_ca.values, c='r', label='From c to a')
plt.legend()

plt.axhline(y=0, xmin=0, xmax=1500000000000, color='y')


x = [1451606400000, 1454284800000, 1456790400000, 1459468800000, 1462060800000, 1464739200000]
lbl = ['2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01']
plt.xticks(x, lbl, rotation=0)

plt.ylim([-60, 100])

plt.xlabel('Date')
plt.ylabel('Delay (ms)')
plt.title('University of Chicago (a)  and  UIUC (c)')
plt.show()

# %%
# MWT2_a = 192.170.227.160    University of Chicago
# MWT2_b = 149.165.225.223    Indiana University
# MWT2_c = 72.36.96.4         UIUC

plt.figure(figsize=[9, 6])
plt.plot(delay_bc.index, delay_bc.values, c='k', label='From b to c')
plt.plot(delay_cb.index, delay_cb.values, c='r', label='From c to b')
plt.legend()

plt.axhline(y=0, xmin=0, xmax=1500000000000, color='y')


x = [1451606400000, 1454284800000, 1456790400000, 1459468800000, 1462060800000, 1464739200000]
lbl = ['2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01']
plt.xticks(x, lbl, rotation=0)

# plt.ylim([-30, 30])

plt.xlabel('Date')
plt.ylabel('Delay (ms)')
plt.title('Indiana University (b)  and  UIUC (c)')
plt.show()

# %% [markdown]
# # ================= Part two ends. Part three begins. =================

# %%
# From: University of Chicago (MWT2_a)

# To: Indiana University (MWT2_b)
#     UIUC (MWT2_c)
#     SFU
#     CERN
#     BEIJING


# delay_ab
# delay_ac
# delay_au
# delay_an
# delay_ag

# %%
src_ip = '192.170.227.160'  # University of Chicago (a)
dest_ip = '149.165.225.223'  # Indiana University (b)
pkl = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))
temp = pkl.delay_median
delay_ab = temp[temp.notnull()]

src_ip = '192.170.227.160'  # University of Chicago (a)
dest_ip = '72.36.96.4'  # UIUC (c)
pkl = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))
temp = pkl.delay_median
delay_ac = temp[temp.notnull()]

src_ip = '192.170.227.160'  # University of Chicago (a)
dest_ip = '206.12.24.251'  # SFU
pkl = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))
temp = pkl.delay_median
delay_au = temp[temp.notnull()]

src_ip = '192.170.227.160'  # University of Chicago (a)
dest_ip = '128.142.223.247'  # CERN
pkl = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))
temp = pkl.delay_median
delay_an = temp[temp.notnull()]

src_ip = '192.170.227.160'  # University of Chicago (a)
dest_ip = '202.122.32.170'  # BEIJING
pkl = pd.read_pickle('./My_data/week0708_clean_from_{}_to_{}.pkl'.format(src_ip, dest_ip))
temp = pkl.delay_median
delay_ag = temp[temp.notnull()]

# %%
print(len(delay_ab))
print(len(delay_ac))
print(len(delay_au))
print(len(delay_an))
print(len(delay_ag))
# Out:
# 15149
# 16048
# 5090
# 6391
# 5002

# %%
# Note that the time index is "ms", so it / 1000 / 60 = minutes

print('{}       {}'.format(delay_ab.index.min(), delay_ab.index.max()))
print('{}       {}'.format(delay_ac.index.min(), delay_ac.index.max()))
print('{}       {}'.format(delay_au.index.min(), delay_au.index.max()))
print('{}       {}'.format(delay_an.index.min(), delay_an.index.max()))
print('{}       {}'.format(delay_ag.index.min(), delay_ag.index.max()))
# Out:
# 1451607300000       1464731700000
# 1451607300000       1464731700000
# 1451607600000       1464730500000
# 1451607300000       1464731700000
# 1451607600000       1464730500000

# %%
time_window_width = 1      # hours
tww = time_window_width * 60 * 60 * 1000      # ms

count = 0
table_count = pd.DataFrame()
time_min = 1451607300000
time_max = 1464731700000

# my_null_value = -10

for i in range(time_min, time_max, tww):
    count += 1
    ie = i + tww
    table_count.set_value(count, 'time_start', i)     # >= time_start
    table_count.set_value(count, 'time_end', ie)   # < time_end
    # ab
    temp = delay_ab[(delay_ab.index >= i) & (delay_ab.index < ie)]
    table_count.set_value(count, 'ab_count', len(temp))
    if len(temp) > 0:
        table_count.set_value(count, 'ab_mean', temp.values.mean())
        last_valid_value_ab = temp.values.mean()
    else:
#         table_count.set_value(count, 'ab_mean', my_null_value)
        table_count.set_value(count, 'ab_mean', last_valid_value_ab)
    # ac
    temp = delay_ac[(delay_ac.index >= i) & (delay_ac.index < ie)]
    table_count.set_value(count, 'ac_count', len(temp))
    if len(temp) > 0:
        table_count.set_value(count, 'ac_mean', temp.values.mean())
        last_valid_value_ac = temp.values.mean()
    else:
#         table_count.set_value(count, 'ac_mean', my_null_value)
        table_count.set_value(count, 'ac_mean', last_valid_value_ac)
    # au
    temp = delay_au[(delay_au.index >= i) & (delay_au.index < ie)]
    table_count.set_value(count, 'au_count', len(temp))
    if len(temp) > 0:
        table_count.set_value(count, 'au_mean', temp.values.mean())
        last_valid_value_au = temp.values.mean()
    else:
#         table_count.set_value(count, 'au_mean', my_null_value)
        table_count.set_value(count, 'au_mean', last_valid_value_au)
    # an
    temp = delay_an[(delay_an.index >= i) & (delay_an.index < ie)]
    table_count.set_value(count, 'an_count', len(temp))
    if len(temp) > 0:
        table_count.set_value(count, 'an_mean', temp.values.mean())
        last_valid_value_an = temp.values.mean()
    else:
#         table_count.set_value(count, 'an_mean', my_null_value)
        table_count.set_value(count, 'an_mean', last_valid_value_an)
    # ag
    temp = delay_ag[(delay_ag.index >= i) & (delay_ag.index < ie)]
    table_count.set_value(count, 'ag_count', len(temp))
    if len(temp) > 0:
        table_count.set_value(count, 'ag_mean', temp.values.mean())
        last_valid_value_ag = temp.values.mean()
    else:
#         table_count.set_value(count, 'ag_mean', my_null_value)
        table_count.set_value(count, 'ag_mean', last_valid_value_ag)

# %%
table_count
# Out:
#         time_start      time_end  ab_count   ab_mean  ac_count   ac_mean  \
# 1     1.451607e+12  1.451611e+12       5.0  2.580000       5.0  1.820000
# 2     1.451611e+12  1.451614e+12       4.0  2.800000       4.0  2.300000
# 3     1.451614e+12  1.451618e+12       5.0  2.900000       5.0  2.760000
# 4     1.451618e+12  1.451622e+12       8.0  2.787500       6.0  2.216667
# 5     1.451622e+12  1.451625e+12       8.0  2.787500       8.0  2.037500
# 6     1.451625e+12  1.451629e+12       8.0  2.737500       7.0  1.857143
# 7     1.451629e+12  1.451632e+12       5.0  2.780000       7.0  2.757143
# 8     1.451632e+12  1.451636e+12       8.0  2.487500       9.0  2.377778
# 9     1.451636e+12  1.451640e+12       6.0  2.433333       5.0  1.980000
# 10    1.451640e+12  1.451643e+12       6.0  2.583333       7.0  1.271429
# 11    1.451643e+12  1.451647e+12       6.0  2.616667       7.0  1.771429
# 12    1.451647e+12  1.451650e+12       4.0  2.675000       6.0  1.900000
# ...

# %%
string = 'ab_count'
d = table_count[string]
fig = plt.figure(figsize=[9, 6])
plt.hist(d, 50, facecolor='green', alpha=0.75)
plt.xlabel(string), plt.ylabel('Count')
plt.title(string)

string = 'ac_count'
d = table_count[string]
fig = plt.figure(figsize=[9, 6])
plt.hist(d, 50, facecolor='green', alpha=0.75)
plt.xlabel(string), plt.ylabel('Count')
plt.title(string)

string = 'au_count'
d = table_count[string]
fig = plt.figure(figsize=[9, 6])
plt.hist(d, 50, facecolor='green', alpha=0.75)
plt.xlabel(string), plt.ylabel('Count')
plt.title(string)

string = 'an_count'
d = table_count[string]
fig = plt.figure(figsize=[9, 6])
plt.hist(d, 50, facecolor='green', alpha=0.75)
plt.xlabel(string), plt.ylabel('Count')
plt.title(string)

string = 'ag_count'
d = table_count[string]
fig = plt.figure(figsize=[9, 6])
plt.hist(d, 50, facecolor='green', alpha=0.75)
plt.xlabel(string), plt.ylabel('Count')
plt.title(string)








plt.figure(figsize=[9, 6])
plt.plot(table_count['ab_mean'].index, table_count['ab_mean'].values, c='k', label='ab_mean')
plt.plot(table_count['ac_mean'].index, table_count['ac_mean'].values, c='r', label='ac_mean')
plt.plot(table_count['au_mean'].index, table_count['au_mean'].values, c='g', label='au_mean')
plt.plot(table_count['an_mean'].index, table_count['an_mean'].values, c='b', label='an_mean')
plt.plot(table_count['ag_mean'].index, table_count['ag_mean'].values, c='y', label='ag_mean')
plt.legend()

# plt.axhline(y=0, xmin=0, xmax=1500000000000, color='y')


# x = [1451606400000, 1454284800000, 1456790400000, 1459468800000, 1462060800000, 1464739200000]
# lbl = ['2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01']
# plt.xticks(x, lbl, rotation=0)

# plt.ylim([-30, 30])

# plt.xlabel('Date')
# plt.ylabel('Delay (ms)')
# plt.title('University of Chicago (a)  and  Indiana University (b)')
# plt.show()

# %%
training_width = 24 * 10    # 10 days
trw = training_width

data_pd = table_count[['ab_mean', 'ac_mean', 'au_mean', 'an_mean', 'ag_mean']]

set_draw = set()

list_all = list()

for i in range(1 + trw, data_pd.index.max()):
    data_training = data_pd[(data_pd.index >= (i - trw)) & (data_pd.index < i)]
    clf = OneClassSVM(nu=0.261, gamma=0.05)
    clf.fit(data_training)
    data_new_line = data_pd[data_pd.index == i]
    result = clf.decision_function(data_new_line)
    y_pred = result.ravel()
    y_pred = y_pred[0]
    list_all.append(y_pred)
#     outliers_fraction = 0.1
#     threshold = stats.scoreatpercentile(y_pred, 100 * outliers_fraction)
#     threshold = .8
#     y_pred = y_pred > threshold
#     if y_pred:
#         set_draw.add(i)

# print(set_draw)
print(list_all)
# Out:
# [0.88908106055436065, 0.88908106055436065, 0.88908106055436065, 0.88855852223110077, 0.88855852223110077, 0.88855852223110787, 0.88855852223110787, 0.88039000361764153, 0.88052097406487917, 0.88051395096668728, 0.8805115388138276, 0.88051153881380628, 0.88051395096665885, 0.88051395096665885, 0.88051395096665885, 0.88258547290213585, 0.88251927146794884, 0.88255139609489675, 0.87641789891776511, 0.87647593867739459, 0.86383510314535528, 0.79815496208428272, 0.59126908162075864, 0.59126908162075864, 0.59152325286704865, 0.59158765795029922, 0.59152315692509916, 0.5915595644099767, 0.59143433065161588, 0.59139954235002534, 0.59130222081461881, 0.59150866128426571, 0.59130222081463302, 0.59130222081461881, 0.59143433065162299, 0.59143433065163009, 0.59155956440996249, 0.59130222081459038, 0.59130222081462591, 0.90866299639139925, 0.3928321005841795, 0.049939903873813307, -0.77312800446392771, -0.65273860268521133, -0.48966430637216263, 0.56415888035061812, 0.92047072327132184, 0.0482845
# ...

# %%
data_pd
# Out:
#        ab_mean   ac_mean    au_mean    an_mean     ag_mean
# 1     2.580000  1.820000  25.400000  52.933333  102.400000
# 2     2.800000  2.300000  25.800000  53.433333  102.900000
# 3     2.900000  2.760000  26.300000  53.400000  103.350000
# 4     2.787500  2.216667  25.866667  53.450000  103.300000
# 5     2.787500  2.037500  25.850000  53.433333  103.200000
# 6     2.737500  1.857143  25.733333  53.500000  102.833333
# 7     2.780000  2.757143  25.750000  53.600000  103.050000
# 8     2.487500  2.377778  25.700000  53.200000  103.166667
# 9     2.433333  1.980000  25.800000  53.300000  103.000000
# 10    2.583333  1.271429  25.800000  53.233333  102.800000
# 11    2.616667  1.771429  25.766667  53.200000  102.600000
# 12    2.675000  1.900000  25.800000  53.250000  102.800000
# 13    2.900000  1.800000  25.600000  53.250000  102.800000
# 14    2.560000  1.683333  25.500000  53.100000  102.700000
# 15    2.270000  1.516667  25.200000  52.750000  102.400000
# ...

# %%
data_pd.shape
# Out:
# (3646, 5)

# %%
clf = OneClassSVM(nu=0.261, gamma=0.05)
clf.fit(data_pd)
result = clf.decision_function(data_pd)

# %%
y_pred = result.ravel()
outliers_fraction = 0.01
threshold = stats.scoreatpercentile(y_pred, 100 * outliers_fraction)
# print(threshold)
y_pred = y_pred > threshold
# n_errors = (y_pred != ground_truth).sum()

# %%
y_pred.shape
# Out:
# (3646,)

# %%
y_pred
# Out:
# array([ True,  True,  True, ...,  True,  True,  True], dtype=bool)

# %%
result.shape
# Out:
# (3646, 1)

# %%
plt.figure(figsize=[9, 6])
plt.plot(table_count.index, result, c='k', label='xxxxxx')
plt.legend()

plt.figure(figsize=[9, 6])
plt.plot(table_count.index, y_pred, c='k', label='xxxxxx')
plt.legend()

# %%
for t in set_dm:
                plt.axvline(x=t, ymin=0, ymax=1, color='r')

# %%
plt.figure(figsize=[9, 6])
plt.semilogy(table_count['ab_mean'].index, table_count['ab_mean'].values, c='k', label='a/b')
plt.semilogy(table_count['ac_mean'].index, table_count['ac_mean'].values, c='y', label='a/c')
plt.semilogy(table_count['au_mean'].index, table_count['au_mean'].values, c='g', label='a/u')
plt.semilogy(table_count['an_mean'].index, table_count['an_mean'].values, c='m', label='a/n')
plt.semilogy(table_count['ag_mean'].index, table_count['ag_mean'].values, c='b', label='a/g')
plt.legend()

threshold = -45

plt.ylim([-60, 220])
plt.ylabel('Delay (ms)')
plt.xlabel('Time point')
plt.title('Delay anomaly detection by using One Class SVM (threshold = {})'.format(threshold))

count = 240
for t in list_all:
    count += 1
    if t < threshold:
        print(count)
        plt.axvline(x=count, ymin=-100, ymax=300, color='r')

plt.semilogy(table_count['ab_mean'].index, table_count['ab_mean'].values, c='k', label='a/b')
plt.semilogy(table_count['ac_mean'].index, table_count['ac_mean'].values, c='y', label='a/c')
plt.semilogy(table_count['au_mean'].index, table_count['au_mean'].values, c='g', label='a/u')
plt.semilogy(table_count['an_mean'].index, table_count['an_mean'].values, c='m', label='a/n')
plt.semilogy(table_count['ag_mean'].index, table_count['ag_mean'].values, c='b', label='a/g')
# Out:
# 937
# 938
# 939
# 940
# 941
# 945
# 946
# 1305
# 1306
# 1307
# 1308
# 1638
# 1639
# 1640
# 1682
# 1683
# 1684
# 1685
# 1686
# 1687
# 1688
# 1689
# 2767
# 2768
# 2769
# 2770
# 2771
# 2772
# 3195
# 3196
# 3288
# 3316
