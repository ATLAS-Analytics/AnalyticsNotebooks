# %%
# %matplotlib inline

# DataFrame
import pandas as pd

# Elasticsearch
from elasticsearch import Elasticsearch, helpers

# datetime
from datetime import datetime

# isnan()
import math

# plot
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# OneClassSVM
# from sklearn.svm import OneClassSVM

# stats
# from scipy import stats

plt.style.use('ggplot')

# %% [markdown]
# ## 3 src sites (MWT2) and 75 dest sites, collect and clean data!

# %%
es = Elasticsearch(['atlas-kibana.mwt2.org:9200'], timeout=6000)

# %%
list_src_ip = ['192.170.227.160', '149.165.225.223', '72.36.96.4']
list_dest_ip = ['192.41.230.59', '192.41.236.31', '192.231.127.41', '202.122.32.170', '192.12.15.26', 
                '192.5.207.251', '132.206.245.252', '142.150.19.61', '206.12.154.60', '128.142.223.247', 
                '148.187.64.25', '212.191.227.174', '131.169.98.30', '141.34.200.28', '146.83.90.7', 
                '109.105.125.232', '158.195.14.26', '192.108.47.12', '144.92.180.75', '134.158.132.200', 
                '134.158.159.85', '192.54.207.250', '147.213.204.112', '193.146.75.138', '147.156.116.40', 
                '193.48.99.76', '134.158.20.192', '134.158.103.10', '134.158.123.183', '193.48.83.165', 
                '144.16.111.26', '90.147.66.50', '192.84.128.112', '141.108.35.18', '131.154.254.12', 
                '159.93.229.151', '164.58.29.121', '109.105.124.86', '129.93.239.148', '129.15.40.231', 
                '193.109.172.188', '147.231.25.192', '130.246.176.109', '81.180.86.38', '81.180.86.64', 
                '85.122.31.74', '144.206.237.142', '144.206.236.189', '194.190.165.192', '145.100.17.8', 
                '206.12.24.251', '200.136.80.20', '203.185.96.100', '117.103.105.191', '157.82.112.68', 
                '206.12.9.2', '150.244.247.2', '128.227.221.44', '194.36.11.38', '128.40.4.25', 
                '194.80.35.169', '138.253.60.82', '195.194.105.178', '193.60.193.3', '129.215.213.70', 
                '130.209.239.124', '193.62.56.9', '131.111.66.196', '163.1.5.210', '130.246.47.129', 
                '139.184.80.18', '129.107.255.29', '192.111.108.112', '134.79.118.72', '132.195.125.213']
print('The size of list_src_ip is {}'.format(len(list_src_ip)))
print('The size of list_dest_ip is {}'.format(len(list_dest_ip)))
# Out:
# The size of list_src_ip is 3
# The size of list_dest_ip is 75

# %%
raw_data_pool = {}

def make_sure(src_site_name, src_site_ip, dest_site_name, dest_site_ip):
    if src_site_ip not in raw_data_pool:
        raw_data_pool[src_site_ip] = {}
        print("In raw_data_pool, created new src_site_ip {} representing src_site_name {}".format(src_site_ip, src_site_name))
    if dest_site_ip not in raw_data_pool[src_site_ip]:
        raw_data_pool[src_site_ip][dest_site_ip] = pd.DataFrame()
        print("In raw_data_pool, created source site {}'s new dest_site_ip {} representing dest_site_name {}".format(src_site_name, dest_site_ip, dest_site_name))

def put_data(src_site_name, src_site_ip, dest_site_name, dest_site_ip, timestamp_epoch, column_type, value):
    make_sure(src_site_name, src_site_ip, dest_site_name, dest_site_ip)
    raw_data_pool[src_site_ip][dest_site_ip].set_value(timestamp_epoch, column_type, value)

# %%
# src_site_name = 'source_site_name'
# dest_site_name = 'destination_site_name'
src_site_ip = 'xxxxxx'
dest_site_ip = 'xxxxxx'

# timestamp = { 'gte': '2016-01-01', 'lt': '2016-06-01' }
timestamp = { 'gte': '2016-01-01' }

my_query = {}
my_query['query'] = {}
my_query['query']['filtered'] = {}
my_query['query']['filtered']['query'] = { "match_all": {} }
my_query['query']['filtered']['filter'] = {}
my_query['query']['filtered']['filter']['bool'] = {}
my_query['query']['filtered']['filter']['bool']['must'] = []
# my_query['query']['filtered']['filter']['bool']['must'].append({ 'term': { 'srcSite': src_site_name } })
# my_query['query']['filtered']['filter']['bool']['must'].append({ 'term': { 'destSite': dest_site_name } })
# my_query['query']['filtered']['filter']['bool']['must'].append({ 'term': { 'src': src_site_ip } })
# my_query['query']['filtered']['filter']['bool']['must'].append({ 'term': { 'dest': dest_site_ip } })
my_query['query']['filtered']['filter']['bool']['must'].append({ 'term': { 'srcProduction': True } })
my_query['query']['filtered']['filter']['bool']['must'].append({ 'term': { 'destProduction': True } })
my_query['query']['filtered']['filter']['bool']['must'].append({ 'range': { 'timestamp': timestamp } })
my_query['fielddata_fields'] = [ 'timestamp' ]

print(my_query)

my_index = "network_weather_2-*"

print(my_index)
# Out:
# {'query': {'filtered': {'query': {'match_all': {}}, 'filter': {'bool': {'must': [{'term': {'srcProduction': True}}, {'term': {'destProduction': True}}, {'range': {'timestamp': {'gte': '2016-01-01'}}}]}}}}, 'fielddata_fields': ['timestamp']}
# network_weather_2-*

# %%
# Note!!! here name actually is IP address!!!

set_timestamp = set()

def collect_and_clean(src_site_name, dest_site_name):
    
#     set_src = set()
#     set_dest = set()
    
    # Set the source/destination pair
#     my_query['query']['filtered']['filter']['bool']['must'][0]['term']['src'] = src_site_name
#     my_query['query']['filtered']['filter']['bool']['must'][1]['term']['dest'] = dest_site_name
#     my_query['query']['filtered']['filter']['bool']['must'][0]['term']['src'] = '*'
#     my_query['query']['filtered']['filter']['bool']['must'][1]['term']['dest'] = '*'
    
    print(my_query)
    print()
    
    # Collect traceroute raw data
    my_type = 'traceroute'
    scroll = list(helpers.scan(client=es, query=my_query, index=my_index, doc_type=my_type, request_timeout=6000))
    count = 0
    for result in scroll:
        count += 1
        timestamp_epoch = result['fields']['timestamp'][0]
        set_timestamp.add(timestamp_epoch)
#         set_src.add(result['_source']['src'])
#         set_dest.add(result['_source']['dest'])
        info = result['_source']
#         print('{}.  {}  {}  {}  {}'.format(count, info.get('src', 'NoSrc'), info.get('dest', 'NoDest'), info.get('hash', 'NoHash'), info.get('hops', 'NoHops')))
#         put_data(src_site_name, info.get('src', 'NoSrc'), dest_site_name, info.get('dest', 'NoDest'), timestamp_epoch, 'iso_8601', info.get('timestamp', 'NoTimestamp'))
#         put_data(src_site_name, info.get('src', 'NoSrc'), dest_site_name, info.get('dest', 'NoDest'), timestamp_epoch, 'hash', info.get('hash', 'NoHash'))
#         put_data(src_site_name, info.get('src', 'NoSrc'), dest_site_name, info.get('dest', 'NoDest'), timestamp_epoch, 'hops', info.get('hops', 'NoHops'))
        if count % 100 == 0:
            print('Collecting raw data, count == {}'.format(count))
    if count == 0:
        print('No raw data found. Finish this src/dest pair now.')
        print()
        print()
        print('===============================================================')
        return
    print('Number of raw records of {} is {}'.format(my_type, count))
    
#     # Collect packet_loss_rate raw data
#     my_type = 'packet_loss_rate'
#     scroll = list(helpers.scan(client=es, query=my_query, index=my_index, doc_type=my_type, request_timeout=6000))
#     count = 0
#     for result in scroll:
#         count += 1
#         timestamp_epoch = result['fields']['timestamp'][0]
# #         set_src.add(result['_source']['src'])
# #         set_dest.add(result['_source']['dest'])
#         put_data(src_site_name, result['_source']['src'], dest_site_name, result['_source']['dest'], timestamp_epoch, 'iso_8601', result['_source']['timestamp'])
#         put_data(src_site_name, result['_source']['src'], dest_site_name, result['_source']['dest'], timestamp_epoch, 'packet_loss', result['_source']['packet_loss'])
#     print('Number of raw records of {} is {}'.format(my_type, count))
    
#     # Collect throughput raw data
#     my_type = 'throughput'
#     scroll = list(helpers.scan(client=es, query=my_query, index=my_index, doc_type=my_type, request_timeout=6000))
#     count = 0
#     for result in scroll:
#         count += 1
#         timestamp_epoch = result['fields']['timestamp'][0]
#         set_src.add(result['_source']['src'])
#         set_dest.add(result['_source']['dest'])
#         put_data(src_site_name, result['_source']['src'], dest_site_name, result['_source']['dest'], timestamp_epoch, 'iso_8601', result['_source']['timestamp'])
#         put_data(src_site_name, result['_source']['src'], dest_site_name, result['_source']['dest'], timestamp_epoch, 'throughput', result['_source']['throughput'])
#     print('Number of raw records of {} is {}'.format(my_type, count))
    
    print()
#     for s in set_src:
#         print('src_site_name {} has src_site_ip {}'.format(src_site_name, s))
#     for s in set_dest:
#         print('dest_site_name {} has dest_site_ip {}'.format(dest_site_name, s))
#     print('Please manually count(), sort_index(), to_pickle() using src_site_ip and dest_site_ip !!!!!!')
    
#     # View statistics of raw_data_pool (already de-duplicated)
    print()
    print('De-duplication result:')
    print(raw_data_pool[src_site_name][dest_site_name].count(axis='index'))
    
#     # Sort in-place
    raw_data_pool[src_site_name][dest_site_name].sort_index(inplace=True)
    
#     # Store this DataFrame to disk file
    raw_data_pool[src_site_name][dest_site_name].to_pickle('My_data_Path/Path_clean_from_{}_to_{}_sorted.pkl'.format(src_site_name, dest_site_name))
    
#     # How to get this DataFrame
#     # raw_data_pool[src_site][dest_site]

    print('========================== Data done and stored on disk. ==============================================')


print('Successfully defined the collect_and_clean(src_site_name, dest_site_name) function')
# Out:
# Successfully defined the collect_and_clean(src_site_name, dest_site_name) function

# %%
count = 0
for src_site_name in list_src_ip:
    if count == 1:
        break
    for dest_site_name in list_dest_ip:
        count += 1
        print('=============================================================================')
        print('{}. Now the pair is {} / {}'.format(count, src_site_name, dest_site_name))
        print()
        collect_and_clean(src_site_name, dest_site_name)
        print('=============================================================================')
        if count == 1:
            break
# Out:
# =============================================================================
# 1. Now the pair is 192.170.227.160 / 192.41.230.59
#
# {'query': {'filtered': {'query': {'match_all': {}}, 'filter': {'bool': {'must': [{'term': {'srcProduction': True}}, {'term': {'destProduction': True}}, {'range': {'timestamp': {'gte': '2016-01-01'}}}]}}}}, 'fielddata_fields': ['timestamp']}
#
# Collecting raw data, count == 100
# Collecting raw data, count == 200
# Collecting raw data, count == 300
# Collecting raw data, count == 400
# Collecting raw data, count == 500
# Collecting raw data, count == 600
# Collecting raw data, count == 700
# Collecting raw data, count == 800
# Collecting raw data, count == 900
# Collecting raw data, count == 1000
# Collecting raw data, count == 1100
# Collecting raw data, count == 1200
# Collecting raw data, count == 1300
# Collecting raw data, count == 1400
# Collecting raw data, count == 1500
# Collecting raw data, count == 1600
# Collecting raw data, count == 1700
# Collecting raw data, count == 1800
# Collecting raw data, count == 1900
# Collecting raw data, count == 2000
# Collecting raw data, count == 2100
# Collecting raw data, count == 2200
# Collecting raw data, count == 2300
# Collecting raw data, count == 2400
# Collecting raw data, count == 2500
# Collecting raw data, count == 2600
# Collecting raw data, count == 2700
# Collecting raw data, count == 2800
# Collecting raw data, count == 2900
# Collecting raw data, count == 3000
# Collecting raw data, count == 3100
# Collecting raw data, count == 3200
# Collecting raw data, count == 3300
# Collecting raw data, count == 3400
# Collecting raw data, count == 3500
# Collecting raw data, count == 3600
# Collecting raw data, count == 3700
# Collecting raw data, count == 3800
# Collecting raw data, count == 3900
# Collecting raw data, count == 4000
# Collecting raw data, count == 4100
# Collecting raw data, count == 4200
# Collecting raw data, count == 4300
# Collecting raw data, count == 4400
# Collecting raw data, count == 4500
# Collecting raw data, count == 4600
# Collecting raw data, count == 4700
# Collecting raw data, count == 4800
# Collecting raw data, count == 4900
# Collecting raw data, count == 5000
# Collecting raw data, count == 5100
# Collecting raw data, count == 5200
# Collecting raw data, count == 5300
# Collecting raw data, count == 5400
# Collecting raw data, count == 5500
# Collecting raw data, count == 5600
# Collecting raw data, count == 5700
# Collecting raw data, count == 5800
# Collecting raw data, count == 5900
# Collecting raw data, count == 6000
# Collecting raw data, count == 6100
# Collecting raw data, count == 6200
# Collecting raw data, count == 6300
# Collecting raw data, count == 6400
# Collecting raw data, count == 6500
# Collecting raw data, count == 6600
# Collecting raw data, count == 6700
# Collecting raw data, count == 6800
# Collecting raw data, count == 6900
# Collecting raw data, count == 7000
# Collecting raw data, count == 7100
# Collecting raw data, count == 7200
# Collecting raw data, count == 7300
# Collecting raw data, count == 7400
# Collecting raw data, count == 7500
# Collecting raw data, count == 7600
# Collecting raw data, count == 7700
# Collecting raw data, count == 7800
# Collecting raw data, count == 7900
# Collecting raw data, count == 8000
# Collecting raw data, count == 8100
# Collecting raw data, count == 8200
# Collecting raw data, count == 8300
# Collecting raw data, count == 8400
# Collecting raw data, count == 8500
# Collecting raw data, count == 8600
# Collecting raw data, count == 8700
# Collecting raw data, count == 8800
# Collecting raw data, count == 8900
# Collecting raw data, count == 9000
# Collecting raw data, count == 9100
# Collecting raw data, count == 9200
# Collecting raw data, count == 9300
# Collecting raw data, count == 9400
# Collecting raw data, count == 9500
# Collecting raw data, count == 9600
# Collecting raw data, count == 9700
# Collecting raw data, count == 9800
# Collecting raw data, count == 9900
# Collecting raw data, count == 10000
# Collecting raw data, count == 10100
# Collecting raw data, count == 10200
# Collecting raw data, count == 10300
# Collecting raw data, count == 10400
# Collecting raw data, count == 10500
# Collecting raw data, count == 10600
# Collecting raw data, count == 10700
# Collecting raw data, count == 10800
# Collecting raw data, count == 10900
# Collecting raw data, count == 11000
# Collecting raw data, count == 11100
# Collecting raw data, count == 11200
# Collecting raw data, count == 11300
# Collecting raw data, count == 11400
# Collecting raw data, count == 11500
# Collecting raw data, count == 11600
# Collecting raw data, count == 11700
# Collecting raw data, count == 11800
# Collecting raw data, count == 11900
# Collecting raw data, count == 12000
# Collecting raw data, count == 12100
# Collecting raw data, count == 12200
# Collecting raw data, count == 12300
# Collecting raw data, count == 12400
# Collecting raw data, count == 12500
# Collecting raw data, count == 12600
# Collecting raw data, count == 12700
# Collecting raw data, count == 12800
# Collecting raw data, count == 12900
# Collecting raw data, count == 13000
# Collecting raw data, count == 13100
# Collecting raw data, count == 13200
# Collecting raw data, count == 13300
# Collecting raw data, count == 13400
# Collecting raw data, count == 13500
# Collecting raw data, count == 13600
# Collecting raw data, count == 13700
# Collecting raw data, count == 13800
# Collecting raw data, count == 13900
# Collecting raw data, count == 14000
# Collecting raw data, count == 14100
# Collecting raw data, count == 14200
# Collecting raw data, count == 14300
# Collecting raw data, count == 14400
# Collecting raw data, count == 14500
# Collecting raw data, count == 14600
# Collecting raw data, count == 14700
# Collecting raw data, count == 14800
# Collecting raw data, count == 14900
# Collecting raw data, count == 15000
# Collecting raw data, count == 15100
# Collecting raw data, count == 15200
# Collecting raw data, count == 15300
# Collecting raw data, count == 15400
# Collecting raw data, count == 15500
# Collecting raw data, count == 15600
# Collecting raw data, count == 15700
# Collecting raw data, count == 15800
# Collecting raw data, count == 15900
# Collecting raw data, count == 16000
# Collecting raw data, count == 16100
# Collecting raw data, count == 16200
# Collecting raw data, count == 16300
# Collecting raw data, count == 16400
# Collecting raw data, count == 16500
# Collecting raw data, count == 16600
# Collecting raw data, count == 16700
# Collecting raw data, count == 16800
# Collecting raw data, count == 16900
# Collecting raw data, count == 17000
# Collecting raw data, count == 17100
# Collecting raw data, count == 17200
# Collecting raw data, count == 17300
# Collecting raw data, count == 17400
# Collecting raw data, count == 17500
# Collecting raw data, count == 17600
# Collecting raw data, count == 17700
# Collecting raw data, count == 17800
# Collecting raw data, count == 17900
# Collecting raw data, count == 18000
# Collecting raw data, count == 18100
# Collecting raw data, count == 18200
# Collecting raw data, count == 18300
# Collecting raw data, count == 18400
# Collecting raw data, count == 18500
# Collecting raw data, count == 18600
# Collecting raw data, count == 18700
# Collecting raw data, count == 18800
# Collecting raw data, count == 18900
# Collecting raw data, count == 19000
# Collecting raw data, count == 19100
# Collecting raw data, count == 19200
# Collecting raw data, count == 19300
# Collecting raw data, count == 19400
# Collecting raw data, count == 19500
# Collecting raw data, count == 19600
# Collecting raw data, count == 19700
# Collecting raw data, count == 19800
# Collecting raw data, count == 19900
# Collecting raw data, count == 20000
# Collecting raw data, count == 20100
# Collecting raw data, count == 20200
# Collecting raw data, count == 20300
# Collecting raw data, count == 20400
# Collecting raw data, count == 20500
# Collecting raw data, count == 20600
# Collecting raw data, count == 20700
# Collecting raw data, count == 20800
# Collecting raw data, count == 20900
# Collecting raw data, count == 21000
# Collecting raw data, count == 21100
# Collecting raw data, count == 21200
# Collecting raw data, count == 21300
# Collecting raw data, count == 21400
# Collecting raw data, count == 21500
# Collecting raw data, count == 21600
# Collecting raw data, count == 21700
# Collecting raw data, count == 21800
# Collecting raw data, count == 21900
# Collecting raw data, count == 22000
# Collecting raw data, count == 22100
# Collecting raw data, count == 22200
# Collecting raw data, count == 22300
# Collecting raw data, count == 22400
# Collecting raw data, count == 22500
# Collecting raw data, count == 22600
# Collecting raw data, count == 22700
# Collecting raw data, count == 22800
# Collecting raw data, count == 22900
# Collecting raw data, count == 23000
# Collecting raw data, count == 23100
# Collecting raw data, count == 23200
# Collecting raw data, count == 23300
# Collecting raw data, count == 23400
# Collecting raw data, count == 23500
# Collecting raw data, count == 23600
# Collecting raw data, count == 23700
# Collecting raw data, count == 23800
# Collecting raw data, count == 23900
# Collecting raw data, count == 24000
# Collecting raw data, count == 24100
# Collecting raw data, count == 24200
# Collecting raw data, count == 24300
# Collecting raw data, count == 24400
# Collecting raw data, count == 24500
# Collecting raw data, count == 24600
# Collecting raw data, count == 24700
# Collecting raw data, count == 24800
# Collecting raw data, count == 24900
# Collecting raw data, count == 25000
# Collecting raw data, count == 25100
# Collecting raw data, count == 25200
# Collecting raw data, count == 25300
# Collecting raw data, count == 25400
# Collecting raw data, count == 25500
# Collecting raw data, count == 25600
# Collecting raw data, count == 25700
# Collecting raw data, count == 25800
# Collecting raw data, count == 25900
# Collecting raw data, count == 26000
# Collecting raw data, count == 26100
# Collecting raw data, count == 26200
# Collecting raw data, count == 26300
# Collecting raw data, count == 26400
# Collecting raw data, count == 26500
# Collecting raw data, count == 26600
# Collecting raw data, count == 26700
# Collecting raw data, count == 26800
# Collecting raw data, count == 26900
# Collecting raw data, count == 27000
# Collecting raw data, count == 27100
# Collecting raw data, count == 27200
# Collecting raw data, count == 27300
# Collecting raw data, count == 27400
# Collecting raw data, count == 27500
# Collecting raw data, count == 27600
# Collecting raw data, count == 27700
# Collecting raw data, count == 27800
# Collecting raw data, count == 27900
# Collecting raw data, count == 28000
# Collecting raw data, count == 28100
# Collecting raw data, count == 28200
# Collecting raw data, count == 28300
# Collecting raw data, count == 28400
# Collecting raw data, count == 28500
# Collecting raw data, count == 28600
# Collecting raw data, count == 28700
# Collecting raw data, count == 28800
# Collecting raw data, count == 28900
# Collecting raw data, count == 29000
# Collecting raw data, count == 29100
# Collecting raw data, count == 29200
# Collecting raw data, count == 29300
# Collecting raw data, count == 29400
# Collecting raw data, count == 29500
# Collecting raw data, count == 29600
# Collecting raw data, count == 29700
# Collecting raw data, count == 29800
# Collecting raw data, count == 29900
# Collecting raw data, count == 30000
# Collecting raw data, count == 30100
# Collecting raw data, count == 30200
# Collecting raw data, count == 30300
# Collecting raw data, count == 30400
# Collecting raw data, count == 30500
# Collecting raw data, count == 30600
# Collecting raw data, count == 30700
# Collecting raw data, count == 30800
# Collecting raw data, count == 30900
# Collecting raw data, count == 31000
# Collecting raw data, count == 31100
# Collecting raw data, count == 31200
# Collecting raw data, count == 31300
# Collecting raw data, count == 31400
# Collecting raw data, count == 31500
# Collecting raw data, count == 31600
# Collecting raw data, count == 31700
# Collecting raw data, count == 31800
# Collecting raw data, count == 31900
# Collecting raw data, count == 32000
# Collecting raw data, count == 32100
# Collecting raw data, count == 32200
# Collecting raw data, count == 32300
# Collecting raw data, count == 32400
# Collecting raw data, count == 32500
# Collecting raw data, count == 32600
# Collecting raw data, count == 32700
# Collecting raw data, count == 32800
# Collecting raw data, count == 32900
# Collecting raw data, count == 33000
# Collecting raw data, count == 33100
# Collecting raw data, count == 33200
# Collecting raw data, count == 33300
# Collecting raw data, count == 33400
# Collecting raw data, count == 33500
# Collecting raw data, count == 33600
# Collecting raw data, count == 33700
# Collecting raw data, count == 33800
# Collecting raw data, count == 33900
# Collecting raw data, count == 34000
# Collecting raw data, count == 34100
# Collecting raw data, count == 34200
# Collecting raw data, count == 34300
# Collecting raw data, count == 34400
# Collecting raw data, count == 34500
# Collecting raw data, count == 34600
# Collecting raw data, count == 34700
# Collecting raw data, count == 34800
# Collecting raw data, count == 34900
# Collecting raw data, count == 35000
# Collecting raw data, count == 35100
# Collecting raw data, count == 35200
# Collecting raw data, count == 35300
# Collecting raw data, count == 35400
# Collecting raw data, count == 35500
# Collecting raw data, count == 35600
# Collecting raw data, count == 35700
# Collecting raw data, count == 35800
# Collecting raw data, count == 35900
# Collecting raw data, count == 36000
# Collecting raw data, count == 36100
# Collecting raw data, count == 36200
# Collecting raw data, count == 36300
# Collecting raw data, count == 36400
# Collecting raw data, count == 36500
# Collecting raw data, count == 36600
# Collecting raw data, count == 36700
# Collecting raw data, count == 36800
# Collecting raw data, count == 36900
# Collecting raw data, count == 37000
# Collecting raw data, count == 37100
# Collecting raw data, count == 37200
# Collecting raw data, count == 37300
# Collecting raw data, count == 37400
# Collecting raw data, count == 37500
# Collecting raw data, count == 37600
# Collecting raw data, count == 37700
# Collecting raw data, count == 37800
# Collecting raw data, count == 37900
# Collecting raw data, count == 38000
# Collecting raw data, count == 38100
# Collecting raw data, count == 38200
# Collecting raw data, count == 38300
# Collecting raw data, count == 38400
# Collecting raw data, count == 38500
# Collecting raw data, count == 38600
# Collecting raw data, count == 38700
# Collecting raw data, count == 38800
# Collecting raw data, count == 38900
# Collecting raw data, count == 39000
# Collecting raw data, count == 39100
# Collecting raw data, count == 39200
# Collecting raw data, count == 39300
# Collecting raw data, count == 39400
# Collecting raw data, count == 39500
# Collecting raw data, count == 39600
# Collecting raw data, count == 39700
# Collecting raw data, count == 39800
# Collecting raw data, count == 39900
# Collecting raw data, count == 40000
# Collecting raw data, count == 40100
# Collecting raw data, count == 40200
# Collecting raw data, count == 40300
# Collecting raw data, count == 40400
# Collecting raw data, count == 40500
# Collecting raw data, count == 40600
# Collecting raw data, count == 40700
# Collecting raw data, count == 40800
# Collecting raw data, count == 40900
# Collecting raw data, count == 41000
# Collecting raw data, count == 41100
# Collecting raw data, count == 41200
# Collecting raw data, count == 41300
# Collecting raw data, count == 41400
# Collecting raw data, count == 41500
# Collecting raw data, count == 41600
# Collecting raw data, count == 41700
# Collecting raw data, count == 41800
# Collecting raw data, count == 41900
# Collecting raw data, count == 42000
# Collecting raw data, count == 42100
# Collecting raw data, count == 42200
# Collecting raw data, count == 42300
# Collecting raw data, count == 42400
# Collecting raw data, count == 42500
# Collecting raw data, count == 42600
# Collecting raw data, count == 42700
# Collecting raw data, count == 42800
# Collecting raw data, count == 42900
# Collecting raw data, count == 43000
# Collecting raw data, count == 43100
# Collecting raw data, count == 43200
# Collecting raw data, count == 43300
# Collecting raw data, count == 43400
# Collecting raw data, count == 43500
# Collecting raw data, count == 43600
# Collecting raw data, count == 43700
# Collecting raw data, count == 43800
# Collecting raw data, count == 43900
# Collecting raw data, count == 44000
# Collecting raw data, count == 44100
# Collecting raw data, count == 44200
# Collecting raw data, count == 44300
# Collecting raw data, count == 44400
# Collecting raw data, count == 44500
# Collecting raw data, count == 44600
# Collecting raw data, count == 44700
# Collecting raw data, count == 44800
# Collecting raw data, count == 44900
# Collecting raw data, count == 45000
# Collecting raw data, count == 45100
# Collecting raw data, count == 45200
# Collecting raw data, count == 45300
# Collecting raw data, count == 45400
# Collecting raw data, count == 45500
# Collecting raw data, count == 45600
# Collecting raw data, count == 45700
# Collecting raw data, count == 45800
# Collecting raw data, count == 45900
# Collecting raw data, count == 46000
# Collecting raw data, count == 46100
# Collecting raw data, count == 46200
# Collecting raw data, count == 46300
# Collecting raw data, count == 46400
# Collecting raw data, count == 46500
# Collecting raw data, count == 46600
# Collecting raw data, count == 46700
# Collecting raw data, count == 46800
# Collecting raw data, count == 46900
# Collecting raw data, count == 47000
# Collecting raw data, count == 47100
# Collecting raw data, count == 47200
# Collecting raw data, count == 47300
# Collecting raw data, count == 47400
# Collecting raw data, count == 47500
# Collecting raw data, count == 47600
# Collecting raw data, count == 47700
# Collecting raw data, count == 47800
# Collecting raw data, count == 47900
# Collecting raw data, count == 48000
# Collecting raw data, count == 48100
# Collecting raw data, count == 48200
# Collecting raw data, count == 48300
# Collecting raw data, count == 48400
# Collecting raw data, count == 48500
# Collecting raw data, count == 48600
# Collecting raw data, count == 48700
# Collecting raw data, count == 48800
# Collecting raw data, count == 48900
# Collecting raw data, count == 49000
# Collecting raw data, count == 49100
# Collecting raw data, count == 49200
# Collecting raw data, count == 49300
# Collecting raw data, count == 49400
# Collecting raw data, count == 49500
# Collecting raw data, count == 49600
# Collecting raw data, count == 49700
# Collecting raw data, count == 49800
# Collecting raw data, count == 49900
# Collecting raw data, count == 50000
# Collecting raw data, count == 50100
# Collecting raw data, count == 50200
# Collecting raw data, count == 50300
# Collecting raw data, count == 50400
# Collecting raw data, count == 50500
# Collecting raw data, count == 50600
# Collecting raw data, count == 50700
# Collecting raw data, count == 50800
# Collecting raw data, count == 50900
# Collecting raw data, count == 51000
# Collecting raw data, count == 51100
# Collecting raw data, count == 51200
# Collecting raw data, count == 51300
# Collecting raw data, count == 51400
# Collecting raw data, count == 51500
# Collecting raw data, count == 51600
# Collecting raw data, count == 51700
# Collecting raw data, count == 51800
# Collecting raw data, count == 51900
# Collecting raw data, count == 52000
# Collecting raw data, count == 52100
# Collecting raw data, count == 52200
# Collecting raw data, count == 52300
# Collecting raw data, count == 52400
# Collecting raw data, count == 52500
# Collecting raw data, count == 52600
# Collecting raw data, count == 52700
# Collecting raw data, count == 52800
# Collecting raw data, count == 52900
# Collecting raw data, count == 53000
# Collecting raw data, count == 53100
# Collecting raw data, count == 53200
# Collecting raw data, count == 53300
# Collecting raw data, count == 53400
# Collecting raw data, count == 53500
# Collecting raw data, count == 53600
# Collecting raw data, count == 53700
# Collecting raw data, count == 53800
# Collecting raw data, count == 53900
# Collecting raw data, count == 54000
# Collecting raw data, count == 54100
# Collecting raw data, count == 54200
# Collecting raw data, count == 54300
# Collecting raw data, count == 54400
# Collecting raw data, count == 54500
# Collecting raw data, count == 54600
# Collecting raw data, count == 54700
# Collecting raw data, count == 54800
# Collecting raw data, count == 54900
# Collecting raw data, count == 55000
# Collecting raw data, count == 55100
# Collecting raw data, count == 55200
# Collecting raw data, count == 55300
# Collecting raw data, count == 55400
# Collecting raw data, count == 55500
# Collecting raw data, count == 55600
# Collecting raw data, count == 55700
# Collecting raw data, count == 55800
# Collecting raw data, count == 55900
# Collecting raw data, count == 56000
# Collecting raw data, count == 56100
# Collecting raw data, count == 56200
# Collecting raw data, count == 56300
# Collecting raw data, count == 56400
# Collecting raw data, count == 56500
# Collecting raw data, count == 56600
# Collecting raw data, count == 56700
# Collecting raw data, count == 56800
# Collecting raw data, count == 56900
# Collecting raw data, count == 57000
# Collecting raw data, count == 57100
# Collecting raw data, count == 57200
# Collecting raw data, count == 57300
# Collecting raw data, count == 57400
# Collecting raw data, count == 57500
# Collecting raw data, count == 57600
# Collecting raw data, count == 57700
# Collecting raw data, count == 57800
# Collecting raw data, count == 57900
# Collecting raw data, count == 58000
# Collecting raw data, count == 58100
# Collecting raw data, count == 58200
# Collecting raw data, count == 58300
# Collecting raw data, count == 58400
# Collecting raw data, count == 58500
# Collecting raw data, count == 58600
# Collecting raw data, count == 58700
# Collecting raw data, count == 58800
# Collecting raw data, count == 58900
# Collecting raw data, count == 59000
# Collecting raw data, count == 59100
# Collecting raw data, count == 59200
# Collecting raw data, count == 59300
# Collecting raw data, count == 59400
# Collecting raw data, count == 59500
# Collecting raw data, count == 59600
# Collecting raw data, count == 59700
# Collecting raw data, count == 59800
# Collecting raw data, count == 59900
# Collecting raw data, count == 60000
# Collecting raw data, count == 60100
# Collecting raw data, count == 60200
# Collecting raw data, count == 60300
# Collecting raw data, count == 60400
# Collecting raw data, count == 60500
# Collecting raw data, count == 60600
# Collecting raw data, count == 60700
# Collecting raw data, count == 60800
# Collecting raw data, count == 60900
# Collecting raw data, count == 61000
# Collecting raw data, count == 61100
# Collecting raw data, count == 61200
# Collecting raw data, count == 61300
# Collecting raw data, count == 61400
# Collecting raw data, count == 61500
# Collecting raw data, count == 61600
# Collecting raw data, count == 61700
# Collecting raw data, count == 61800
# Collecting raw data, count == 61900
# Collecting raw data, count == 62000
# Collecting raw data, count == 62100
# Collecting raw data, count == 62200
# Collecting raw data, count == 62300
# Collecting raw data, count == 62400
# Collecting raw data, count == 62500
# Collecting raw data, count == 62600
# Collecting raw data, count == 62700
# Collecting raw data, count == 62800
# Collecting raw data, count == 62900
# Collecting raw data, count == 63000
# Collecting raw data, count == 63100
# Collecting raw data, count == 63200
# Collecting raw data, count == 63300
# Collecting raw data, count == 63400
# Collecting raw data, count == 63500
# Collecting raw data, count == 63600
# Collecting raw data, count == 63700
# Collecting raw data, count == 63800
# Collecting raw data, count == 63900
# Collecting raw data, count == 64000
# Collecting raw data, count == 64100
# Collecting raw data, count == 64200
# Collecting raw data, count == 64300
# Collecting raw data, count == 64400
# Collecting raw data, count == 64500
# Collecting raw data, count == 64600
# Collecting raw data, count == 64700
# Collecting raw data, count == 64800
# Collecting raw data, count == 64900
# Collecting raw data, count == 65000
# Collecting raw data, count == 65100
# Collecting raw data, count == 65200
# Collecting raw data, count == 65300
# Collecting raw data, count == 65400
# Collecting raw data, count == 65500
# Collecting raw data, count == 65600
# Collecting raw data, count == 65700
# Collecting raw data, count == 65800
# Collecting raw data, count == 65900
# Collecting raw data, count == 66000
# Collecting raw data, count == 66100
# Collecting raw data, count == 66200
# Collecting raw data, count == 66300
# Collecting raw data, count == 66400
# Collecting raw data, count == 66500
# Collecting raw data, count == 66600
# Collecting raw data, count == 66700
# Collecting raw data, count == 66800
# Collecting raw data, count == 66900
# Collecting raw data, count == 67000
# Collecting raw data, count == 67100
# Collecting raw data, count == 67200
# Collecting raw data, count == 67300
# Collecting raw data, count == 67400
# Collecting raw data, count == 67500
# Collecting raw data, count == 67600
# Collecting raw data, count == 67700
# Collecting raw data, count == 67800
# Collecting raw data, count == 67900
# Collecting raw data, count == 68000
# Collecting raw data, count == 68100
# Collecting raw data, count == 68200
# Number of raw records of traceroute is 68268
#
#
# De-duplication result:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-6a728b3572a0> in <module>()
#       8         print('{}. Now the pair is {} / {}'.format(count, src_site_name, dest_site_name))
#       9         print()
# ---> 10         collect_and_clean(src_site_name, dest_site_name)
#      11         print('=============================================================================')
#      12         if count == 1:
#
# <ipython-input-44-8e4dfa6be6e4> in collect_and_clean(src_site_name, dest_site_name)
#      78     print()
#      79     print('De-duplication result:')
# ---> 80     print(raw_data_pool[src_site_name][dest_site_name].count(axis='index'))
#      81
#      82 #     # Sort in-place
#
# KeyError: '192.170.227.160'

# %%
a = pd.DataFrame(list(set_timestamp))
a.min()   # 07/28/2016  ==  1469724756000
a.max()   # 08/05/2016  ==  1470398661000  just now
print('No path records involving MWT2 three sites')
# 1) 'srcProduction': True
# 2) 'destProduction': True
# 3) 'gte': '2016-01-01'
# Number of raw records of traceroute is 68268
# Out:
# No path records involving MWT2 three sites
