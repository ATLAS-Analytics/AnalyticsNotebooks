# %%
from IPython.display import HTML

# %% [markdown]
# # FTAG
# ART status for:
# [DATA17](#DATA17Mainstream)
# [MC16](#MC16)<br>
# Plots for :
# [DATA17](#data17)
# [MC16](#mc16)

# %% [markdown]
# ### DATA17Mainstream
# [TOP](#FTAG)

# %%
HTML(filename='web/status_data17_TAUP.html')
# Out:
# <style  type="text/css" >
#     #T_3a2383e6_2790_11e8_97b1_001b215b3eebrow0_col0 {
#             background-color:  green;
#         }    #T_3a2383e6_2790_11e8_97b1_001b215b3eebrow0_col1 {
#             background-color:  green;
#         }    #T_3a2383e6_2790_11e8_97b1_001b215b3eebrow0_col2 {
#             background-color:  green;
#         }    #T_3a2383e6_2790_11e8_97b1_001b215b3eebrow0_col3 {
#             background-color:  green;
#         }    #T_3a2383e6_2790_11e8_97b1_001b215b3eebrow0_col4 {
#             background-color:  green;
#         }    #T_3a2383e6_2790_11e8_97b1_001b215b3eebrow0_col5 {
#             background-color:  green;
#         }    #T_3a2383e6_2790_11e8_97b1_001b215b3eebrow0_col6 {
#             background-color:  green;
#         }    #T_3a2383e6_2790_11e8_97b1_001b215b3eebrow0_col7 {
#             background-color:  green;
#         }    #T_3a2383e6_2790_11e8_97b1_001b215b3eebrow0_col8 {
#             background-color:  green;
# ...

# %% [markdown]
# ### MC16
# [TOP](#FTAG)

# %%
HTML(filename='web/status_mc16_TAUP.html')
# Out:
# <style  type="text/css" >
#     #T_3c3e4b20_2790_11e8_97b1_001b215b3eebrow0_col0 {
#             background-color:  green;
#         }    #T_3c3e4b20_2790_11e8_97b1_001b215b3eebrow0_col1 {
#             background-color:  green;
#         }    #T_3c3e4b20_2790_11e8_97b1_001b215b3eebrow0_col2 {
#             background-color:  green;
#         }    #T_3c3e4b20_2790_11e8_97b1_001b215b3eebrow0_col3 {
#             background-color:  red;
#         }    #T_3c3e4b20_2790_11e8_97b1_001b215b3eebrow0_col4 {
#             background-color:  red;
#         }    #T_3c3e4b20_2790_11e8_97b1_001b215b3eebrow0_col5 {
#             background-color:  green;
#         }    #T_3c3e4b20_2790_11e8_97b1_001b215b3eebrow0_col6 {
#             background-color:  green;
#         }    #T_3c3e4b20_2790_11e8_97b1_001b215b3eebrow0_col7 {
#             background-color:  green;
#         }    #T_3c3e4b20_2790_11e8_97b1_001b215b3eebrow0_col8 {
#             background-color:  green;
# ...

# %% [markdown]
# ## data17
# [TOP](#FTAG)

# %% [markdown]
# ### cpu consumption time [seconds]
# <img src="./plots/cpuconsumptiontime_data17_FTAG.png" width=120% align='center'>
# ### max pss [MB]
# <img src="./plots/maxpss_data17_FTAG.png" width=120% align='center'>
# ### max vmem [MB]
# <img src="./plots/maxvmem_data17_FTAG.png" width=120% align='center'>
# ### Size fraction [%]
# <img src="./plots/outputfilebytes_data17_FTAG.png" width=120% align='center'>
# ### Event fraction [%]
# <img src="./plots/nevents_data17_FTAG.png" width=120% align='center'>

# %% [markdown]
# ## mc16
# [TOP](#FTAG)

# %% [markdown]
# ### cpu consumption time [seconds]
# <img src="./plots/cpuconsumptiontime_mc16_FTAG.png" width=120% align='center'>
# ### max pss [MB]
# <img src="./plots/maxpss_mc16_FTAG.png" width=120% align='center'>
# ### max vmem [MB]
# <img src="./plots/maxvmem_mc16_FTAG.png" width=120% align='center'>
# ### Size fraction [%]
# <img src="./plots/outputfilebytes_mc16_FTAG.png" width=120% align='center'>
# ### Event fraction [%]
# <img src="./plots/nevents_mc16_FTAG.png" width=120% align='center'>
