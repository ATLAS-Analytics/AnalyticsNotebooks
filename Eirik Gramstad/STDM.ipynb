# %%
from IPython.display import HTML
name = "STDM"

# %% [markdown]
# # STDM
# ART status for:
# [DATA17](#DATA17Mainstream)
# [MC16](#MC16)<br>
# Plots for :
# [DATA17](#data17)
# [MC16](#mc16)

# %% [markdown]
# ### DATA17Mainstream
# [TOP](#STDM)

# %%
HTML(filename='web/status_data17_%s.html'%name)
# Out:
# <style  type="text/css" >
#     #T_3b120580_22a8_11e8_97b1_001b215b3eebrow0_col0 {
#             background-color:  green;
#         }    #T_3b120580_22a8_11e8_97b1_001b215b3eebrow0_col1 {
#             background-color:  green;
#         }    #T_3b120580_22a8_11e8_97b1_001b215b3eebrow0_col2 {
#             background-color:  green;
#         }    #T_3b120580_22a8_11e8_97b1_001b215b3eebrow0_col3 {
#             background-color:  green;
#         }    #T_3b120580_22a8_11e8_97b1_001b215b3eebrow0_col4 {
#             background-color:  green;
#         }    #T_3b120580_22a8_11e8_97b1_001b215b3eebrow0_col5 {
#             background-color:  green;
#         }    #T_3b120580_22a8_11e8_97b1_001b215b3eebrow0_col6 {
#             background-color:  green;
#         }    #T_3b120580_22a8_11e8_97b1_001b215b3eebrow0_col7 {
#             background-color:  green;
#         }    #T_3b120580_22a8_11e8_97b1_001b215b3eebrow0_col8 {
#             background-color:  green;
# ...

# %% [markdown]
# ### MC16
# [TOP](#STDM)

# %%
HTML(filename='web/status_mc16_%s.html'%name)
# Out:
# <style  type="text/css" >
#     #T_3c446092_22a8_11e8_97b1_001b215b3eebrow0_col0 {
#             background-color:  green;
#         }    #T_3c446092_22a8_11e8_97b1_001b215b3eebrow0_col1 {
#             background-color:  green;
#         }    #T_3c446092_22a8_11e8_97b1_001b215b3eebrow0_col2 {
#             background-color:  green;
#         }    #T_3c446092_22a8_11e8_97b1_001b215b3eebrow0_col3 {
#             background-color:  green;
#         }    #T_3c446092_22a8_11e8_97b1_001b215b3eebrow0_col4 {
#             background-color:  green;
#         }    #T_3c446092_22a8_11e8_97b1_001b215b3eebrow0_col5 {
#             background-color:  green;
#         }    #T_3c446092_22a8_11e8_97b1_001b215b3eebrow0_col6 {
#             background-color:  green;
#         }    #T_3c446092_22a8_11e8_97b1_001b215b3eebrow0_col7 {
#             background-color:  green;
#         }    #T_3c446092_22a8_11e8_97b1_001b215b3eebrow0_col8 {
#             background-color:  red;
# ...

# %% [markdown]
# ## data17
# [TOP](#STDM)

# %% [markdown]
# ### cpu consumption time [seconds]
# <img src="./plots/cpuconsumptiontime_data17_STDM.png" width=120% align='center'>
# ### max pss [MB]
# <img src="./plots/maxpss_data17_STDM.png" width=120% align='center'>
# ### max vmem [MB]
# <img src="./plots/maxvmem_data17_STDM.png" width=120% align='center'>
# ### Size fraction [%]
# <img src="./plots/outputfilebytes_data17_STDM.png" width=120% align='center'>
# ### Event fraction [%]
# <img src="./plots/nevents_data17_STDM.png" width=120% align='center'>

# %% [markdown]
# ## mc16
# [TOP](#STDM)

# %% [markdown]
# ### cpu consumption time [seconds]
# <img src="./plots/cpuconsumptiontime_mc16_STDM.png" width=120% align='center'>
# ### max pss [MB]
# <img src="./plots/maxpss_mc16_STDM.png" width=120% align='center'>
# ### max vmem [MB]
# <img src="./plots/maxvmem_mc16_STDM.png" width=120% align='center'>
# ### Size fraction [%]
# <img src="./plots/outputfilebytes_mc16_STDM.png" width=120% align='center'>
# ### Event fraction [%]
# <img src="./plots/nevents_mc16_STDM.png" width=120% align='center'>
