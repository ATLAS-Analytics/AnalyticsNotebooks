# %%
from IPython.display import HTML

# %% [markdown]
# # BPHYS
# ART status for:
# [BPHYSLS](#BPHYSLSstream)
# [DATA17](#DATA17Mainstream)
# [DELAYED](#BPHYSDELAYEDstream)
# [MC16](#MC16)<br>
# Plots for :
# [BPHYSLS](#BPHYSLS)
# [DATA17](#data17)
# [DELAYED](#delayed)
# [MC16](#mc16)

# %% [markdown]
# ## ART STATUS
# ### BPHYSLSstream
# [TOP](#BPHYS)

# %%
HTML(filename='web/status_BPHYSLS_BPHY.html')
# Out:
# <style  type="text/css" >
#     #T_3c64b3b4_2790_11e8_97b1_001b215b3eebrow0_col0 {
#             background-color:  red;
#         }    #T_3c64b3b4_2790_11e8_97b1_001b215b3eebrow0_col1 {
#             background-color:  green;
#         }    #T_3c64b3b4_2790_11e8_97b1_001b215b3eebrow0_col2 {
#             background-color:  green;
#         }    #T_3c64b3b4_2790_11e8_97b1_001b215b3eebrow0_col3 {
#             background-color:  green;
#         }    #T_3c64b3b4_2790_11e8_97b1_001b215b3eebrow0_col4 {
#             background-color:  green;
#         }    #T_3c64b3b4_2790_11e8_97b1_001b215b3eebrow0_col5 {
#             background-color:  green;
#         }    #T_3c64b3b4_2790_11e8_97b1_001b215b3eebrow0_col6 {
#             background-color:  green;
#         }    #T_3c64b3b4_2790_11e8_97b1_001b215b3eebrow0_col7 {
#             background-color:  green;
#         }    #T_3c64b3b4_2790_11e8_97b1_001b215b3eebrow0_col8 {
#             background-color:  green;
# ...

# %% [markdown]
# ### BPHYSDELAYEDstream
# [TOP](#BPHYS)

# %%
HTML(filename='web/status_DELAYED_BPHY.html')
# Out:
# <style  type="text/css" >
#     #T_38133524_2790_11e8_97b1_001b215b3eebrow0_col0 {
#             background-color:  green;
#         }    #T_38133524_2790_11e8_97b1_001b215b3eebrow0_col1 {
#             background-color:  green;
#         }    #T_38133524_2790_11e8_97b1_001b215b3eebrow0_col2 {
#             background-color:  green;
#         }    #T_38133524_2790_11e8_97b1_001b215b3eebrow0_col3 {
#             background-color:  green;
#         }    #T_38133524_2790_11e8_97b1_001b215b3eebrow0_col4 {
#             background-color:  green;
#         }    #T_38133524_2790_11e8_97b1_001b215b3eebrow0_col5 {
#             background-color:  green;
#         }    #T_38133524_2790_11e8_97b1_001b215b3eebrow0_col6 {
#             background-color:  green;
#         }    #T_38133524_2790_11e8_97b1_001b215b3eebrow0_col7 {
#             background-color:  green;
#         }    #T_38133524_2790_11e8_97b1_001b215b3eebrow0_col8 {
#             background-color:  green;
# ...

# %% [markdown]
# ### DATA17Mainstream
# [TOP](#BPHYS)

# %%
HTML(filename='web/status_data17_BPHY.html')
# Out:
# <style  type="text/css" >
#     #T_39a01a38_2790_11e8_97b1_001b215b3eebrow0_col0 {
#             background-color:  green;
#         }    #T_39a01a38_2790_11e8_97b1_001b215b3eebrow0_col1 {
#             background-color:  green;
#         }    #T_39a01a38_2790_11e8_97b1_001b215b3eebrow0_col2 {
#             background-color:  green;
#         }    #T_39a01a38_2790_11e8_97b1_001b215b3eebrow0_col3 {
#             background-color:  green;
#         }    #T_39a01a38_2790_11e8_97b1_001b215b3eebrow0_col4 {
#             background-color:  red;
#         }    #T_39a01a38_2790_11e8_97b1_001b215b3eebrow0_col5 {
#             background-color:  green;
#         }    #T_39a01a38_2790_11e8_97b1_001b215b3eebrow0_col6 {
#             background-color:  green;
#         }    #T_39a01a38_2790_11e8_97b1_001b215b3eebrow0_col7 {
#             background-color:  green;
#         }    #T_39a01a38_2790_11e8_97b1_001b215b3eebrow0_col8 {
#             background-color:  green;
# ...

# %% [markdown]
# ### MC16
# [TOP](#BPHYS)

# %%
HTML(filename='web/status_mc16_BPHY.html')
# Out:
# <style  type="text/css" >
#     #T_3bc41d00_2790_11e8_97b1_001b215b3eebrow0_col0 {
#             background-color:  green;
#         }    #T_3bc41d00_2790_11e8_97b1_001b215b3eebrow0_col1 {
#             background-color:  green;
#         }    #T_3bc41d00_2790_11e8_97b1_001b215b3eebrow0_col2 {
#             background-color:  green;
#         }    #T_3bc41d00_2790_11e8_97b1_001b215b3eebrow0_col3 {
#             background-color:  green;
#         }    #T_3bc41d00_2790_11e8_97b1_001b215b3eebrow0_col4 {
#             background-color:  red;
#         }    #T_3bc41d00_2790_11e8_97b1_001b215b3eebrow0_col5 {
#             background-color:  green;
#         }    #T_3bc41d00_2790_11e8_97b1_001b215b3eebrow0_col6 {
#             background-color:  green;
#         }    #T_3bc41d00_2790_11e8_97b1_001b215b3eebrow0_col7 {
#             background-color:  green;
#         }    #T_3bc41d00_2790_11e8_97b1_001b215b3eebrow0_col8 {
#             background-color:  green;
# ...

# %% [markdown]
# ## bphysls
# [TOP](#BPHYS)

# %% [markdown]
# ### cpu consumption time [seconds]
# <img src="./plots/cpuconsumptiontime_BPHYSLS_BPHY.png" width=120% align='center'>
# ### max pss [MB]
# <img src="./plots/maxpss_BPHYSLS_BPHY.png" width=120% align='center'>
# ### max vmem [MB]
# <img src="./plots/maxvmem_BPHYSLS_BPHY.png" width=120% align='center'>
# ### Size fraction [%]
# <img src="./plots/outputfilebytes_BPHYSLS_BPHY.png" width=120% align='center'>
# ### Event fraction [%]
# <img src="./plots/nevents_BPHYSLS_BPHY.png" width=120% align='center'>

# %% [markdown]
# ## data17
# [TOP](#BPHYS)

# %% [markdown]
# ### cpu consumption time [seconds]
# <img src="./plots/cpuconsumptiontime_data17_BPHY.png" width=120% align='center'>
# ### max pss [MB]
# <img src="./plots/maxpss_data17_BPHY.png" width=120% align='center'>
# ### max vmem [MB]
# <img src="./plots/maxvmem_data17_BPHY.png" width=120% align='center'>
# ### Size fraction [%]
# <img src="./plots/outputfilebytes_data17_BPHY.png" width=120% align='center'>
# ### Event fraction [%]
# <img src="./plots/nevents_data17_BPHY.png" width=120% align='center'>

# %% [markdown]
# ## delayed
# [TOP](#BPHYS)

# %% [markdown]
# ### cpu consumption time [seconds]
# <img src="./plots/cpuconsumptiontime_DELAYED_BPHY.png" width=120% align='center'>
# ### max pss [MB]
# <img src="./plots/maxpss_DELAYED_BPHY.png" width=120% align='center'>
# ### max vmem [MB]
# <img src="./plots/maxvmem_DELAYED_BPHY.png" width=120% align='center'>
# ### Size fraction [%]
# <img src="./plots/outputfilebytes_DELAYED_BPHY.png" width=120% align='center'>
# ### Event fraction [%]
# <img src="./plots/nevents_DELAYED_BPHY.png" width=120% align='center'>

# %% [markdown]
# ## mc16
# [TOP](#BPHYS)

# %% [markdown]
# ### cpu consumption time [seconds]
# <img src="./plots/cpuconsumptiontime_DELAYED_BPHY.png" width=120% align='center'>
# ### max pss [MB]
# <img src="./plots/maxpss_DELAYED_BPHY.png" width=120% align='center'>
# ### max vmem [MB]
# <img src="./plots/maxvmem_DELAYED_BPHY.png" width=120% align='center'>
# ### Size fraction [%]
# <img src="./plots/outputfilebytes_DELAYED_BPHY.png" width=120% align='center'>
# ### Event fraction [%]
# <img src="./plots/nevents_DELAYED_BPHY.png" width=120% align='center'>
