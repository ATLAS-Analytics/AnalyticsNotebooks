# %%
from IPython.display import HTML
from os import listdir
from os.path import isfile, join

# %%
onlyfiles = [f for f in listdir("./web/") if isfile(join("./web/", f))]

# %%
html = []
for of in onlyfiles:
    html.append(HTML(filename='web/%s'%of))

# %%
html[0]
# Out:
# <style  type="text/css" >
#     #T_a65d79fe_206f_11e8_bb76_001b215b3eebrow0_col0 {
#             background-color:  green;
#         }    #T_a65d79fe_206f_11e8_bb76_001b215b3eebrow0_col1 {
#             background-color:  red;
#         }    #T_a65d79fe_206f_11e8_bb76_001b215b3eebrow0_col2 {
#             background-color:  green;
#         }    #T_a65d79fe_206f_11e8_bb76_001b215b3eebrow0_col3 {
#             background-color:  green;
#         }    #T_a65d79fe_206f_11e8_bb76_001b215b3eebrow0_col4 {
#             background-color:  green;
#         }    #T_a65d79fe_206f_11e8_bb76_001b215b3eebrow0_col5 {
#             background-color:  green;
#         }    #T_a65d79fe_206f_11e8_bb76_001b215b3eebrow0_col6 {
#             background-color:  green;
#         }    #T_a65d79fe_206f_11e8_bb76_001b215b3eebrow0_col7 {
#             background-color:  green;
#         }    #T_a65d79fe_206f_11e8_bb76_001b215b3eebrow0_col8 {
#             background-color:  green;
# ...

# %%
html[1]
# Out:
# <style  type="text/css" >
#     #T_a98b5d8a_206f_11e8_bb76_001b215b3eebrow0_col0 {
#             background-color:  green;
#         }    #T_a98b5d8a_206f_11e8_bb76_001b215b3eebrow0_col1 {
#             background-color:  green;
#         }    #T_a98b5d8a_206f_11e8_bb76_001b215b3eebrow0_col2 {
#             background-color:  green;
#         }    #T_a98b5d8a_206f_11e8_bb76_001b215b3eebrow0_col3 {
#             background-color:  green;
#         }    #T_a98b5d8a_206f_11e8_bb76_001b215b3eebrow0_col4 {
#             background-color:  green;
#         }    #T_a98b5d8a_206f_11e8_bb76_001b215b3eebrow0_col5 {
#             background-color:  green;
#         }    #T_a98b5d8a_206f_11e8_bb76_001b215b3eebrow0_col6 {
#             background-color:  green;
#         }    #T_a98b5d8a_206f_11e8_bb76_001b215b3eebrow0_col7 {
#             background-color:  green;
#         }    #T_a98b5d8a_206f_11e8_bb76_001b215b3eebrow0_col8 {
#             background-color:  green;
# ...
