# %%
from IPython.display import HTML
name = "EXOT"

# %% [markdown]
# # EXOT
# ART status for:
# [DATA17](#DATA17Mainstream)
# [MC16](#MC16)<br>
# Plots for :
# [DATA17](#data17)
# [MC16](#mc16)

# %% [markdown]
# ### DATA17Mainstream
# [TOP](#EXOT)

# %%
HTML(filename='web/status_data18_%s.html'%name)
# Out:
# <style  type="text/css" >
#     #T_d76c4124_4c4d_11e8_bbc7_0242eae79c31row0_col0 {
#             background-color:  green;
#         }    #T_d76c4124_4c4d_11e8_bbc7_0242eae79c31row0_col1 {
#             background-color:  green;
#         }    #T_d76c4124_4c4d_11e8_bbc7_0242eae79c31row1_col0 {
#             background-color:  green;
#         }    #T_d76c4124_4c4d_11e8_bbc7_0242eae79c31row1_col1 {
#             background-color:  green;
#         }    #T_d76c4124_4c4d_11e8_bbc7_0242eae79c31row2_col0 {
#             background-color:  green;
#         }    #T_d76c4124_4c4d_11e8_bbc7_0242eae79c31row2_col1 {
#             background-color:  green;
#         }    #T_d76c4124_4c4d_11e8_bbc7_0242eae79c31row3_col0 {
#             background-color:  green;
#         }    #T_d76c4124_4c4d_11e8_bbc7_0242eae79c31row3_col1 {
#             background-color:  green;
#         }    #T_d76c4124_4c4d_11e8_bbc7_0242eae79c31row4_col0 {
#             background-color:  green;
# ...

# %% [markdown]
# ### MC16
# [TOP](#EXOT)

# %%
HTML(filename='web/status_mc16_%s.html'%name)
# Out:
# <style  type="text/css" >
#     #T_d7be8e70_4c4d_11e8_bbc7_0242eae79c31row0_col0 {
#             background-color:  green;
#         }    #T_d7be8e70_4c4d_11e8_bbc7_0242eae79c31row0_col1 {
#             background-color:  green;
#         }    #T_d7be8e70_4c4d_11e8_bbc7_0242eae79c31row0_col2 {
#             background-color:  green;
#         }    #T_d7be8e70_4c4d_11e8_bbc7_0242eae79c31row0_col3 {
#             background-color:  green;
#         }    #T_d7be8e70_4c4d_11e8_bbc7_0242eae79c31row0_col4 {
#             background-color:  green;
#         }    #T_d7be8e70_4c4d_11e8_bbc7_0242eae79c31row1_col0 {
#             background-color:  green;
#         }    #T_d7be8e70_4c4d_11e8_bbc7_0242eae79c31row1_col1 {
#             background-color:  green;
#         }    #T_d7be8e70_4c4d_11e8_bbc7_0242eae79c31row1_col2 {
#             background-color:  green;
#         }    #T_d7be8e70_4c4d_11e8_bbc7_0242eae79c31row1_col3 {
#             background-color:  green;
# ...

# %% [markdown]
# ## data17
# [TOP](#EXOT)

# %% [markdown]
# ### cpu consumption time [seconds]
# <img src="./plots/cpuconsumptiontime_data17_EXOT.png" width=120% align='center'>
# ### max pss [MB]
# <img src="./plots/maxpss_data17_EXOT.png" width=120% align='center'>
# ### max vmem [MB]
# <img src="./plots/maxvmem_data17_EXOT.png" width=120% align='center'>
# ### Size fraction [%]
# <img src="./plots/outputfilebytes_data17_EXOT.png" width=120% align='center'>
# ### Event fraction [%]
# <img src="./plots/nevents_data17_EXOT.png" width=120% align='center'>

# %% [markdown]
# ## mc16
# [TOP](#EXOT)

# %% [markdown]
# ### cpu consumption time [seconds]
# <img src="./plots/cpuconsumptiontime_mc16_EXOT.png" width=120% align='center'>
# ### max pss [MB]
# <img src="./plots/maxpss_mc16_EXOT.png" width=120% align='center'>
# ### max vmem [MB]
# <img src="./plots/maxvmem_mc16_EXOT.png" width=120% align='center'>
# ### Size fraction [%]
# <img src="./plots/outputfilebytes_mc16_EXOT.png" width=120% align='center'>
# ### Event fraction [%]
# <img src="./plots/nevents_mc16_EXOT.png" width=120% align='center'>
