# %%
from IPython.display import HTML
name = "HIGGD"

# %% [markdown]
# # HIGG
# ART status for:
# [DATA17](#DATA17Mainstream)
# [MC16](#MC16)<br>
# Plots for :
# [DATA17](#data17)
# [MC16](#mc16)

# %% [markdown]
# ### DATA17Mainstream
# [TOP](#HIGG)

# %%
HTML(filename='web/status_data18_%s.html'%name)
# Out:
# <style  type="text/css" >
#     #T_c494e356_51cc_11e8_a056_0242eae79c31row0_col0 {
#             background-color:  red;
#         }    #T_c494e356_51cc_11e8_a056_0242eae79c31row0_col1 {
#             background-color:  green;
#         }    #T_c494e356_51cc_11e8_a056_0242eae79c31row0_col2 {
#             background-color:  green;
#         }    #T_c494e356_51cc_11e8_a056_0242eae79c31row0_col3 {
#             background-color:  green;
#         }    #T_c494e356_51cc_11e8_a056_0242eae79c31row0_col4 {
#             background-color:  green;
#         }    #T_c494e356_51cc_11e8_a056_0242eae79c31row0_col5 {
#             background-color:  green;
#         }    #T_c494e356_51cc_11e8_a056_0242eae79c31row0_col6 {
#             background-color:  green;
#         }    #T_c494e356_51cc_11e8_a056_0242eae79c31row1_col0 {
#             background-color:  red;
#         }    #T_c494e356_51cc_11e8_a056_0242eae79c31row1_col1 {
#             background-color:  green;
# ...

# %% [markdown]
# ### MC16
# [TOP](#HIGG)

# %%
HTML(filename='web/status_mc16_%s.html'%name)
# Out:
# <style  type="text/css" >
#     #T_c3dac2d2_51cc_11e8_a056_0242eae79c31row0_col0 {
#             background-color:  green;
#         }    #T_c3dac2d2_51cc_11e8_a056_0242eae79c31row0_col1 {
#             background-color:  green;
#         }    #T_c3dac2d2_51cc_11e8_a056_0242eae79c31row0_col2 {
#             background-color:  green;
#         }    #T_c3dac2d2_51cc_11e8_a056_0242eae79c31row0_col3 {
#             background-color:  green;
#         }    #T_c3dac2d2_51cc_11e8_a056_0242eae79c31row0_col4 {
#             background-color:  green;
#         }    #T_c3dac2d2_51cc_11e8_a056_0242eae79c31row0_col5 {
#             background-color:  green;
#         }    #T_c3dac2d2_51cc_11e8_a056_0242eae79c31row0_col6 {
#             background-color:  green;
#         }    #T_c3dac2d2_51cc_11e8_a056_0242eae79c31row0_col7 {
#             background-color:  green;
#         }    #T_c3dac2d2_51cc_11e8_a056_0242eae79c31row0_col8 {
#             background-color:  green;
# ...

# %% [markdown]
# ## data17
# [TOP](#HIGG)

# %% [markdown]
# ### cpu consumption time [seconds]
# <img src="./plots/cpuconsumptiontime_data17_HIGGD.png" width=120% align='center'>
# ### max pss [MB]
# <img src="./plots/maxpss_data17_HIGGD.png" width=120% align='center'>
# ### max vmem [MB]
# <img src="./plots/maxvmem_data17_HIGGD.png" width=120% align='center'>
# ### Size fraction [%]
# <img src="./plots/outputfilebytes_data17_HIGGD.png" width=120% align='center'>
# ### Event fraction [%]
# <img src="./plots/nevents_data17_HIGGD.png" width=120% align='center'>

# %% [markdown]
# ## mc16
# [TOP](#HIGG)

# %% [markdown]
# ### cpu consumption time [seconds]
# <img src="./plots/cpuconsumptiontime_mc16_HIGGD.png" width=120% align='center'>
# ### max pss [MB]
# <img src="./plots/maxpss_mc16_HIGGD.png" width=120% align='center'>
# ### max vmem [MB]
# <img src="./plots/maxvmem_mc16_HIGGD.png" width=120% align='center'>
# ### Size fraction [%]
# <img src="./plots/outputfilebytes_mc16_HIGGD.png" width=120% align='center'>
# ### Event fraction [%]
# <img src="./plots/nevents_mc16_HIGGD.png" width=120% align='center'>
