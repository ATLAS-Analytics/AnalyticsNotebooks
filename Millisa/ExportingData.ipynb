# %% [markdown]
# # Exporting frontier data for one task

# %%
import pandas as pd
import numpy as np

from elasticsearch import Elasticsearch, helpers
from elasticsearch.helpers import scan

es = Elasticsearch([{'host':'atlas-kibana.mwt2.org', 'port':9200}],timeout=60)

# %% [markdown]
# ## here change parameters

# %%
limit = 1000000        # maximum number of records to save
taskid = 14375483 # taskID to search for

# %%
my_query={
    "size": 0,
    "_source": ["pandaid","cached","sqlquery","disconn","querytime","queryiov","fsize"],
    "query": {
        "bool": {
            "must": [
                {
#                 "term": {"tableowner": ""},
                "term": {"taskid":taskid}
#           "term": {"computingsite":"BOINC-ES"}
                }
            ]
        }
    }
}

res = helpers.scan(es, query=my_query, index='frontier-new', scroll='5m', timeout="5m", size=1000)

data = []
counter = 0
for r in res:
    counter+=1
    if counter>limit: break
    if not counter%5000: print ("loaded:", counter)
    data.append(r['_source'])

print ('finished loading. total of',counter, 'rows.')
df = pd.DataFrame(data)
df
# Out:
# loaded: 1000
# loaded: 2000
# loaded: 3000
# loaded: 4000
# loaded: 5000
# loaded: 6000
# loaded: 7000
# loaded: 8000
# loaded: 9000
# loaded: 10000
# loaded: 11000
# loaded: 12000
# loaded: 13000
# loaded: 14000
# loaded: 15000
# loaded: 16000
# loaded: 17000
# loaded: 18000
# loaded: 19000
# loaded: 20000
# loaded: 21000
# loaded: 22000
# loaded: 23000
# loaded: 24000
# loaded: 25000
# loaded: 26000
# loaded: 27000
# loaded: 28000
# loaded: 29000
# loaded: 30000
# loaded: 31000
# loaded: 32000
# loaded: 33000
# loaded: 34000
# loaded: 35000
# loaded: 36000
# loaded: 37000
# loaded: 38000
# loaded: 39000
# loaded: 40000
# loaded: 41000
# loaded: 42000
# loaded: 43000
# loaded: 44000
# loaded: 45000
# loaded: 46000
# loaded: 47000
# loaded: 48000
# loaded: 49000
# loaded: 50000
# loaded: 51000
# loaded: 52000
# loaded: 53000
# loaded: 54000
# loaded: 55000
# loaded: 56000
# loaded: 57000
# loaded: 58000
# loaded: 59000
# loaded: 60000
# loaded: 61000
# loaded: 62000
# loaded: 63000
# loaded: 64000
# loaded: 65000
# loaded: 66000
# loaded: 67000
# loaded: 68000
# loaded: 69000
# loaded: 70000
# loaded: 71000
# loaded: 72000
# loaded: 73000
# loaded: 74000
# loaded: 75000
# loaded: 76000
# loaded: 77000
# loaded: 78000
# loaded: 79000
# loaded: 80000
# loaded: 81000
# loaded: 82000
# loaded: 83000
# loaded: 84000
# loaded: 85000
# loaded: 86000
# loaded: 87000
# loaded: 88000
# loaded: 89000
# loaded: 90000
# loaded: 91000
# loaded: 92000
# loaded: 93000
# loaded: 94000
# loaded: 95000
# loaded: 96000
# loaded: 97000
# loaded: 98000
# loaded: 99000
# loaded: 100000
# loaded: 101000
# loaded: 102000
# loaded: 103000
# loaded: 104000
# loaded: 105000
# loaded: 106000
# loaded: 107000
# loaded: 108000
# loaded: 109000
# loaded: 110000
# loaded: 111000
# loaded: 112000
# loaded: 113000
# loaded: 114000
# loaded: 115000
# loaded: 116000
# loaded: 117000
# loaded: 118000
# loaded: 119000
# loaded: 120000
# loaded: 121000
# loaded: 122000
# loaded: 123000
# loaded: 124000
# loaded: 125000
# loaded: 126000
# loaded: 127000
# loaded: 128000
# loaded: 129000
# loaded: 130000
# loaded: 131000
# loaded: 132000
# loaded: 133000
# loaded: 134000
# loaded: 135000
# loaded: 136000
# loaded: 137000
# loaded: 138000
# loaded: 139000
# loaded: 140000
# loaded: 141000
# loaded: 142000
# loaded: 143000
# loaded: 144000
# loaded: 145000
# loaded: 146000
# loaded: 147000
# loaded: 148000
# loaded: 149000
# loaded: 150000
# loaded: 151000
# loaded: 152000
# loaded: 153000
# loaded: 154000
# loaded: 155000
# loaded: 156000
# loaded: 157000
# loaded: 158000
# loaded: 159000
# loaded: 160000
# loaded: 161000
# loaded: 162000
# loaded: 163000
# loaded: 164000
# loaded: 165000
# loaded: 166000
# loaded: 167000
# loaded: 168000
# loaded: 169000
# loaded: 170000
# loaded: 171000
# loaded: 172000
# loaded: 173000
# loaded: 174000
# loaded: 175000
# loaded: 176000
# loaded: 177000
# loaded: 178000
# loaded: 179000
# loaded: 180000
# loaded: 181000
# loaded: 182000
# loaded: 183000
# loaded: 184000
# loaded: 185000
# loaded: 186000
# loaded: 187000
# loaded: 188000
# loaded: 189000
# loaded: 190000
# loaded: 191000
# loaded: 192000
# loaded: 193000
# loaded: 194000
# loaded: 195000
# loaded: 196000
# loaded: 197000
# loaded: 198000
# loaded: 199000
# loaded: 200000
# loaded: 201000
# loaded: 202000
# loaded: 203000
# loaded: 204000
# loaded: 205000
# loaded: 206000
# loaded: 207000
# loaded: 208000
# loaded: 209000
# loaded: 210000
# loaded: 211000
# loaded: 212000
# loaded: 213000
# loaded: 214000
# loaded: 215000
# loaded: 216000
# loaded: 217000
# loaded: 218000
# loaded: 219000
# loaded: 220000
# loaded: 221000
# loaded: 222000
# loaded: 223000
# loaded: 224000
# loaded: 225000
# loaded: 226000
# loaded: 227000
# loaded: 228000
# loaded: 229000
# loaded: 230000
# loaded: 231000
# loaded: 232000
# loaded: 233000
# loaded: 234000
# loaded: 235000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9d739672d17a> in <module>()
#      19 data = []
#      20 counter = 0
# ---> 21 for r in res:
#      22     counter+=1
#      23     if counter>limit: break
#
# /usr/local/lib/python3.5/dist-packages/elasticsearch/helpers/__init__.py in scan(client, query, scroll, raise_on_error, preserve_order, size, request_timeout, clear_scroll, scroll_kwargs, **kwargs)
#     377                 resp = client.scroll(scroll_id, scroll=scroll,
#     378                                      request_timeout=request_timeout,
# --> 379                                      **scroll_kwargs)
#     380
#     381             for hit in resp['hits']['hits']:
#
# /usr/local/lib/python3.5/dist-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#      74                 if p in kwargs:
#      75                     params[p] = kwargs.pop(p)
# ---> 76             return func(*args, params=params, **kwargs)
#      77         return _wrapped
#      78     return _wrapper
#
# /usr/local/lib/python3.5/dist-packages/elasticsearch/client/__init__.py in scroll(self, scroll_id, body, params)
#    1009
#    1010         return self.transport.perform_request('GET', '/_search/scroll',
# -> 1011             params=params, body=body)
#    1012
#    1013     @query_params()
#
# /usr/local/lib/python3.5/dist-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     312
#     313             try:
# --> 314                 status, headers_response, data = connection.perform_request(method, url, params, body, headers=headers, ignore=ignore, timeout=timeout)
#     315
#     316             except TransportError as e:
#
# /usr/local/lib/python3.5/dist-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     164             if self.http_compress and body:
#     165                 body = gzip.compress(body)
# --> 166             response = self.pool.urlopen(method, url, body, retries=False, headers=request_headers, **kw)
#     167             duration = time.time() - start
#     168             raw_data = response.data.decode('utf-8')
#
# /usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.5/http/client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# /usr/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## saving data as compressed hdf5 file

# %%
store = pd.HDFStore('frontier.h5', complevel=9)
store.append('tid_'+str(taskid), df)
